# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
df_xs_kT4_zQ2xbjPhT = pd.read_csv('../Unpol_proposal/Materials/enhanced_1xs_Nsim1Lum1.dat',delim_whitespace=True)
df_xs_kT4_zQ2xbjPhT.head()
# Out:
#    i  Ebeam         x      phih         y         z        Q2        pT   obs  \
# 0  0   11.0  0.089951 -2.838515  0.631022  0.322419  1.168826  0.160646  FUUT
# 1  1   11.0  0.110701 -2.830511  0.573350  0.323378  1.307896  0.142646  FUUT
# 2  2   11.0  0.135704 -2.823800  0.496652  0.323888  1.385438  0.125963  FUUT
# 3  3   11.0  0.170189 -2.812747  0.415303  0.324682  1.456716  0.076163  FUUT
# 4  4   11.0  0.097743 -2.240322  0.599704  0.322490  1.206434  0.160094  FUUT
#
#       value      stat  systrel systabs   target hadron Experiment     error
# 0  0.184163  0.000444      0.0     0.0  neutron    pi+      solid  0.000444
# 1  0.168190  0.000448      0.0     0.0  neutron    pi+      solid  0.000448
# 2  0.165526  0.000445      0.0     0.0  neutron    pi+      solid  0.000445
# 3  0.167753  0.001587      0.0     0.0  neutron    pi+      solid  0.001587
# 4  0.180834  0.000448      0.0     0.0  neutron    pi+      solid  0.000448

# %%
df_xs_kT8_zQ2xbjPhT = pd.read_csv('../Unpol_proposal/Materials/enhanced_1xs_Nsim1Lum2.dat',delim_whitespace=True)
df_xs_kT8_zQ2xbjPhT.head()
# Out:
#    i  Ebeam         x      phih         y         z        Q2        pT   obs  \
# 0  0   11.0  0.083886 -2.841947  0.643952  0.321910  1.113130  0.166017  FUUT
# 1  1   11.0  0.096364 -2.835966  0.617578  0.322935  1.228095  0.154915  FUUT
# 2  2   11.0  0.105848 -2.831311  0.589787  0.323377  1.288117  0.146252  FUUT
# 3  3   11.0  0.115755 -2.829210  0.556075  0.323432  1.328048  0.138699  FUUT
# 4  4   11.0  0.127496 -2.826982  0.518143  0.323672  1.362750  0.132956  FUUT
#
#       value      stat  systrel systabs   target hadron Experiment     error
# 0  0.193028  0.000442      0.0     0.0  neutron    pi+      solid  0.000442
# 1  0.175433  0.000447      0.0     0.0  neutron    pi+      solid  0.000447
# 2  0.169166  0.000449      0.0     0.0  neutron    pi+      solid  0.000449
# 3  0.167632  0.000445      0.0     0.0  neutron    pi+      solid  0.000445
# 4  0.166671  0.000443      0.0     0.0  neutron    pi+      solid  0.000443

# %%
kT8_list = df_xs_kT8_zQ2xbjPhT['stat'].to_list()
kT4_list = df_xs_kT4_zQ2xbjPhT['stat'].to_list()
for i_kT8 in range(0,len(kT8_list)):
    print(kT8_list[i_kT8],kT4_list[i_kT8])
# Out:
# 0.000442 0.000444
# 0.000447 0.000448
# 0.000449 0.000445
# 0.000445 0.001587
# 0.000443 0.000448
# 0.000445 0.000446
# 0.001248 0.000563
# 0.000449 0.000444
# 0.000442 0.000608
# 0.000445 0.000448
# 0.000448 0.000444
# 0.000446 0.00066
# 0.000898 0.000442
# 0.000445 0.000443
# 0.000444 0.000576
# 0.000446 0.000444
# 0.001565 0.000446
# 0.000452 0.000446
# 0.001718 0.00164
# 0.000452 0.000449
# 0.000448 0.000439
# 0.000444 0.000444
# 0.000474 0.000444
# 0.000442 0.000448
# 0.000442 0.000442
# 0.000446 0.000442
# 0.000441 0.00066
# 0.000447 0.000446
# 0.001022 0.000444
# 0.000442 0.00044
# 0.000447 0.00044
# 0.000447 0.000449
# 0.000444 0.000445
# 0.00045 0.000446
# 0.000443 0.000508
# 0.001243 0.000448
# 0.000446 0.000443
# 0.000453 0.000443
# 0.000439 0.000446
# 0.00044 0.000445
# 0.000443 0.000444
# 0.000437 0.000502
# 0.000442 0.000449
# 0.000446 0.00045
# 0.000443 0.000813
# 0.000447 0.000446
# 0.000435 0.000443
# 0.000445 0.000838
# 0.000441 0.000448
# 0.000442 0.000448
# ...

# %%
kT8_list = df_xs_kT8_zQ2xbjPhT['x'].to_list()
kT4_list = df_xs_kT4_zQ2xbjPhT['x'].to_list()
for i_kT8 in range(0,len(kT8_list)):
    print(kT8_list[i_kT8],kT4_list[i_kT8])

# %%
kT8_list = df_xs_kT8_zQ2xbjPhT['value'].to_list()
kT4_list = df_xs_kT4_zQ2xbjPhT['value'].to_list()
for i_kT8 in range(0,len(kT8_list)):
    print(kT8_list[i_kT8],kT4_list[i_kT8])
