# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from matplotlib import rc, rcParams
rc('text', usetex=True)
rc('axes', linewidth=1.5)
rc('axes', labelweight='bold')
rc('axes',labelsize=20)
rc('axes.formatter',min_exponent=0)
rc('font', weight='bold')
rc('font', size=16)
rc('xtick',direction='in')
rc('ytick',direction='in')
rc('xtick.major',width=1)
rc('ytick.major',width=1)
rc('xtick.major',size=6)
rc('ytick.major',size=6)
rc('xtick.minor',visible=True)
rc('ytick.minor',visible=True)
rc('xtick.minor',size=3)
rc('ytick.minor',size=3)
rc('xaxis',labellocation='right')
rc('yaxis',labellocation='top')
rc('lines',linewidth='2')
rcParams['text.latex.preamble'] = r'\usepackage{sfmath} \boldmath'

# %%
#    JLab 1: S=10.3 GeV2, Q=1.52 GeV, x=0.32, z=0.55
#    JLab 2: Eb=12 GeV, Q2=8 GeV2, x=0.48, z=0.375
#    JLab 3: Eb=24 GeV, Q2=15 GeV2, x=0.48, z=0.375
#    EIC 1: sqrt(S)=140 GeV, Q=3 GeV, y=0.4, z=0.5
#    EIC 2: sqrt(S)=140 GeV, Q=10 GeV, y=0.4, z=0.5
#    EIC 3: sqrt(S)=140 GeV, Q=5 GeV, x=0.01, z=0.5
#    qt_to_Q = PhT/x/Q

def Get_error(value1,error1,value2,error2):
    ratios=[]
    ratios_err=[]
    for i in range(0,len(value1)):
        ratio = value1[i]/value2[i]
        ratio_err = ratio*math.sqrt((error1[i]/value1[i])**2+(error2[i]/value2[i])**2)
        ratios.append(ratio)
        ratios_err.append(ratio_err)
    return ratios,ratios_err
    #return value1/value2,(value1/value2)*math.sqrt((error1/value1)**2+(error2/value2)**2)

# %%
df_T_eic3_unpol = pd.read_csv('results/Tra-results/results-fine/without-vac-pol/eic3-unpol.txt',delim_whitespace=True)
qt_to_Q = df_T_eic3_unpol['qt_to_Q']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_T_eic3_unpol = pd.read_csv('results/Tra-results/results-fine/without-vac-pol/eic3-unpol.txt',delim_whitespace=True)
#       2 qt_to_Q = df_T_eic3_unpol['qt_to_Q']
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results/Tra-results/results-fine/without-vac-pol/eic3-unpol.txt'

# %%
with open('analysis/increase_grids.txt','w') as file:
    for i_qtQ in qt_to_Q:
        print(round(i_qtQ,6))
        file.write(str(round(i_qtQ,6))+'\n')
        
file.close()

# %%
df_T_eic3_unpol = pd.read_csv('results/Tra-results/results-fine/results/eic3-unpol.txt',delim_whitespace=True)
df_T_eic3_unpol.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_T_eic3_unpol.head()
df_T_eic3_siv = pd.read_csv('results/Tra-results/results-fine/results/eic3-siv.txt',delim_whitespace=True)
df_T_eic3_siv.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_T_eic3_siv.head()
df_T_eic3_col = pd.read_csv('results/Tra-results/results-fine/results/eic3-col.txt',delim_whitespace=True)
df_T_eic3_col.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_T_eic3_col.head()

# %%
df_T_eic2_unpol = pd.read_csv('results/Tra-results/results-fine/results/eic2-unpol.txt',delim_whitespace=True)
df_T_eic2_unpol.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_T_eic2_unpol.head()
df_T_eic2_siv = pd.read_csv('results/Tra-results/results-fine/results/eic2-siv.txt',delim_whitespace=True)
df_T_eic2_siv.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_T_eic2_siv.head()
df_T_eic2_col = pd.read_csv('results/Tra-results/results-fine/results/eic2-col.txt',delim_whitespace=True)
df_T_eic2_col.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_T_eic2_col.head()

# %%
df_T_eic1_unpol = pd.read_csv('results/Tra-results/results-fine/results/eic1-unpol.txt',delim_whitespace=True)
df_T_eic1_unpol.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_T_eic1_unpol.head()
df_T_eic1_siv = pd.read_csv('results/Tra-results/results-fine/results/eic1-siv.txt',delim_whitespace=True)
df_T_eic1_siv.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_T_eic1_siv.head()
df_T_eic1_col = pd.read_csv('results/Tra-results/results-fine/results/eic1-col.txt',delim_whitespace=True)
df_T_eic1_col.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_T_eic1_col.head()

# %%
df_T_jlab3_unpol = pd.read_csv('results/Tra-results/results-fine/results/jlab3-unpol.txt',delim_whitespace=True)
df_T_jlab3_unpol.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_T_jlab3_unpol.head()
df_T_jlab3_siv = pd.read_csv('results/Tra-results/results-fine/results/jlab3-siv.txt',delim_whitespace=True)
df_T_jlab3_siv.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_T_jlab3_siv.head()
df_T_jlab3_col = pd.read_csv('results/Tra-results/results-fine/results/jlab3-col.txt',delim_whitespace=True)
df_T_jlab3_col.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_T_jlab3_col.head()

# %%
df_T_jlab2_unpol = pd.read_csv('results/Tra-results/results-fine/results/jlab2-unpol.txt',delim_whitespace=True)
df_T_jlab2_unpol.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_T_jlab2_unpol.head()
df_T_jlab2_siv = pd.read_csv('results/Tra-results/results-fine/results/jlab2-siv.txt',delim_whitespace=True)
df_T_jlab2_siv.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_T_jlab2_siv.head()
df_T_jlab2_col = pd.read_csv('results/Tra-results/results-fine/results/jlab2-col.txt',delim_whitespace=True)
df_T_jlab2_col.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_T_jlab2_col.head()

# %%
#df_T_JLab1_unpol = pd.read_csv('results/Tra-results/results-fine/results/JLab1-unpol.txt',delim_whitespace=True)
#df_T_JLab1_unpol.head()
#df_T_JLab1_siv = pd.read_csv('results/Tra-results/results-fine/results/JLab1-siv.txt',delim_whitespace=True)
#df_T_JLab1_siv.head()
#df_T_JLab1_col = pd.read_csv('results/Tra-results/results-fine/results/JLab1-col.txt',delim_whitespace=True)
#df_T_JLab1_col.head()

# %%
column_names=['x','z','Q','qT_Q','xs','xs_err']
df_F_EIC_1_siv_rc = pd.read_csv('results/Fac-results/Fine/EIC_1_siv_rc.txt',delim_whitespace=True,names=column_names)
df_F_EIC_1_siv_bn = pd.read_csv('results/Fac-results/Fine/EIC_1_siv_born.txt',delim_whitespace=True,names=column_names)
df_F_EIC_1_col_rc = pd.read_csv('results/Fac-results/Fine/EIC_1_col_rc.txt',delim_whitespace=True,names=column_names)
df_F_EIC_1_col_bn = pd.read_csv('results/Fac-results/Fine/EIC_1_col_born.txt',delim_whitespace=True,names=column_names)
df_F_EIC_1_unpol_rc = pd.read_csv('results/Fac-results/Fine/EIC_1_unpol_rc.txt',delim_whitespace=True,names=column_names)
df_F_EIC_1_unpol_bn = pd.read_csv('results/Fac-results/Fine/EIC_1_unpol_born.txt',delim_whitespace=True,names=column_names)
df_F_EIC_1_siv_rc.head()
print((df_F_EIC_1_unpol_bn['qT_Q']))
print((df_F_EIC_1_siv_bn['qT_Q']))
print((df_F_EIC_1_col_bn['qT_Q']))

# %%
df_F_eic1_siv_rc = pd.read_csv('results/Fac-results/EIC_1_siv_rc.txt',delim_whitespace=True,skiprows=12)
df_F_eic1_siv_bn = pd.read_csv('results/Fac-results/EIC_1_siv_bn.txt',delim_whitespace=True,skiprows=12)
df_F_eic1_col_rc = pd.read_csv('results/Fac-results/EIC_1_col_rc.txt',delim_whitespace=True,skiprows=12)
df_F_eic1_col_bn = pd.read_csv('results/Fac-results/EIC_1_col_bn.txt',delim_whitespace=True,skiprows=12)
df_F_eic1_unpol_rc = pd.read_csv('results/Fac-results/EIC_1_unpol_rc.txt',delim_whitespace=True,skiprows=12)
df_F_eic1_unpol_bn = pd.read_csv('results/Fac-results/EIC_1_unpol_bn.txt',delim_whitespace=True,skiprows=12)
df_T_eic1 = pd.read_csv('results/Tra-results/inj-all/results-eic1.txt',delim_whitespace=True)
df_T_eic1.head()

# %%
df_F_EIC_2_siv_rc = pd.read_csv('results/Fac-results/Fine/EIC_2_siv_rc.txt',delim_whitespace=True,names=column_names)
df_F_EIC_2_siv_bn = pd.read_csv('results/Fac-results/Fine/EIC_2_siv_born.txt',delim_whitespace=True,names=column_names)
df_F_EIC_2_col_rc = pd.read_csv('results/Fac-results/Fine/EIC_2_col_rc.txt',delim_whitespace=True,names=column_names)
df_F_EIC_2_col_bn = pd.read_csv('results/Fac-results/Fine/EIC_2_col_born.txt',delim_whitespace=True,names=column_names)
df_F_EIC_2_unpol_rc = pd.read_csv('results/Fac-results/Fine/EIC_2_unpol_rc.txt',delim_whitespace=True,names=column_names)
df_F_EIC_2_unpol_bn = pd.read_csv('results/Fac-results/Fine/EIC_2_unpol_born.txt',delim_whitespace=True,names=column_names)
df_F_EIC_2_siv_rc.head()

# %%
df_F_eic2_siv_rc = pd.read_csv('results/Fac-results/EIC_2_siv_rc.txt',delim_whitespace=True,skiprows=12)
df_F_eic2_siv_bn = pd.read_csv('results/Fac-results/EIC_2_siv_bn.txt',delim_whitespace=True,skiprows=12)
df_F_eic2_col_rc = pd.read_csv('results/Fac-results/EIC_2_col_rc.txt',delim_whitespace=True,skiprows=12)
df_F_eic2_col_bn = pd.read_csv('results/Fac-results/EIC_2_col_bn.txt',delim_whitespace=True,skiprows=12)
df_F_eic2_unpol_rc = pd.read_csv('results/Fac-results/EIC_2_unpol_rc.txt',delim_whitespace=True,skiprows=12)
df_F_eic2_unpol_bn = pd.read_csv('results/Fac-results/EIC_2_unpol_bn.txt',delim_whitespace=True,skiprows=12)
df_F_eic2_siv_rc.head()
df_T_eic2 = pd.read_csv('results/Tra-results/inj-all/results-eic2.txt',delim_whitespace=True)
df_T_eic2.head()

# %%
df_F_EIC_3_siv_rc = pd.read_csv('results/Fac-results/Fine/EIC_3_siv_rc.txt',delim_whitespace=True,names=column_names)
df_F_EIC_3_siv_bn = pd.read_csv('results/Fac-results/Fine/EIC_3_siv_born.txt',delim_whitespace=True,names=column_names)
df_F_EIC_3_col_rc = pd.read_csv('results/Fac-results/Fine/EIC_3_col_rc.txt',delim_whitespace=True,names=column_names)
df_F_EIC_3_col_bn = pd.read_csv('results/Fac-results/Fine/EIC_3_col_born.txt',delim_whitespace=True,names=column_names)
df_F_EIC_3_unpol_rc = pd.read_csv('results/Fac-results/Fine/EIC_3_unpol_rc.txt',delim_whitespace=True,names=column_names)
df_F_EIC_3_unpol_bn = pd.read_csv('results/Fac-results/Fine/EIC_3_unpol_born.txt',delim_whitespace=True,names=column_names)
df_F_EIC_3_siv_rc.head()

# %%
df_F_eic3_siv_rc = pd.read_csv('results/Fac-results/EIC_3_siv_rc.txt',delim_whitespace=True,skiprows=12)
df_F_eic3_siv_bn = pd.read_csv('results/Fac-results/EIC_3_siv_bn.txt',delim_whitespace=True,skiprows=12)
df_F_eic3_col_rc = pd.read_csv('results/Fac-results/EIC_3_col_rc.txt',delim_whitespace=True,skiprows=12)
df_F_eic3_col_bn = pd.read_csv('results/Fac-results/EIC_3_col_bn.txt',delim_whitespace=True,skiprows=12)
df_F_eic3_unpol_rc = pd.read_csv('results/Fac-results/EIC_3_unpol_rc.txt',delim_whitespace=True,skiprows=12)
df_F_eic3_unpol_bn = pd.read_csv('results/Fac-results/EIC_3_unpol_bn.txt',delim_whitespace=True,skiprows=12)
df_T_eic3 = pd.read_csv('results/Tra-results/inj-all/results-eic3.txt',delim_whitespace=True)
df_T_eic3.head()

# %%
df_F_JLab_1_siv_rc = pd.read_csv('results/Fac-results/Fine/Jlab_1_siv_rc.txt',delim_whitespace=True,names=column_names)
df_F_JLab_1_siv_bn = pd.read_csv('results/Fac-results/Fine/Jlab_1_siv_born.txt',delim_whitespace=True,names=column_names)
df_F_JLab_1_col_rc = pd.read_csv('results/Fac-results/Fine/Jlab_1_col_rc.txt',delim_whitespace=True,names=column_names)
df_F_JLab_1_col_bn = pd.read_csv('results/Fac-results/Fine/Jlab_1_col_born.txt',delim_whitespace=True,names=column_names)
df_F_JLab_1_unpol_rc = pd.read_csv('results/Fac-results/Fine/Jlab_1_unpol_rc.txt',delim_whitespace=True,names=column_names)
df_F_JLab_1_unpol_bn = pd.read_csv('results/Fac-results/Fine/Jlab_1_unpol_born.txt',delim_whitespace=True,names=column_names)
df_F_JLab_1_siv_rc.head()

# %%
df_F_JLab_2_siv_rc = pd.read_csv('results/Fac-results/Fine/JLab_2_siv_rc.txt',delim_whitespace=True,names=column_names)
df_F_JLab_2_siv_bn = pd.read_csv('results/Fac-results/Fine/JLab_2_siv_born.txt',delim_whitespace=True,names=column_names)
df_F_JLab_2_col_rc = pd.read_csv('results/Fac-results/Fine/JLab_2_col_rc.txt',delim_whitespace=True,names=column_names)
df_F_JLab_2_col_bn = pd.read_csv('results/Fac-results/Fine/JLab_2_col_born.txt',delim_whitespace=True,names=column_names)
df_F_JLab_2_unpol_rc = pd.read_csv('results/Fac-results/Fine/JLab_2_unpol_rc.txt',delim_whitespace=True,names=column_names)
df_F_JLab_2_unpol_bn = pd.read_csv('results/Fac-results/Fine/JLab_2_unpol_born.txt',delim_whitespace=True,names=column_names)
df_F_JLab_2_siv_rc.head()

# %%
df_F_JLab2_siv_rc = pd.read_csv('results/Fac-results/JLab_2_siv_rc.txt',delim_whitespace=True,skiprows=12)
df_F_JLab2_siv_bn = pd.read_csv('results/Fac-results/JLab_2_siv_bn.txt',delim_whitespace=True,skiprows=12)
df_F_JLab2_col_rc = pd.read_csv('results/Fac-results/JLab_2_col_rc.txt',delim_whitespace=True,skiprows=12)
df_F_JLab2_col_bn = pd.read_csv('results/Fac-results/JLab_2_col_bn.txt',delim_whitespace=True,skiprows=12)
df_F_JLab2_unpol_rc = pd.read_csv('results/Fac-results/JLab_2_unpol_rc.txt',delim_whitespace=True,skiprows=12)
df_F_JLab2_unpol_bn = pd.read_csv('results/Fac-results/JLab_2_unpol_bn.txt',delim_whitespace=True,skiprows=12)
df_F_JLab2_siv_rc.head()
df_T_JLab2 = pd.read_csv('results/Tra-results/inj-all/results-jlab2.txt',delim_whitespace=True)
df_T_JLab2.head()

# %%
df_F_JLab_3_siv_rc = pd.read_csv('results/Fac-results/Fine/JLab_3_siv_rc.txt',delim_whitespace=True,names=column_names)
df_F_JLab_3_siv_bn = pd.read_csv('results/Fac-results/Fine/JLab_3_siv_born.txt',delim_whitespace=True,names=column_names)
df_F_JLab_3_col_rc = pd.read_csv('results/Fac-results/Fine/JLab_3_col_rc.txt',delim_whitespace=True,names=column_names)
df_F_JLab_3_col_bn = pd.read_csv('results/Fac-results/Fine/JLab_3_col_born.txt',delim_whitespace=True,names=column_names)
df_F_JLab_3_unpol_rc = pd.read_csv('results/Fac-results/Fine/JLab_3_unpol_rc.txt',delim_whitespace=True,names=column_names)
df_F_JLab_3_unpol_bn = pd.read_csv('results/Fac-results/Fine/JLab_3_unpol_born.txt',delim_whitespace=True,names=column_names)
df_F_JLab_3_siv_rc.head()

# %%
df_F_JLab3_siv_rc = pd.read_csv('results/Fac-results/JLab_3_siv_rc.txt',delim_whitespace=True,skiprows=12)
df_F_JLab3_siv_bn = pd.read_csv('results/Fac-results/JLab_3_siv_bn.txt',delim_whitespace=True,skiprows=12)
df_F_JLab3_col_rc = pd.read_csv('results/Fac-results/JLab_3_col_rc.txt',delim_whitespace=True,skiprows=12)
df_F_JLab3_col_bn = pd.read_csv('results/Fac-results/JLab_3_col_bn.txt',delim_whitespace=True,skiprows=12)
df_F_JLab3_unpol_rc = pd.read_csv('results/Fac-results/JLab_3_unpol_rc.txt',delim_whitespace=True,skiprows=12)
df_F_JLab3_unpol_bn = pd.read_csv('results/Fac-results/JLab_3_unpol_bn.txt',delim_whitespace=True,skiprows=12)
df_F_JLab3_siv_rc.head()
df_T_JLab3 = pd.read_csv('results/Tra-results/inj-all/results-jlab3.txt',delim_whitespace=True)
df_T_JLab3.head()

# %%
#df_T_eic3_unpol,df_T_jlab2_unpol(all included),df_T_eic3_siv(only siv, the rc case would be different)
#df_F_JLab_2_unpol_bn
#fig,ax=one_plot()
plt.plot(np.asarray(df_T_jlab2_unpol['qt_to_Q']),df_T_jlab2_unpol['sivers_bn'],color='b',linestyle='--',label='born all')
plt.plot(np.asarray(df_T_jlab2_siv['qt_to_Q']),df_T_jlab2_siv['sivers_bn'],color='r',linestyle='-.',label='born only siv')
plt.xlim(0,0.7)
plt.ylim(3e-7,3.5e-7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/Tra_siv_bn_JLab2.pdf')
plt.figure()
plt.plot(np.asarray(df_T_jlab2_unpol['qt_to_Q']),df_T_jlab2_unpol['sivers_rc'],color='b',linestyle='--',label='rc all')
plt.plot(np.asarray(df_T_jlab2_siv['qt_to_Q']),df_T_jlab2_siv['sivers_rc'],color='r',linestyle='-.',label='rc only siv')
plt.plot(np.asarray(df_T_jlab2_siv['qt_to_Q']),np.asarray(df_T_jlab2_siv['sivers_rc'])+np.asarray(df_T_jlab2_col['sivers_rc']),color='m',linestyle=':',label='rc siv+col')
plt.xlim(0,0.7)
plt.ylim(2.5e-7,3e-7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/Tra_siv_rc_JLab2.pdf')
plt.figure()
plt.plot(np.asarray(df_T_jlab2_unpol['qt_to_Q']),df_T_jlab2_unpol['collins_bn'],color='b',linestyle='--',label='all')
plt.plot(np.asarray(df_T_jlab2_col['qt_to_Q']),df_T_jlab2_col['collins_bn'],color='r',linestyle='-.',label='only siv')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/Tra_col_bn_JLab2.pdf')
plt.figure()
plt.plot(np.asarray(df_T_jlab2_unpol['qt_to_Q']),df_T_jlab2_unpol['collins_rc'],color='b',linestyle='--',label='all')
plt.plot(np.asarray(df_T_jlab2_col['qt_to_Q']),df_T_jlab2_col['collins_rc'],color='r',linestyle='-.',label='only col')
plt.plot(np.asarray(df_T_jlab2_col['qt_to_Q']),np.asarray(df_T_jlab2_col['collins_rc'])+np.asarray(df_T_jlab2_siv['collins_rc']),color='m',linestyle=':',label='siv+col')
plt.xlim(0,0.7)
plt.ylim(4.8e-7,5.2e-7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/Tra_col_rc_JLab2.pdf')

# %%
print(df_T_eic1_unpol['qt_to_Q'])

# %%
#plt.plot(np.asarray(df_T_JLab2['qt_to_Q']),df_T_JLab2['sivers_bn'],color='b',label='Tra bn rough')
#plt.plot(np.asarray(df_F_JLab2_siv_bn['qT_Q']),df_F_JLab2_siv_bn['xs'],color='r',label='Fac bn rough')

plt.plot(np.asarray(df_T_jlab2_siv['qt_to_Q']),df_T_jlab2_siv['sivers_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_JLab_2_siv_bn['qT_Q']),df_F_JLab_2_siv_bn['xs'],color='r',label='Factorized bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_bn_jlab2.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_JLab2['qt_to_Q']),df_T_JLab2['sivers_rc'],color='b',label='Tra rc rough')
#plt.plot(np.asarray(df_F_JLab2_siv_rc['qT_Q']),df_F_JLab2_siv_rc['xs'],color='r',label='Fac rc rough')

plt.plot(np.asarray(df_T_jlab2_siv['qt_to_Q']),df_T_jlab2_siv['sivers_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_JLab_2_siv_rc['qT_Q']),df_F_JLab_2_siv_rc['xs'],color='r',label='Factorized rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_rc_jlab2.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_JLab2['qt_to_Q']),df_T_JLab2['collins_bn'],color='b',label='Tra bn rough')
#plt.plot(np.asarray(df_F_JLab2_col_bn['qT_Q']),df_F_JLab2_col_bn['xs'],color='r',label='Fac bn rough')

plt.plot(np.asarray(df_T_jlab2_col['qt_to_Q']),df_T_jlab2_col['collins_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_JLab_2_col_bn['qT_Q']),df_F_JLab_2_col_bn['xs'],color='r',label='Factorized bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_bn_jlab2.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_JLab2['qt_to_Q']),df_T_JLab2['collins_rc'],color='b',label='Tra rc rough')
#plt.plot(np.asarray(df_F_JLab2_col_rc['qT_Q']),df_F_JLab2_col_rc['xs'],color='r',label='Fac rc rough')

plt.plot(np.asarray(df_T_jlab2_col['qt_to_Q']),df_T_jlab2_col['collins_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_JLab_2_col_rc['qT_Q']),df_F_JLab_2_col_rc['xs'],color='r',label='Factorized rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_rc_jlab2.pdf')

# %%
#plt.plot(np.asarray(df_T_JLab2['qt_to_Q']),df_T_JLab2['sivers_bn'],color='b',label='Tra bn rough')
#plt.plot(np.asarray(df_F_JLab2_siv_bn['qT_Q']),df_F_JLab2_siv_bn['xs'],color='r',label='Fac bn rough')

plt.plot(np.asarray(df_T_jlab2_siv['qt_to_Q'])*0.375*np.sqrt(8),df_T_jlab2_siv['sivers_bn'],color='b',label='Traditional')
plt.plot(np.asarray(df_F_JLab_2_siv_bn['qT_Q'])*0.375*np.sqrt(8),df_F_JLab_2_siv_bn['xs'],color='r',label='Factorized')
plt.xlim(0,1.2)
plt.legend()
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_bn_jlab2_Pt.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_JLab2['qt_to_Q']),df_T_JLab2['sivers_rc'],color='b',label='Tra rc rough')
#plt.plot(np.asarray(df_F_JLab2_siv_rc['qT_Q']),df_F_JLab2_siv_rc['xs'],color='r',label='Fac rc rough')

plt.plot(np.asarray(df_T_jlab2_siv['qt_to_Q'])*0.375*np.sqrt(8),df_T_jlab2_siv['sivers_rc'],color='b',label='Traditional')
plt.plot(np.asarray(df_F_JLab_2_siv_rc['qT_Q'])*0.375*np.sqrt(8),df_F_JLab_2_siv_rc['xs'],color='r',label='Factorized')
plt.xlim(0,1.2)
plt.legend()
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_rc_jlab2_Pt.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_JLab2['qt_to_Q']),df_T_JLab2['collins_bn'],color='b',label='Tra bn rough')
#plt.plot(np.asarray(df_F_JLab2_col_bn['qT_Q']),df_F_JLab2_col_bn['xs'],color='r',label='Fac bn rough')

plt.plot(np.asarray(df_T_jlab2_col['qt_to_Q'])*0.375*np.sqrt(8),df_T_jlab2_col['collins_bn'],color='b',label='Traditional')
plt.plot(np.asarray(df_F_JLab_2_col_bn['qT_Q'])*0.375*np.sqrt(8),df_F_JLab_2_col_bn['xs'],color='r',label='Factorized')
plt.xlim(0,1.2)
plt.legend()
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_bn_jlab2_Pt.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_JLab2['qt_to_Q']),df_T_JLab2['collins_rc'],color='b',label='Tra rc rough')
#plt.plot(np.asarray(df_F_JLab2_col_rc['qT_Q']),df_F_JLab2_col_rc['xs'],color='r',label='Fac rc rough')

plt.plot(np.asarray(df_T_jlab2_col['qt_to_Q'])*0.375*np.sqrt(8),df_T_jlab2_col['collins_rc'],color='b',label='Traditional')
plt.plot(np.asarray(df_F_JLab_2_col_rc['qT_Q'])*0.375*np.sqrt(8),df_F_JLab_2_col_rc['xs'],color='r',label='Factorized')
plt.xlim(0,1.2)
plt.legend()
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_rc_jlab2_Pt.pdf')

# %%
#plt.plot(np.asarray(df_T_JLab2['qt_to_Q']),df_T_JLab2['unpol_bn'],color='b',label='Tra bn rough')
#plt.plot(np.asarray(df_F_JLab2_unpol_bn['qT_Q']),df_F_JLab2_unpol_bn['xs'],color='r',label='Fac bn rough')

plt.plot(np.asarray(df_T_jlab2_unpol['qt_to_Q']),df_T_jlab2_unpol['unpol_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_JLab_2_unpol_bn['qT_Q']),df_F_JLab_2_unpol_bn['xs'],color='r',label='Factorized bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/unpol_bn_JLab2.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_JLab2['qt_to_Q']),df_T_JLab2['unpol_rc'],color='b',label='Tra rc rough')
#plt.plot(np.asarray(df_F_JLab2_unpol_rc['qT_Q']),df_F_JLab2_unpol_rc['xs'],color='r',label='Fac rc rough')

plt.plot(np.asarray(df_T_jlab2_unpol['qt_to_Q']),df_T_jlab2_unpol['unpol_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_JLab_2_unpol_rc['qT_Q']),df_F_JLab_2_unpol_rc['xs'],color='r',label='Factorized rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/unpol_rc_JLab2.pdf')

# %%
plt.figure()
F_Born_JLab2 = np.asarray(df_F_JLab_2_unpol_bn['xs'])
T_Born_JLab2 = np.asarray(df_T_jlab2_unpol['unpol_bn'])
R_Born_unpol_JLab2 = F_Born_JLab2/T_Born_JLab2
plt.plot(np.asarray(df_F_JLab_2_unpol_bn['qT_Q'])*0.375*math.sqrt(8),R_Born_unpol_JLab2,color='b')
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$R_{Born}$',fontsize=16)
plt.ylim(0.94,1.06)
#plt.title('including unpol')
plt.savefig('results/compare/Fine/compare_born_unpol_JLab2.pdf')


plt.figure()
F_RC_JLab2 = np.asarray(df_F_JLab_2_unpol_rc['xs'])
T_RC_JLab2 = np.asarray(df_T_jlab2_unpol['unpol_rc'])
RC_F = F_Born_JLab2/F_RC_JLab2
RC_T = (T_Born_JLab2/T_RC_JLab2)
plt.plot(np.asarray(df_F_JLab_2_unpol_rc['qT_Q'])*0.375*math.sqrt(8),RC_F/RC_T,label='$RC_F/RC_T')
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
plt.ylim(0.9,1.1)
plt.xlim(0,1.2)
#plt.title('including unpol')
plt.savefig('results/compare/Fine/compare_RC_unpol_Pt_JLab2.pdf')

fig1 = plt.figure()
ax1 = fig1.add_subplot()
fig2 = plt.figure()
ax2 = fig2.add_subplot()
F_bnerr_JLab2 = np.asarray(df_F_JLab_2_unpol_bn['xs_err'])
T_bnerr_JLab2 = np.asarray(df_T_jlab2_unpol['unpol_bn_err'])
F_RCerr_JLab2 = np.asarray(df_F_JLab_2_unpol_rc['xs_err'])
T_RCerr_JLab2 = np.asarray(df_T_jlab2_unpol['unpol_rc_err'])
RC_Fs,RCerr_Fs=Get_error(F_Born_JLab2,F_bnerr_JLab2,F_RC_JLab2,F_RCerr_JLab2)
RC_Ts,RCerr_Ts=Get_error(T_Born_JLab2,T_bnerr_JLab2,T_RC_JLab2,T_RCerr_JLab2)
RC_ratios,RC_ratioerrs=Get_error(RC_Fs,RCerr_Fs,RC_Ts,RCerr_Ts)

ax1.fill_between(np.asarray(df_F_JLab_2_unpol_rc['qT_Q'].to_list()),np.asarray(RC_Fs)-np.asarray(RCerr_Fs),np.asarray(RC_Fs)+np.asarray(RCerr_Fs),color='red',alpha=0.25,linewidth=0)
ax1.fill_between(np.asarray(df_F_JLab_2_unpol_rc['qT_Q'].to_list()),np.asarray(RC_Ts)-np.asarray(RCerr_Ts),np.asarray(RC_Ts)+np.asarray(RCerr_Ts),color='blue',alpha=0.25,linewidth=0)
ax1.plot(np.asarray(df_F_JLab_2_unpol_rc['qT_Q'].to_list()),RC_Fs,color='red',label='Factorized')
ax1.plot(np.asarray(df_F_JLab_2_unpol_rc['qT_Q'].to_list()),RC_Ts,color='blue',label='Traditional')
ax1.set_xlabel('$qT/Q$',fontsize=16)
ax1.set_ylabel('RC',fontsize=16)
ax1.legend()
fig1.savefig('results/compare/Fine/RCs_both_JLab2.pdf')


ax2.fill_between(np.asarray(df_F_JLab_2_unpol_rc['qT_Q'].to_list()),np.asarray(RC_ratios)-np.asarray(RC_ratioerrs),np.asarray(RC_ratios)+np.asarray(RC_ratioerrs),color='black',alpha=0.25,linewidth=0)
ax2.plot(np.asarray(df_F_JLab_2_unpol_rc['qT_Q'].to_list()),RC_ratios,color='black')
ax2.set_xlabel('$qT/Q$',fontsize=16)
ax2.set_ylabel('$RC_F/RC_T$',fontsize=16)
fig2.savefig('results/compare/Fine/compare_RC_unpol_JLab2.pdf')

fig3 = plt.figure()
ax3 = fig3.add_subplot()
ax3.fill_between(np.asarray(df_F_JLab_2_unpol_rc['qT_Q'].to_list())*0.375*math.sqrt(8),np.asarray(RC_Fs)-np.asarray(RCerr_Fs),np.asarray(RC_Fs)+np.asarray(RCerr_Fs),color='red',alpha=0.25,linewidth=0)
ax3.fill_between(np.asarray(df_F_JLab_2_unpol_rc['qT_Q'].to_list())*0.375*math.sqrt(8),np.asarray(RC_Ts)-np.asarray(RCerr_Ts),np.asarray(RC_Ts)+np.asarray(RCerr_Ts),color='blue',alpha=0.25,linewidth=0)
ax3.plot(np.asarray(df_F_JLab_2_unpol_rc['qT_Q'].to_list())*0.375*math.sqrt(8),RC_Fs,color='red',label='Factorized')
ax3.plot(np.asarray(df_F_JLab_2_unpol_rc['qT_Q'].to_list())*0.375*math.sqrt(8),RC_Ts,color='blue',label='Traditional')
ax3.set_xlabel('$P_{hT}(GeV/c)$',fontsize=16)
ax3.set_ylabel(r'$\textbf{RC}$',fontsize=16)
ax3.legend()
plt.xlim(0,1.2)
fig3.savefig('results/compare/Fine/RCs_both_JLab2_Pt.pdf')

plt.figure()
plt.plot(np.asarray(df_F_JLab_2_unpol_rc['qT_Q'].to_list()),(np.asarray(RC_Fs)-np.asarray(RC_Ts))/(np.asarray(RC_Ts)-np.asarray(1)),color = 'black')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel(r'$\frac{RC_F-RC_T}{RC_T}$',fontsize=16)
plt.ylim(0,0.5)
plt.xlim(0,0.8)
plt.savefig('results/compare/Fine/compare_RC_with1_unpol_JLab2.pdf')

plt.figure()
F_Born_JLab2 = np.asarray(df_F_JLab_2_unpol_bn['xs'])+np.asarray(df_F_JLab_2_siv_bn['xs'])+np.asarray(df_F_JLab_2_col_bn['xs'])
T_Born_JLab2 = np.asarray(df_T_jlab2_unpol['unpol_bn'])+np.asarray(df_T_jlab2_unpol['sivers_bn'])+np.asarray(df_T_jlab2_unpol['collins_bn'])
R_Born_JLab2 = F_Born_JLab2/T_Born_JLab2
plt.plot(np.asarray(df_F_JLab_2_unpol_bn['qT_Q']),R_Born_JLab2,color='b')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$R_{Born}$',fontsize=16)
plt.ylim(0.94,1.06)
plt.title('including unpol and pol')
plt.savefig('results/compare/Fine/compare_born_both_JLab2.pdf')


plt.figure()
F_RC_JLab2 = np.asarray(df_F_JLab_2_unpol_rc['xs'])+np.asarray(df_F_JLab_2_siv_rc['xs'])+np.asarray(df_F_JLab_2_col_rc['xs'])
T_RC_JLab2 = np.asarray(df_T_jlab2_unpol['unpol_rc'])+np.asarray(df_T_jlab2_siv['sivers_rc'])+np.asarray(df_T_jlab2_col['collins_rc'])
RC_F = F_Born_JLab2/F_RC_JLab2
RC_T = (T_Born_JLab2/T_RC_JLab2)
plt.plot(np.asarray(df_F_JLab_2_unpol_rc['qT_Q']),RC_F/RC_T,label='$RC_F/RC_T')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
plt.ylim(0.9,1.2)
plt.title('including unpol and pol')
plt.savefig('results/compare/Fine/compare_RC_both_JLab2.pdf')

# %%
T_bn_qtQ_jlab2 = df_T_jlab2_siv['qt_to_Q'].to_list()
T_bn_siv_jlab2 = df_T_jlab2_siv['sivers_bn'].to_list()
F_bn_qtQ_JLab_2 = df_F_JLab_2_siv_bn['qT_Q'].to_list()
F_bn_siv_JLab_2 = df_F_JLab_2_siv_bn['xs'].to_list()
T_rc_qtQ_jlab2 = df_T_jlab2_siv['qt_to_Q'].to_list()
T_rc_siv_jlab2 = df_T_jlab2_siv['sivers_rc'].to_list()
F_rc_qtQ_JLab_2 = df_F_JLab_2_siv_rc['qT_Q'].to_list()
F_rc_siv_JLab_2 = df_F_JLab_2_siv_rc['xs'].to_list()
RC_F_siv_jlab2 = np.asarray(F_bn_siv_JLab_2)/np.asarray(F_rc_siv_JLab_2)
RC_T_siv_jlab2 = np.asarray(T_bn_siv_jlab2)/np.asarray(T_rc_siv_jlab2)
plt.plot(T_bn_qtQ_jlab2,RC_T_siv_jlab2,color='r',label='Traditional RC')
plt.plot(F_bn_qtQ_JLab_2,RC_F_siv_jlab2,color='b',label='Factorized RC')
plt.xlabel('qT/Q',fontsize =16)
plt.ylabel('RC from siv',fontsize =16)
plt.legend()
plt.savefig('results/compare/Fine/RCs_siv_both_JLab2.pdf')

plt.figure()
T_bn_qtQ_jlab2 = df_T_jlab2_col['qt_to_Q'].to_list()
T_bn_col_jlab2 = df_T_jlab2_col['collins_bn'].to_list()
F_bn_qtQ_JLab_2 = df_F_JLab_2_col_bn['qT_Q'].to_list()
F_bn_col_JLab_2 = df_F_JLab_2_col_bn['xs'].to_list()
T_rc_qtQ_jlab2 = df_T_jlab2_col['qt_to_Q'].to_list()
T_rc_col_jlab2 = df_T_jlab2_col['collins_rc'].to_list()
F_rc_qtQ_JLab_2 = df_F_JLab_2_col_rc['qT_Q'].to_list()
F_rc_col_JLab_2 = df_F_JLab_2_col_rc['xs'].to_list()
RC_F_col_jlab2 = np.asarray(F_bn_col_JLab_2)/np.asarray(F_rc_col_JLab_2)
RC_T_col_jlab2 = np.asarray(T_bn_col_jlab2)/np.asarray(T_rc_col_jlab2)
plt.plot(T_bn_qtQ_jlab2,RC_T_col_jlab2,color='r',label='Traditional RC')
plt.plot(F_bn_qtQ_JLab_2,RC_F_col_jlab2,color='b',label='Factorized RC')
plt.xlabel('qT/Q',fontsize =16)
plt.ylabel('RC from col',fontsize =16)
plt.legend()
plt.savefig('results/compare/Fine/RCs_col_both_JLab2.pdf')

plt.figure()
RC_FT_siv = RC_F_siv_jlab2/RC_T_siv_jlab2
plt.plot(T_bn_qtQ_jlab2,RC_FT_siv,label='siv')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
plt.legend()
plt.ylim(0.9,1.2)
plt.savefig('results/compare/Fine/compare_RC_siv_jlab2.pdf')
plt.figure()
plt.plot(T_bn_qtQ_jlab2,(np.asarray(RC_F_siv_jlab2)-np.asarray(RC_T_siv_jlab2))/(np.asarray(RC_T_siv_jlab2)-np.asarray(1)),color = 'black')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel(r'$\frac{RC_F-RC_T}{RC_T}$ siv',fontsize=16)
plt.ylim(0,0.5)
plt.xlim(0,0.8)
plt.savefig('results/compare/Fine/compare_RC_with1_siv_jlab2.pdf')
plt.figure()
RC_FT_col = RC_F_col_jlab2/RC_T_col_jlab2
plt.plot(T_bn_qtQ_jlab2,RC_FT_col,label='col')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
plt.legend()
plt.ylim(0.9,1.2)
plt.savefig('results/compare/Fine/compare_RC_col_jlab2.pdf')
plt.figure()
plt.plot(T_bn_qtQ_jlab2,(np.asarray(RC_F_col_jlab2)-np.asarray(RC_T_col_jlab2))/(np.asarray(RC_T_col_jlab2)-np.asarray(1)),color = 'black')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel(r'$\frac{RC_F-RC_T}{RC_T}$ col',fontsize=16)
plt.ylim(0,0.5)
plt.xlim(0,0.8)
plt.savefig('results/compare/Fine/compare_RC_with1_col_jlab2.pdf')

# %%
#plt.plot(np.asarray(df_T_JLab3['qt_to_Q']),df_T_JLab3['sivers_bn'],color='b',label='Tra bn rough')
#plt.plot(np.asarray(df_F_JLab3_siv_bn['qT_Q']),df_F_JLab3_siv_bn['xs'],color='r',label='Fac bn rough')

plt.plot(np.asarray(df_T_jlab3_siv['qt_to_Q']),df_T_jlab3_siv['sivers_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_JLab_3_siv_bn['qT_Q']),df_F_JLab_3_siv_bn['xs'],color='r',label='Factorized bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_bn_jlab3.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_JLab3['qt_to_Q']),df_T_JLab3['sivers_rc'],color='b',label='Tra rc rough')
#plt.plot(np.asarray(df_F_JLab3_siv_rc['qT_Q']),df_F_JLab3_siv_rc['xs'],color='r',label='Fac rc rough')

plt.plot(np.asarray(df_T_jlab3_siv['qt_to_Q']),df_T_jlab3_siv['sivers_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_JLab_3_siv_rc['qT_Q']),df_F_JLab_3_siv_rc['xs'],color='r',label='Factorized rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_rc_jlab3.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_JLab3['qt_to_Q']),df_T_JLab3['collins_bn'],color='b',linestyle='-.',label='Tra bn rough')
#plt.plot(np.asarray(df_F_JLab3_col_bn['qT_Q']),df_F_JLab3_col_bn['xs'],color='r',linestyle='-.',label='Fac bn rough')

plt.plot(np.asarray(df_T_jlab3_col['qt_to_Q']),df_T_jlab3_col['collins_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_JLab_3_col_bn['qT_Q']),df_F_JLab_3_col_bn['xs'],color='r',label='Factorized bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_bn_jlab3.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_JLab3['qt_to_Q']),df_T_JLab3['collins_rc'],color='b',linestyle='-.',label='Tra rc rough')
#plt.plot(np.asarray(df_F_JLab3_col_rc['qT_Q']),df_F_JLab3_col_rc['xs'],color='r',linestyle='-.',label='Fac rc rough')

plt.plot(np.asarray(df_T_jlab3_col['qt_to_Q']),df_T_jlab3_col['collins_rc'],color='b',linestyle='-',label='Traditional rc')
plt.plot(np.asarray(df_F_JLab_3_col_rc['qT_Q']),df_F_JLab_3_col_rc['xs'],color='r',linestyle='-',label='Factorized rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_rc_jlab3.pdf')

# %%
#plt.plot(np.asarray(df_T_JLab3['qt_to_Q']),df_T_JLab3['sivers_bn'],color='b',label='Tra bn rough')
#plt.plot(np.asarray(df_F_JLab3_siv_bn['qT_Q']),df_F_JLab3_siv_bn['xs'],color='r',label='Fac bn rough')

plt.plot(np.asarray(df_T_jlab3_siv['qt_to_Q'])*0.375*np.sqrt(15),df_T_jlab3_siv['sivers_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_JLab_3_siv_bn['qT_Q'])*0.375*np.sqrt(15),df_F_JLab_3_siv_bn['xs'],color='r',label='Factorized bn')
plt.xlim(0,1.2)
plt.legend()
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_bn_jlab3_Pt.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_JLab3['qt_to_Q']),df_T_JLab3['sivers_rc'],color='b',label='Tra rc rough')
#plt.plot(np.asarray(df_F_JLab3_siv_rc['qT_Q']),df_F_JLab3_siv_rc['xs'],color='r',label='Fac rc rough')

plt.plot(np.asarray(df_T_jlab3_siv['qt_to_Q'])*0.375*np.sqrt(15),df_T_jlab3_siv['sivers_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_JLab_3_siv_rc['qT_Q'])*0.375*np.sqrt(15),df_F_JLab_3_siv_rc['xs'],color='r',label='Factorized rc')
plt.xlim(0,1.2)
plt.legend()
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_rc_jlab3_Pt.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_JLab3['qt_to_Q']),df_T_JLab3['collins_bn'],color='b',linestyle='-.',label='Tra bn rough')
#plt.plot(np.asarray(df_F_JLab3_col_bn['qT_Q']),df_F_JLab3_col_bn['xs'],color='r',linestyle='-.',label='Fac bn rough')

plt.plot(np.asarray(df_T_jlab3_col['qt_to_Q'])*0.375*np.sqrt(15),df_T_jlab3_col['collins_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_JLab_3_col_bn['qT_Q'])*0.375*np.sqrt(15),df_F_JLab_3_col_bn['xs'],color='r',label='Factorized bn')
plt.xlim(0,1.2)
plt.legend()
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_bn_jlab3_Pt.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_JLab3['qt_to_Q']),df_T_JLab3['collins_rc'],color='b',linestyle='-.',label='Tra rc rough')
#plt.plot(np.asarray(df_F_JLab3_col_rc['qT_Q']),df_F_JLab3_col_rc['xs'],color='r',linestyle='-.',label='Fac rc rough')

plt.plot(np.asarray(df_T_jlab3_col['qt_to_Q'])*0.375*np.sqrt(15),df_T_jlab3_col['collins_rc'],color='b',linestyle='-',label='Traditional rc')
plt.plot(np.asarray(df_F_JLab_3_col_rc['qT_Q'])*0.375*np.sqrt(15),df_F_JLab_3_col_rc['xs'],color='r',linestyle='-',label='Factorized rc')
plt.xlim(0,1.2)
plt.legend()
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_rc_jlab3_Pt.pdf')

# %%
#plt.plot(np.asarray(df_T_JLab3['qt_to_Q']),df_T_JLab3['unpol_bn'],color='b',label='Tra bn rough')
#plt.plot(np.asarray(df_F_JLab3_unpol_bn['qT_Q']),df_F_JLab3_unpol_bn['xs'],color='r',label='Fac bn rough')

plt.plot(np.asarray(df_T_jlab3_unpol['qt_to_Q']),df_T_jlab3_unpol['unpol_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_JLab_3_unpol_bn['qT_Q']),df_F_JLab_3_unpol_bn['xs'],color='r',label='Factorized bn')
#plt.xlim(0.7,1.4)
#plt.ylim(0,5e-7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/unpol_bn_JLab3.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_JLab3['qt_to_Q']),df_T_JLab3['unpol_rc'],color='b',label='Tra rc rough')
#plt.plot(np.asarray(df_F_JLab3_unpol_rc['qT_Q']),df_F_JLab3_unpol_rc['xs'],color='r',label='Fac rc rough')

plt.plot(np.asarray(df_T_jlab3_unpol['qt_to_Q']),df_T_jlab3_unpol['unpol_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_JLab_3_unpol_rc['qT_Q']),df_F_JLab_3_unpol_rc['xs'],color='r',label='Factorized rc')
#plt.xlim(0.7,1.4)
#plt.ylim(0,5e-7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/unpol_rc_JLab3.pdf')

# %%
plt.figure()
F_Born_JLab3 = np.asarray(df_F_JLab_3_unpol_bn['xs'])
T_Born_JLab3 = np.asarray(df_T_jlab3_unpol['unpol_bn'])
R_Born_JLab3 = F_Born_JLab3/T_Born_JLab3
plt.plot(np.asarray(df_F_JLab_3_unpol_bn['qT_Q'])*0.375*math.sqrt(15),R_Born_JLab3,color='b')
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$R_{Born}$',fontsize=16)
plt.ylim(0.94,1.06)
plt.title('including unpol')
plt.savefig('results/compare/Fine/compare_born_unpol_JLab3.pdf')


plt.figure()
F_RC_JLab3 = np.asarray(df_F_JLab_3_unpol_rc['xs'])
T_RC_JLab3 = np.asarray(df_T_jlab3_unpol['unpol_rc'])
RC_F = F_Born_JLab3/F_RC_JLab3
RC_T = (T_Born_JLab3/T_RC_JLab3)
plt.plot(np.asarray(df_F_JLab_3_unpol_rc['qT_Q'])*0.375*math.sqrt(15),RC_F/RC_T,label='$RC_F/RC_T')
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
plt.ylim(0.9,1.125)
plt.xlim(0,1.2)
#plt.title('including unpol')
plt.savefig('results/compare/Fine/compare_RC_unpol_Pt_JLab3.pdf')

fig1 = plt.figure()
ax1 = fig1.add_subplot()
fig2 = plt.figure()
ax2 = fig2.add_subplot()
F_bnerr_JLab3 = np.asarray(df_F_JLab_3_unpol_bn['xs_err'])
T_bnerr_JLab3 = np.asarray(df_T_jlab3_unpol['unpol_bn_err'])
F_RCerr_JLab3 = np.asarray(df_F_JLab_3_unpol_rc['xs_err'])
T_RCerr_JLab3 = np.asarray(df_T_jlab3_unpol['unpol_rc_err'])
RC_Fs,RCerr_Fs=Get_error(F_Born_JLab3,F_bnerr_JLab3,F_RC_JLab3,F_RCerr_JLab3)
RC_Ts,RCerr_Ts=Get_error(T_Born_JLab3,T_bnerr_JLab3,T_RC_JLab3,T_RCerr_JLab3)
RC_ratios,RC_ratioerrs=Get_error(RC_Fs,RCerr_Fs,RC_Ts,RCerr_Ts)

#ax1.fill_between(np.asarray(df_F_JLab_3_unpol_rc['qT_Q'].to_list()),np.asarray(RC_Fs)-np.asarray(RCerr_Fs),np.asarray(RC_Fs)+np.asarray(RCerr_Fs),color='red',alpha=0.25,linewidth=0)
#ax1.fill_between(np.asarray(df_F_JLab_3_unpol_rc['qT_Q'].to_list()),np.asarray(RC_Ts)-np.asarray(RCerr_Ts),np.asarray(RC_Ts)+np.asarray(RCerr_Ts),color='blue',alpha=0.25,linewidth=0)
ax1.plot(np.asarray(df_F_JLab_3_unpol_rc['qT_Q'].to_list()),RC_Fs,color='red',label='Factorized')
ax1.plot(np.asarray(df_F_JLab_3_unpol_rc['qT_Q'].to_list()),RC_Ts,color='blue',label='Traditional')
ax1.set_xlabel('$qT/Q$',fontsize=16)
ax1.set_ylabel('RC',fontsize=16)
ax1.legend()
fig1.savefig('results/compare/Fine/RCs_both_JLab3.pdf')
ax2.fill_between(np.asarray(df_F_JLab_3_unpol_rc['qT_Q'].to_list()),np.asarray(RC_ratios)-np.asarray(RC_ratioerrs),np.asarray(RC_ratios)+np.asarray(RC_ratioerrs),color='black',alpha=0.25,linewidth=0)
ax2.plot(np.asarray(df_F_JLab_3_unpol_rc['qT_Q'].to_list()),RC_ratios,color='black')
ax2.set_xlabel('$qT/Q$',fontsize=16)
ax2.set_ylabel('$RC_F/RC_T$',fontsize=16)
fig2.savefig('results/compare/Fine/compare_RC_unpol_JLab3.pdf')
plt.figure()
plt.plot(np.asarray(df_F_JLab_3_unpol_rc['qT_Q'].to_list()),(np.asarray(RC_Fs)-np.asarray(RC_Ts))/(np.asarray(RC_Ts)-np.asarray(1)),color = 'black')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel(r'$\frac{RC_F-RC_T}{RC_T}$',fontsize=16)
plt.ylim(0,0.5)
plt.xlim(0,0.8)
plt.savefig('results/compare/Fine/compare_RC_with1_unpol_JLab3.pdf')

plt.figure()
plt.plot(np.asarray(df_F_JLab_3_unpol_rc['qT_Q'].to_list())*0.375*math.sqrt(15),RC_Fs,color='red',label='Factorized')
plt.plot(np.asarray(df_F_JLab_3_unpol_rc['qT_Q'].to_list())*0.375*math.sqrt(15),RC_Ts,color='blue',label='Traditional')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel(r'$\textbf{RC}$',fontsize=16)
plt.legend()
plt.xlim(0,1.2)
plt.ylim(0,2)
plt.savefig('results/compare/Fine/RCs_both_JLab3_Pt.pdf')

plt.figure()
F_Born_JLab3 = np.asarray(df_F_JLab_3_unpol_bn['xs'])+np.asarray(df_F_JLab_3_siv_bn['xs'])+np.asarray(df_F_JLab_3_col_bn['xs'])
T_Born_JLab3 = np.asarray(df_T_jlab3_unpol['unpol_bn'])+np.asarray(df_T_jlab3_unpol['sivers_bn'])+np.asarray(df_T_jlab3_unpol['collins_bn'])
R_Born_JLab3 = F_Born_JLab3/T_Born_JLab3
plt.plot(np.asarray(df_F_JLab_3_unpol_bn['qT_Q']),R_Born_JLab3,color='b')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$R_{Born}$',fontsize=16)
plt.ylim(0.94,1.06)
plt.title('including both unpol and pol')
plt.savefig('results/compare/Fine/compare_born_both_JLab3.pdf')



plt.figure()
F_RC_JLab3 = np.asarray(df_F_JLab_3_unpol_rc['xs'])+np.asarray(df_F_JLab_3_siv_rc['xs'])+np.asarray(df_F_JLab_3_col_rc['xs'])
T_RC_JLab3 = np.asarray(df_T_jlab3_unpol['unpol_rc'])+np.asarray(df_T_jlab3_siv['sivers_rc'])+np.asarray(df_T_jlab3_col['collins_rc'])
RC_F = F_Born_JLab3/F_RC_JLab3
RC_T = (T_Born_JLab3/T_RC_JLab3)
plt.plot(np.asarray(df_F_JLab_3_unpol_rc['qT_Q']),RC_F/RC_T,label='$RC_F/RC_T')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
plt.ylim(0.9,1.2)
plt.title('including both unpol and pol')
plt.savefig('results/compare/Fine/compare_RC_both_JLab3.pdf')

# %%
T_bn_qtQ_jlab3 = df_T_jlab3_siv['qt_to_Q'].to_list()
T_bn_siv_jlab3 = df_T_jlab3_siv['sivers_bn'].to_list()
F_bn_qtQ_JLab_3 = df_F_JLab_3_siv_bn['qT_Q'].to_list()
F_bn_siv_JLab_3 = df_F_JLab_3_siv_bn['xs'].to_list()
T_rc_qtQ_jlab3 = df_T_jlab3_siv['qt_to_Q'].to_list()
T_rc_siv_jlab3 = df_T_jlab3_siv['sivers_rc'].to_list()
F_rc_qtQ_JLab_3 = df_F_JLab_3_siv_rc['qT_Q'].to_list()
F_rc_siv_JLab_3 = df_F_JLab_3_siv_rc['xs'].to_list()
RC_F_siv_jlab3 = np.asarray(F_bn_siv_JLab_3)/np.asarray(F_rc_siv_JLab_3)
RC_T_siv_jlab3 = np.asarray(T_bn_siv_jlab3)/np.asarray(T_rc_siv_jlab3)
plt.plot(T_bn_qtQ_jlab3,RC_T_siv_jlab3,color='r',label='Traditional RC')
plt.plot(F_bn_qtQ_JLab_3,RC_F_siv_jlab3,color='b',label='Factorized RC')
plt.xlabel('qT/Q',fontsize =16)
plt.ylabel('RC from siv',fontsize =16)
plt.legend()
plt.savefig('results/compare/Fine/RCs_siv_both_jlab3.pdf')

plt.figure()
T_bn_qtQ_jlab3 = df_T_jlab3_col['qt_to_Q'].to_list()
T_bn_col_jlab3 = df_T_jlab3_col['collins_bn'].to_list()
F_bn_qtQ_JLab_3 = df_F_JLab_3_col_bn['qT_Q'].to_list()
F_bn_col_JLab_3 = df_F_JLab_3_col_bn['xs'].to_list()
T_rc_qtQ_jlab3 = df_T_jlab3_col['qt_to_Q'].to_list()
T_rc_col_jlab3 = df_T_jlab3_col['collins_rc'].to_list()
F_rc_qtQ_JLab_3 = df_F_JLab_3_col_rc['qT_Q'].to_list()
F_rc_col_JLab_3 = df_F_JLab_3_col_rc['xs'].to_list()
RC_F_col_jlab3 = np.asarray(F_bn_col_JLab_3)/np.asarray(F_rc_col_JLab_3)
RC_T_col_jlab3 = np.asarray(T_bn_col_jlab3)/np.asarray(T_rc_col_jlab3)
plt.plot(T_bn_qtQ_jlab3,RC_T_col_jlab3,color='r',label='Traditional RC')
plt.plot(F_bn_qtQ_JLab_3,RC_F_col_jlab3,color='b',label='Factorized RC')
plt.xlabel('qT/Q',fontsize =16)
plt.ylabel('RC from col',fontsize =16)
plt.legend()
plt.savefig('results/compare/Fine/RCs_col_both_jlab3.pdf')

plt.figure()
RC_FT_siv = RC_F_siv_jlab3/RC_T_siv_jlab3
plt.plot(T_bn_qtQ_jlab3,RC_FT_siv,label='siv')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
plt.legend()
plt.ylim(0.9,1.2)
plt.savefig('results/compare/Fine/compare_RC_siv_jlab3.pdf')
plt.figure()
plt.plot(T_bn_qtQ_jlab3,(np.asarray(RC_F_siv_jlab3)-np.asarray(RC_T_siv_jlab3))/(np.asarray(RC_T_siv_jlab3)-np.asarray(1)),color = 'black')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel(r'$\frac{RC_F-RC_T}{RC_T}$ siv',fontsize=16)
plt.ylim(0,0.5)
plt.xlim(0,0.8)
plt.savefig('results/compare/Fine/compare_RC_with1_siv_jlab3.pdf')
plt.figure()
RC_FT_col = RC_F_col_jlab3/RC_T_col_jlab3
plt.plot(T_bn_qtQ_jlab3,RC_FT_col,label='col')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
plt.legend()
plt.ylim(0.9,1.2)
plt.savefig('results/compare/Fine/compare_RC_col_jlab3.pdf')
plt.figure()
plt.plot(T_bn_qtQ_jlab3,(np.asarray(RC_F_col_jlab3)-np.asarray(RC_T_col_jlab3))/(np.asarray(RC_T_col_jlab3)-np.asarray(1)),color = 'black')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel(r'$\frac{RC_F-RC_T}{RC_T}$ col',fontsize=16)
plt.ylim(0,0.5)
plt.xlim(0,0.8)
plt.savefig('results/compare/Fine/compare_RC_with1_col_jlab3.pdf')

# %%
#plt.plot(np.asarray(df_T_eic1['qt_to_Q']),df_T_eic1['sivers_bn'],color='b',label='Tra bn rough')
#plt.plot(np.asarray(df_F_eic1_siv_bn['qT_Q']),df_F_eic1_siv_bn['xs'],color='r',label='Fac bn rough')

plt.plot(np.asarray(df_T_eic1_siv['qt_to_Q']),df_T_eic1_siv['sivers_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_EIC_1_siv_bn['qT_Q']),df_F_EIC_1_siv_bn['xs'],color='r',label='Factorized bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_bn_eic1.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic1['qt_to_Q']),df_T_eic1['sivers_rc'],color='b',label='Tra rc rough')
#plt.plot(np.asarray(df_F_eic1_siv_rc['qT_Q']),df_F_eic1_siv_rc['xs'],color='r',label='Fac rc rough')

plt.plot(np.asarray(df_T_eic1_siv['qt_to_Q']),df_T_eic1_siv['sivers_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_EIC_1_siv_rc['qT_Q']),df_F_EIC_1_siv_rc['xs'],color='r',label='Factorized rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_rc_eic1.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic1['qt_to_Q']),df_T_eic1['collins_bn'],color='b',label='Tra bn rough')
#plt.plot(np.asarray(df_F_eic1_col_bn['qT_Q']),df_F_eic1_col_bn['xs'],color='r',label='Fac bn rough')

plt.plot(np.asarray(df_T_eic1_col['qt_to_Q']),df_T_eic1_col['collins_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_EIC_1_col_bn['qT_Q']),df_F_EIC_1_col_bn['xs'],color='r',label='Factorized bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_bn_eic1.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic1['qt_to_Q']),df_T_eic1['collins_rc'],color='b',label='Tra rc rough')
#plt.plot(np.asarray(df_F_eic1_col_rc['qT_Q']),df_F_eic1_col_rc['xs'],color='r',label='Fac rc rough')

plt.plot(np.asarray(df_T_eic1_col['qt_to_Q']),df_T_eic1_col['collins_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_EIC_1_col_rc['qT_Q']),df_F_EIC_1_col_rc['xs'],color='r',label='Factorized rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_rc_eic1.pdf')

# %%
#plt.plot(np.asarray(df_T_eic1['qt_to_Q']),df_T_eic1['unpol_bn'],color='b',label='Tra bn rough')
#plt.plot(np.asarray(df_F_eic1_unpol_bn['qT_Q']),df_F_eic1_unpol_bn['xs'],color='r',label='Fac bn rough')

plt.plot(np.asarray(df_T_eic1_unpol['qt_to_Q']),df_T_eic1_unpol['unpol_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_EIC_1_unpol_bn['qT_Q']),df_F_EIC_1_unpol_bn['xs'],color='r',label='Factorized bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/unpol_bn_eic1.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic1['qt_to_Q']),df_T_eic1['unpol_rc'],color='b',label='Tra rc rough')
#plt.plot(np.asarray(df_F_eic1_unpol_rc['qT_Q']),df_F_eic1_unpol_rc['xs'],color='r',label='Fac rc rough')

plt.plot(np.asarray(df_T_eic1_unpol['qt_to_Q']),df_T_eic1_unpol['unpol_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_EIC_1_unpol_rc['qT_Q']),df_F_EIC_1_unpol_rc['xs'],color='r',label='Factorized rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/unpol_rc_eic1.pdf')

# %%
plt.figure()
F_Born_eic1 = np.asarray(df_F_EIC_1_unpol_bn['xs'])
T_Born_eic1 = np.asarray(df_T_eic1_unpol['unpol_bn'])
R_Born_eic1 = F_Born_eic1/T_Born_eic1
plt.plot(np.asarray(df_F_EIC_1_unpol_bn['qT_Q'])*0.5*3,R_Born_eic1,color='b')
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$R_{Born}$',fontsize=16)
plt.ylim(0.94,1.06)
plt.title('including unpol')
plt.savefig('results/compare/Fine/compare_born_unpol_eic1.pdf')


plt.figure()
F_RC_eic1 = np.asarray(df_F_EIC_1_unpol_rc['xs'])
T_RC_eic1 = np.asarray(df_T_eic1_unpol['unpol_rc'])
RC_F = (F_Born_eic1/F_RC_eic1)
RC_T = (T_Born_eic1/T_RC_eic1)
plt.plot(np.asarray(df_F_EIC_1_unpol_rc['qT_Q'])*0.5*3,RC_F/RC_T,label='$RC_F/RC_T')
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
plt.ylim(1,1.1)
plt.xlim(0,1.2)
#plt.title('including unpol')
plt.savefig('results/compare/Fine/compare_RC_unpol_Pt_eic1.pdf')


fig1 = plt.figure()
ax1 = fig1.add_subplot()
fig2 = plt.figure()
ax2 = fig2.add_subplot()
F_bnerr_eic1 = np.asarray(df_F_EIC_1_unpol_bn['xs_err'])
T_bnerr_eic1 = np.asarray(df_T_eic1_unpol['unpol_bn_err'])
F_RCerr_eic1 = np.asarray(df_F_EIC_1_unpol_rc['xs_err'])
T_RCerr_eic1 = np.asarray(df_T_eic1_unpol['unpol_rc_err'])
RC_Fs,RCerr_Fs=Get_error(F_Born_eic1,F_bnerr_eic1,F_RC_eic1,F_RCerr_eic1)
RC_Ts,RCerr_Ts=Get_error(T_Born_eic1,T_bnerr_eic1,T_RC_eic1,T_RCerr_eic1)
RC_ratios,RC_ratioerrs=Get_error(RC_Fs,RCerr_Fs,RC_Ts,RCerr_Ts)

plt.figure()
plt.plot(np.asarray(df_F_EIC_1_unpol_rc['qT_Q'].to_list())*0.5*3,RC_Fs,color='red',label='Factorized')
plt.plot(np.asarray(df_F_EIC_1_unpol_rc['qT_Q'].to_list())*0.5*3,RC_Ts,color='blue',label='Traditional')
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel(r'$\textbf{RC}$',fontsize=16)
plt.legend()
plt.xlim(0,1.2)
plt.savefig('results/compare/Fine/RCs_both_eic1_Pt.pdf')

#ax1.fill_between(np.asarray(df_F_EIC_1_unpol_rc['qT_Q'].to_list()),np.asarray(RC_Fs)-np.asarray(RCerr_Fs),np.asarray(RC_Fs)+np.asarray(RCerr_Fs),color='red',alpha=0.25,linewidth=0)
#ax1.fill_between(np.asarray(df_F_EIC_1_unpol_rc['qT_Q'].to_list()),np.asarray(RC_Ts)-np.asarray(RCerr_Ts),np.asarray(RC_Ts)+np.asarray(RCerr_Ts),color='blue',alpha=0.25,linewidth=0)
ax1.plot(np.asarray(df_F_EIC_1_unpol_rc['qT_Q'].to_list()),RC_Fs,color='red',label='Factorized')
ax1.plot(np.asarray(df_F_EIC_1_unpol_rc['qT_Q'].to_list()),RC_Ts,color='blue',label='Traditional')
ax1.set_xlabel('$qT/Q$',fontsize=16)
ax1.set_ylabel('RC',fontsize=16)
ax1.legend()
fig1.savefig('results/compare/Fine/RCs_both_eic1.pdf')
ax2.fill_between(np.asarray(df_F_EIC_1_unpol_rc['qT_Q'].to_list()),np.asarray(RC_ratios)-np.asarray(RC_ratioerrs),np.asarray(RC_ratios)+np.asarray(RC_ratioerrs),color='black',alpha=0.25,linewidth=0)
ax2.plot(np.asarray(df_F_EIC_1_unpol_rc['qT_Q'].to_list()),RC_ratios,color='black')
ax2.set_xlabel('$qT/Q$',fontsize=16)
ax2.set_ylabel('$RC_F/RC_T$',fontsize=16)
fig2.savefig('results/compare/Fine/compare_RC_unpol_eic1.pdf')
plt.figure()
plt.plot(np.asarray(df_F_EIC_1_unpol_rc['qT_Q'].to_list()),(np.asarray(RC_Fs)-np.asarray(RC_Ts))/(np.asarray(RC_Ts)-np.asarray(1)),color = 'black')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel(r'$\frac{RC_F-RC_T}{RC_T}$',fontsize=16)
plt.ylim(0,0.5)
plt.xlim(0,0.8)
plt.savefig('results/compare/Fine/compare_RC_with1_unpol_eic1.pdf')

plt.figure()
F_Born_eic1 = np.asarray(df_F_EIC_1_unpol_bn['xs'])+np.asarray(df_F_EIC_1_siv_bn['xs'])+np.asarray(df_F_EIC_1_col_bn['xs'])
T_Born_eic1 = np.asarray(df_T_eic1_unpol['unpol_bn'])+np.asarray(df_T_eic1_unpol['sivers_bn'])+np.asarray(df_T_eic1_unpol['collins_bn'])
R_Born_eic1 = F_Born_eic1/T_Born_eic1
plt.plot(np.asarray(df_F_EIC_1_unpol_bn['qT_Q']),R_Born_eic1,color='b')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$R_{Born}$',fontsize=16)
plt.ylim(0.94,1.06)
plt.title('including both unpol and pol')
plt.savefig('results/compare/Fine/compare_born_both_eic1.pdf')



plt.figure()
F_RC_eic1 = np.asarray(df_F_EIC_1_unpol_rc['xs'])+np.asarray(df_F_EIC_1_siv_rc['xs'])+np.asarray(df_F_EIC_1_col_rc['xs'])
T_RC_eic1 = np.asarray(df_T_eic1_unpol['unpol_rc'])+np.asarray(df_T_eic1_siv['sivers_rc'])+np.asarray(df_T_eic1_col['collins_rc'])
RC_F = (F_Born_eic1/F_RC_eic1)
RC_T = (T_Born_eic1/T_RC_eic1)
plt.plot(np.asarray(df_F_EIC_1_unpol_rc['qT_Q']),RC_F/RC_T,label='$RC_F/RC_T')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
#plt.ylim(0.9,1.2)
plt.title('including both unpol and pol')
plt.savefig('results/compare/Fine/compare_RC_both_eic1.pdf')

# %%
T_bn_qtQ_eic1 = df_T_eic1_siv['qt_to_Q'].to_list()
T_bn_siv_eic1 = df_T_eic1_siv['sivers_bn'].to_list()
F_bn_qtQ_EIC_1 = df_F_EIC_1_siv_bn['qT_Q'].to_list()
F_bn_siv_EIC_1 = df_F_EIC_1_siv_bn['xs'].to_list()
T_rc_qtQ_eic1 = df_T_eic1_siv['qt_to_Q'].to_list()
T_rc_siv_eic1 = df_T_eic1_siv['sivers_rc'].to_list()
F_rc_qtQ_EIC_1 = df_F_EIC_1_siv_rc['qT_Q'].to_list()
F_rc_siv_EIC_1 = df_F_EIC_1_siv_rc['xs'].to_list()
RC_F_siv_eic1 = np.asarray(F_bn_siv_EIC_1)/np.asarray(F_rc_siv_EIC_1)
RC_T_siv_eic1 = np.asarray(T_bn_siv_eic1)/np.asarray(T_rc_siv_eic1)
plt.plot(T_bn_qtQ_eic1,RC_T_siv_eic1,color='r',label='Traditional RC')
plt.plot(F_bn_qtQ_EIC_1,RC_F_siv_eic1,color='b',label='Factorized RC')
plt.xlabel('qT/Q',fontsize =16)
plt.ylabel('RC from siv',fontsize =16)
plt.legend()
plt.savefig('results/compare/Fine/RCs_siv_both_eic1.pdf')

plt.figure()
T_bn_qtQ_eic1 = df_T_eic1_col['qt_to_Q'].to_list()
T_bn_col_eic1 = df_T_eic1_col['collins_bn'].to_list()
F_bn_qtQ_EIC_1 = df_F_EIC_1_col_bn['qT_Q'].to_list()
F_bn_col_EIC_1 = df_F_EIC_1_col_bn['xs'].to_list()
T_rc_qtQ_eic1 = df_T_eic1_col['qt_to_Q'].to_list()
T_rc_col_eic1 = df_T_eic1_col['collins_rc'].to_list()
F_rc_qtQ_EIC_1 = df_F_EIC_1_col_rc['qT_Q'].to_list()
F_rc_col_EIC_1 = df_F_EIC_1_col_rc['xs'].to_list()
RC_F_col_eic1 = np.asarray(F_bn_col_EIC_1)/np.asarray(F_rc_col_EIC_1)
RC_T_col_eic1 = np.asarray(T_bn_col_eic1)/np.asarray(T_rc_col_eic1)
plt.plot(T_bn_qtQ_eic1,RC_T_col_eic1,color='r',label='Traditional RC')
plt.plot(F_bn_qtQ_EIC_1,RC_F_col_eic1,color='b',label='Factorized RC')
plt.xlabel('qT/Q',fontsize =16)
plt.ylabel('RC from col',fontsize =16)
plt.legend()
plt.savefig('results/compare/Fine/RCs_col_both_eic1.pdf')

plt.figure()
RC_FT_siv = RC_F_siv_eic1/RC_T_siv_eic1
plt.plot(T_bn_qtQ_eic1,RC_FT_siv,label='siv')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
plt.legend()
plt.ylim(0.9,1.2)
plt.savefig('results/compare/Fine/compare_RC_siv_eic1.pdf')
plt.figure()
plt.plot(T_bn_qtQ_eic1,(np.asarray(RC_F_siv_eic1)-np.asarray(RC_T_siv_eic1))/(np.asarray(RC_T_siv_eic1)-np.asarray(1)),color = 'black')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel(r'$\frac{RC_F-RC_T}{RC_T}$ siv',fontsize=16)
plt.ylim(0,0.5)
plt.xlim(0,0.8)
plt.savefig('results/compare/Fine/compare_RC_with1_siv_eic1.pdf')
plt.figure()
RC_FT_col = RC_F_col_eic1/RC_T_col_eic1
plt.plot(T_bn_qtQ_eic1,RC_FT_col,label='col')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
plt.legend()
plt.ylim(0.9,1.2)
plt.savefig('results/compare/Fine/compare_RC_col_eic1.pdf')
plt.figure()
plt.plot(T_bn_qtQ_eic1,(np.asarray(RC_F_col_eic1)-np.asarray(RC_T_col_eic1))/(np.asarray(RC_T_col_eic1)-np.asarray(1)),color = 'black')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel(r'$\frac{RC_F-RC_T}{RC_T}$ col',fontsize=16)
plt.ylim(0,0.5)
plt.xlim(0,0.8)
plt.savefig('results/compare/Fine/compare_RC_with1_col_eic1.pdf')

# %%
#plt.plot(np.asarray(df_T_eic2['qt_to_Q']),df_T_eic2['sivers_bn'],color='b',label='Tra bn rough')
#plt.plot(np.asarray(df_F_eic2_siv_bn['qT_Q']),df_F_eic2_siv_bn['xs'],color='r',label='Fac bn rough')
#print(df_F_EIC_2_siv_bn['qT_Q'])
plt.plot(np.asarray(df_T_eic2_siv['qt_to_Q']),df_T_eic2_siv['sivers_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_EIC_2_siv_bn['qT_Q']),df_F_EIC_2_siv_bn['xs'],color='r',linestyle='-',label='Factorized bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_bn_eic2.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic2['qt_to_Q']),df_T_eic2['sivers_rc'],color='b',label='Tra rc rough')
#plt.plot(np.asarray(df_F_eic2_siv_rc['qT_Q']),df_F_eic2_siv_rc['xs'],color='r',label='Fac rc rough')

plt.plot(np.asarray(df_T_eic2_siv['qt_to_Q']),df_T_eic2_siv['sivers_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_EIC_2_siv_rc['qT_Q']),df_F_EIC_2_siv_rc['xs'],color='r',label='Factorized rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_rc_eic2.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic2['qt_to_Q']),df_T_eic2['collins_bn'],color='b',label='Tra bn rough')
#plt.plot(np.asarray(df_F_eic2_col_bn['qT_Q']),df_F_eic2_col_bn['xs'],color='r',label='Fac bn rough')

plt.plot(np.asarray(df_T_eic2_col['qt_to_Q']),df_T_eic2_col['collins_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_EIC_2_col_bn['qT_Q']),df_F_EIC_2_col_bn['xs'],color='r',label='Factorized bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_bn_eic2.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic2['qt_to_Q']),df_T_eic2['collins_rc'],color='b',label='Tra rc rough')
#plt.plot(np.asarray(df_F_eic2_col_rc['qT_Q']),df_F_eic2_col_rc['xs'],color='r',label='Fac rc rough')

plt.plot(np.asarray(df_T_eic2_col['qt_to_Q']),df_T_eic2_col['collins_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_EIC_2_col_rc['qT_Q']),df_F_EIC_2_col_rc['xs'],color='r',label='Factorized rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_rc_eic2.pdf')

# %%
#plt.plot(np.asarray(df_T_eic2['qt_to_Q']),df_T_eic2['sivers_bn'],color='b',label='Tra bn rough')
#plt.plot(np.asarray(df_F_eic2_siv_bn['qT_Q']),df_F_eic2_siv_bn['xs'],color='r',label='Fac bn rough')
#print(df_F_EIC_2_siv_bn['qT_Q'])
plt.plot(np.asarray(df_T_eic2_siv['qt_to_Q'])*10*0.5,df_T_eic2_siv['sivers_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_EIC_2_siv_bn['qT_Q'])*10*0.5,df_F_EIC_2_siv_bn['xs'],color='r',linestyle='-',label='Factorized bn')
plt.xlim(0,0.9)
plt.legend()
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_bn_eic2_pT.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic2['qt_to_Q']),df_T_eic2['sivers_rc'],color='b',label='Tra rc rough')
#plt.plot(np.asarray(df_F_eic2_siv_rc['qT_Q']),df_F_eic2_siv_rc['xs'],color='r',label='Fac rc rough')

plt.plot(np.asarray(df_T_eic2_siv['qt_to_Q'])*10*0.5,df_T_eic2_siv['sivers_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_EIC_2_siv_rc['qT_Q'])*10*0.5,df_F_EIC_2_siv_rc['xs'],color='r',label='Factorized rc')
plt.xlim(0,0.9)
plt.legend()
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_rc_eic2_pT.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic2['qt_to_Q']),df_T_eic2['collins_bn'],color='b',label='Tra bn rough')
#plt.plot(np.asarray(df_F_eic2_col_bn['qT_Q']),df_F_eic2_col_bn['xs'],color='r',label='Fac bn rough')

plt.plot(np.asarray(df_T_eic2_col['qt_to_Q'])*10*0.5,df_T_eic2_col['collins_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_EIC_2_col_bn['qT_Q'])*10*0.5,df_F_EIC_2_col_bn['xs'],color='r',label='Factorized bn')
plt.xlim(0,0.9)
plt.legend()
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_bn_eic2_pT.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic2['qt_to_Q']),df_T_eic2['collins_rc'],color='b',label='Tra rc rough')
#plt.plot(np.asarray(df_F_eic2_col_rc['qT_Q']),df_F_eic2_col_rc['xs'],color='r',label='Fac rc rough')

plt.plot(np.asarray(df_T_eic2_col['qt_to_Q'])*10*0.5,df_T_eic2_col['collins_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_EIC_2_col_rc['qT_Q'])*10*0.5,df_F_EIC_2_col_rc['xs'],color='r',label='Factorized rc')
plt.xlim(0,0.9)
plt.legend()
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_rc_eic2_pT.pdf')

# %%
#plt.plot(np.asarray(df_T_eic2['qt_to_Q']),df_T_eic2['unpol_bn'],color='b',label='Tra bn rough')
#plt.plot(np.asarray(df_F_eic2_unpol_bn['qT_Q']),df_F_eic2_unpol_bn['xs'],color='r',label='Fac bn rough')

plt.plot(np.asarray(df_T_eic2_unpol['qt_to_Q']),df_T_eic2_unpol['unpol_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_EIC_2_unpol_bn['qT_Q']),df_F_EIC_2_unpol_bn['xs'],color='r',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/unpol_bn_eic2.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic2['qt_to_Q']),df_T_eic2['unpol_rc'],color='b',label='Tra rc rough')
#plt.plot(np.asarray(df_F_eic2_unpol_rc['qT_Q']),df_F_eic2_unpol_rc['xs'],color='r',label='Fac rc rough')

plt.plot(np.asarray(df_T_eic2_unpol['qt_to_Q']),df_T_eic2_unpol['unpol_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_EIC_2_unpol_rc['qT_Q']),df_F_EIC_2_unpol_rc['xs'],color='r',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/unpol_rc_eic2.pdf')

# %%
#print(df_F_EIC_2_unpol_bn['qT_Q'])
#print(df_F_EIC_2_siv_bn['qT_Q'])
#print(df_F_EIC_2_col_bn['qT_Q'])
plt.figure()
F_Born_eic2 = np.asarray(df_F_EIC_2_unpol_bn['xs'])[:81]
T_Born_eic2 = np.asarray(df_T_eic2_unpol['unpol_bn'])[:81]
R_Born_eic2 = F_Born_eic2/T_Born_eic2[:81]
plt.plot(np.asarray(df_F_EIC_2_unpol_bn['qT_Q'])*0.5*10,R_Born_eic2,color='b')
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$R_{Born}$',fontsize=16)
#plt.ylim(0.94,1.06)
plt.title('including unpol')
plt.savefig('results/compare/Fine/compare_born_unpol_eic2.pdf')


#print(df_F_EIC_2_unpol_rc['qT_Q'])
#print(df_F_EIC_2_siv_rc['qT_Q'])
#print(df_F_EIC_2_col_rc['qT_Q'])
plt.figure()
F_RC_eic2 = np.asarray(df_F_EIC_2_unpol_rc['xs'])[:81]
T_RC_eic2 = np.asarray(df_T_eic2_unpol['unpol_rc'])[:81]
RC_F = F_Born_eic2/F_RC_eic2[:81]
RC_T = (T_Born_eic2/T_RC_eic2)[:81]
plt.plot(np.asarray(df_F_EIC_2_unpol_bn['qT_Q'])*0.5*10,RC_F/RC_T,label='$RC_F/RC_T',color='b')
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
plt.ylim(1,1.1)
plt.xlim(0,1)
#plt.title('including unpol')
plt.savefig('results/compare/Fine/compare_RC_unpol_Pt_eic2.pdf')

fig1 = plt.figure()
ax1 = fig1.add_subplot()
fig2 = plt.figure()
ax2 = fig2.add_subplot()
F_bnerr_eic2 = np.asarray(df_F_EIC_2_unpol_bn['xs_err'])[:81]
T_bnerr_eic2 = np.asarray(df_T_eic2_unpol['unpol_bn_err'])[:81]
F_RCerr_eic2 = np.asarray(df_F_EIC_2_unpol_rc['xs_err'])[:81]
T_RCerr_eic2 = np.asarray(df_T_eic2_unpol['unpol_rc_err'])[:81]
RC_Fs,RCerr_Fs=Get_error(F_Born_eic2,F_bnerr_eic2,F_RC_eic2,F_RCerr_eic2)
RC_Ts,RCerr_Ts=Get_error(T_Born_eic2,T_bnerr_eic2,T_RC_eic2,T_RCerr_eic2)
RC_ratios,RC_ratioerrs=Get_error(RC_Fs,RCerr_Fs,RC_Ts,RCerr_Ts)

plt.figure()
plt.plot(np.asarray(df_F_EIC_2_unpol_bn['qT_Q'].to_list())*0.5*10,RC_Fs,color='red',label='Factorized')
plt.plot(np.asarray(df_F_EIC_2_unpol_bn['qT_Q'].to_list())*0.5*10,RC_Ts,color='blue',label='Traditional')
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel(r'$\textbf{RC}$',fontsize=16)
plt.legend()
#plt.ylim(1,1.1)
plt.xlim(0,1)
plt.savefig('results/compare/Fine/RCs_both_eic2_Pt.pdf')

ax1.fill_between(np.asarray(df_F_EIC_2_unpol_bn['qT_Q'].to_list()),np.asarray(RC_Fs)-np.asarray(RCerr_Fs),np.asarray(RC_Fs)+np.asarray(RCerr_Fs),color='red',alpha=0.25,linewidth=0)
ax1.fill_between(np.asarray(df_F_EIC_2_unpol_bn['qT_Q'].to_list()),np.asarray(RC_Ts)-np.asarray(RCerr_Ts),np.asarray(RC_Ts)+np.asarray(RCerr_Ts),color='blue',alpha=0.25,linewidth=0)
ax1.plot(np.asarray(df_F_EIC_2_unpol_bn['qT_Q'].to_list()),RC_Fs,color='red',label='Factorized')
ax1.plot(np.asarray(df_F_EIC_2_unpol_bn['qT_Q'].to_list()),RC_Ts,color='blue',label='Traditional')
ax1.set_xlabel('$qT/Q$',fontsize=16)
ax1.set_ylabel('RC',fontsize=16)
ax1.legend()
fig1.savefig('results/compare/Fine/RCs_both_eic2.pdf')
ax2.fill_between(np.asarray(df_F_EIC_2_unpol_bn['qT_Q'].to_list()),np.asarray(RC_ratios)-np.asarray(RC_ratioerrs),np.asarray(RC_ratios)+np.asarray(RC_ratioerrs),color='black',alpha=0.25,linewidth=0)
ax2.plot(np.asarray(df_F_EIC_2_unpol_bn['qT_Q'].to_list()),RC_ratios,color='black')
ax2.set_xlabel('$qT/Q$',fontsize=16)
ax2.set_ylabel('$RC_F/RC_T$',fontsize=16)
fig2.savefig('results/compare/Fine/compare_RC_unpol_eic2.pdf')
plt.figure()
plt.plot(np.asarray(df_F_EIC_2_unpol_bn['qT_Q'].to_list()),(np.asarray(RC_Fs)-np.asarray(RC_Ts))/(np.asarray(RC_Ts)-np.asarray(1)),color = 'black')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel(r'$\frac{RC_F-RC_T}{RC_T}$',fontsize=16)
plt.ylim(0,0.5)
plt.xlim(0,0.8)
plt.savefig('results/compare/Fine/compare_RC_with1_unpol_eic2.pdf')

plt.figure()
F_Born_eic2 = np.asarray(df_F_EIC_2_unpol_bn['xs'])+np.asarray(df_F_EIC_2_siv_bn['xs'])[:81]+np.asarray(df_F_EIC_2_col_bn['xs'])[:81]
T_Born_eic2 = np.asarray(df_T_eic2_unpol['unpol_bn'])+np.asarray(df_T_eic2_unpol['sivers_bn'])+np.asarray(df_T_eic2_unpol['collins_bn'])
R_Born_eic2 = F_Born_eic2/T_Born_eic2[:81]
plt.plot(np.asarray(df_F_EIC_2_unpol_bn['qT_Q']),R_Born_eic2,color='b')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$R_{Born}$',fontsize=16)
#plt.ylim(0.94,1.06)
plt.title('including both')
plt.savefig('results/compare/Fine/compare_born_both_eic2.pdf')


plt.figure()
F_RC_eic2 = np.asarray(df_F_EIC_2_unpol_rc['xs'])+np.asarray(df_F_EIC_2_siv_rc['xs'])+np.asarray(df_F_EIC_2_col_rc['xs'])
T_RC_eic2 = np.asarray(df_T_eic2_unpol['unpol_rc'])+np.asarray(df_T_eic2_siv['sivers_rc'])+np.asarray(df_T_eic2_col['collins_rc'])
RC_F = F_Born_eic2/F_RC_eic2[:81]
RC_T = (T_Born_eic2/T_RC_eic2)[:81]
plt.plot(np.asarray(df_F_EIC_2_unpol_bn['qT_Q']),RC_F/RC_T,label='$RC_F/RC_T')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
#plt.ylim(0.9,1.2)
plt.title('including both')
plt.savefig('results/compare/Fine/compare_RC_both_eic2.pdf')

# %%
T_bn_qtQ_eic2 = df_T_eic2_siv['qt_to_Q'].to_list()
T_bn_siv_eic2 = df_T_eic2_siv['sivers_bn'].to_list()
F_bn_qtQ_EIC_2 = df_F_EIC_2_siv_bn['qT_Q'].to_list()
F_bn_siv_EIC_2 = df_F_EIC_2_siv_bn['xs'].to_list()
T_rc_qtQ_eic2 = df_T_eic2_siv['qt_to_Q'].to_list()
T_rc_siv_eic2 = df_T_eic2_siv['sivers_rc'].to_list()
F_rc_qtQ_EIC_2 = df_F_EIC_2_siv_rc['qT_Q'].to_list()
F_rc_siv_EIC_2 = df_F_EIC_2_siv_rc['xs'].to_list()
RC_F_siv_eic2 = np.asarray(F_bn_siv_EIC_2)/np.asarray(F_rc_siv_EIC_2)
RC_T_siv_eic2 = np.asarray(T_bn_siv_eic2)/np.asarray(T_rc_siv_eic2)
plt.plot(T_bn_qtQ_eic2,RC_T_siv_eic2,color='r',label='Traditional RC')
plt.plot(F_bn_qtQ_EIC_2,RC_F_siv_eic2,color='b',label='Factorized RC')
plt.xlabel('qT/Q',fontsize =16)
plt.ylabel('RC from siv',fontsize =16)
plt.legend()
plt.savefig('results/compare/Fine/RCs_siv_both_eic2.pdf')

plt.figure()
T_bn_qtQ_eic2 = df_T_eic2_col['qt_to_Q'].to_list()
T_bn_col_eic2 = df_T_eic2_col['collins_bn'].to_list()
F_bn_qtQ_EIC_2 = df_F_EIC_2_col_bn['qT_Q'].to_list()
F_bn_col_EIC_2 = df_F_EIC_2_col_bn['xs'].to_list()
T_rc_qtQ_eic2 = df_T_eic2_col['qt_to_Q'].to_list()
T_rc_col_eic2 = df_T_eic2_col['collins_rc'].to_list()
F_rc_qtQ_EIC_2 = df_F_EIC_2_col_rc['qT_Q'].to_list()
F_rc_col_EIC_2 = df_F_EIC_2_col_rc['xs'].to_list()
RC_F_col_eic2 = np.asarray(F_bn_col_EIC_2)/np.asarray(F_rc_col_EIC_2)
RC_T_col_eic2 = np.asarray(T_bn_col_eic2)/np.asarray(T_rc_col_eic2)
plt.plot(T_bn_qtQ_eic2,RC_T_col_eic2,color='r',label='Traditional RC')
plt.plot(F_bn_qtQ_EIC_2,RC_F_col_eic2,color='b',label='Factorized RC')
plt.xlabel('qT/Q',fontsize =16)
plt.ylabel('RC from col',fontsize =16)
plt.legend()
plt.savefig('results/compare/Fine/RCs_col_both_eic2.pdf')

plt.figure()
RC_FT_siv = RC_F_siv_eic2/RC_T_siv_eic2
plt.plot(T_bn_qtQ_eic2,RC_FT_siv,label='siv')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
plt.legend()
plt.ylim(0.9,1.2)
plt.savefig('results/compare/Fine/compare_RC_siv_eic2.pdf')
plt.figure()
plt.plot(T_bn_qtQ_eic2,(np.asarray(RC_F_siv_eic2)-np.asarray(RC_T_siv_eic2))/(np.asarray(RC_T_siv_eic2)-np.asarray(1)),color = 'black')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel(r'$\frac{RC_F-RC_T}{RC_T}$ siv',fontsize=16)
plt.ylim(0,0.5)
plt.xlim(0,0.8)
plt.savefig('results/compare/Fine/compare_RC_with1_siv_eic2.pdf')
plt.figure()
RC_FT_col = RC_F_col_eic2/RC_T_col_eic2
plt.plot(T_bn_qtQ_eic2,RC_FT_col,label='col')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
plt.legend()
plt.ylim(0.9,1.2)
plt.savefig('results/compare/Fine/compare_RC_col_eic2.pdf')
plt.figure()
plt.plot(T_bn_qtQ_eic2,(np.asarray(RC_F_col_eic2)-np.asarray(RC_T_col_eic2))/(np.asarray(RC_T_col_eic2)-np.asarray(1)),color = 'black')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel(r'$\frac{RC_F-RC_T}{RC_T}$ col',fontsize=16)
plt.ylim(0,0.5)
plt.xlim(0,0.8)
plt.savefig('results/compare/Fine/compare_RC_with1_col_eic2.pdf')

# %%
#plt.plot(np.asarray(df_T_eic3['qt_to_Q']),df_T_eic3['sivers_bn'],color='b',label='Tra bn rough')
#plt.plot(np.asarray(df_F_eic3_siv_bn['qT_Q']),df_F_eic3_siv_bn['xs'],color='r',label='Fac bn rough')

plt.plot(np.asarray(df_T_eic3_siv['qt_to_Q']),df_T_eic3_siv['sivers_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_EIC_3_siv_bn['qT_Q']),df_F_EIC_3_siv_bn['xs'],color='r',label='Factorized bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_bn_eic3.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic3['qt_to_Q']),df_T_eic3['sivers_rc'],color='b',label='Tra rc rough')
#plt.plot(np.asarray(df_F_eic3_siv_rc['qT_Q']),df_F_eic3_siv_rc['xs'],color='r',label='Fac rc rough')

plt.plot(np.asarray(df_T_eic3_siv['qt_to_Q']),df_T_eic3_siv['sivers_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_EIC_3_siv_rc['qT_Q']),df_F_EIC_3_siv_rc['xs'],color='r',label='Factorized rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_rc_eic3.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic3['qt_to_Q']),df_T_eic3['collins_bn'],color='b',linestyle='-.',label='Tra bn rough')
#plt.plot(np.asarray(df_F_eic3_col_bn['qT_Q']),df_F_eic3_col_bn['xs'],color='r',linestyle='-.',label='Fac bn rough')

plt.plot(np.asarray(df_T_eic3_col['qt_to_Q']),df_T_eic3_col['collins_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_EIC_3_col_bn['qT_Q']),df_F_EIC_3_col_bn['xs'],color='r',label='Factorized bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_bn_eic3.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic3['qt_to_Q']),df_T_eic3['collins_rc'],color='b',linestyle='-.',label='Tra rc rough')
#plt.plot(np.asarray(df_F_eic3_col_rc['qT_Q']),df_F_eic3_col_rc['xs'],color='r',linestyle='-.',label='Fac rc rough')

plt.plot(np.asarray(df_T_eic3_col['qt_to_Q']),df_T_eic3_col['collins_rc'],color='b',label='Traditional rc just col')
#plt.plot(np.asarray(df_T_eic3_unpol['qt_to_Q']),df_T_eic3_unpol['collins_rc'],color='b',linestyle=':',label='Traditional rc col including leakage')
plt.plot(np.asarray(df_F_EIC_3_col_rc['qT_Q']),df_F_EIC_3_col_rc['xs'],color='r',label='Factorized rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_rc_eic3.pdf')

# %%
#plt.plot(np.asarray(df_T_eic3['qt_to_Q']),df_T_eic3['sivers_bn'],color='b',label='Tra bn rough')
#plt.plot(np.asarray(df_F_eic3_siv_bn['qT_Q']),df_F_eic3_siv_bn['xs'],color='r',label='Fac bn rough')

plt.plot(np.asarray(df_T_eic3_siv['qt_to_Q'])*0.5*5,df_T_eic3_siv['sivers_bn'],color='b',label='Traditional')
plt.plot(np.asarray(df_F_EIC_3_siv_bn['qT_Q'])*0.5*5,df_F_EIC_3_siv_bn['xs'],color='r',label='Factorized')
plt.xlim(0,1.6)
plt.legend()
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_bn_eic3_Pt.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic3['qt_to_Q']),df_T_eic3['sivers_rc'],color='b',label='Tra rc rough')
#plt.plot(np.asarray(df_F_eic3_siv_rc['qT_Q']),df_F_eic3_siv_rc['xs'],color='r',label='Fac rc rough')

plt.plot(np.asarray(df_T_eic3_siv['qt_to_Q'])*0.5*5,df_T_eic3_siv['sivers_rc'],color='b',label='Traditional')
plt.plot(np.asarray(df_F_EIC_3_siv_rc['qT_Q'])*0.5*5,df_F_EIC_3_siv_rc['xs'],color='r',label='Factorized')
plt.xlim(0,1.6)
plt.legend()
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_rc_eic3_Pt.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic3['qt_to_Q']),df_T_eic3['collins_bn'],color='b',linestyle='-.',label='Tra bn rough')
#plt.plot(np.asarray(df_F_eic3_col_bn['qT_Q']),df_F_eic3_col_bn['xs'],color='r',linestyle='-.',label='Fac bn rough')

plt.plot(np.asarray(df_T_eic3_col['qt_to_Q'])*0.5*5,df_T_eic3_col['collins_bn'],color='b',label='Traditional')
plt.plot(np.asarray(df_F_EIC_3_col_bn['qT_Q'])*0.5*5,df_F_EIC_3_col_bn['xs'],color='r',label='Factorized')
plt.xlim(0,1.6)
plt.legend()
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_bn_eic3_Pt.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic3['qt_to_Q']),df_T_eic3['collins_rc'],color='b',linestyle='-.',label='Tra rc rough')
#plt.plot(np.asarray(df_F_eic3_col_rc['qT_Q']),df_F_eic3_col_rc['xs'],color='r',linestyle='-.',label='Fac rc rough')

plt.plot(np.asarray(df_T_eic3_col['qt_to_Q'])*0.5*5,df_T_eic3_col['collins_rc'],color='b',label='Traditional')
#plt.plot(np.asarray(df_T_eic3_unpol['qt_to_Q']),df_T_eic3_unpol['collins_rc'],color='b',linestyle=':',label='Traditional rc col including leakage')
plt.plot(np.asarray(df_F_EIC_3_col_rc['qT_Q'])*0.5*5,df_F_EIC_3_col_rc['xs'],color='r',label='Factorized')
plt.xlim(0,1.6)
plt.legend()
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_rc_eic3_Pt.pdf')

# %%
#plt.plot(np.asarray(df_T_eic3['qt_to_Q']),df_T_eic3['unpol_bn'],color='b',label='Tra bn rough')
#plt.plot(np.asarray(df_F_eic3_unpol_bn['qT_Q']),df_F_eic3_unpol_bn['xs'],color='r',label='Fac bn rough')

plt.plot(np.asarray(df_T_eic3_unpol['qt_to_Q']),df_T_eic3_unpol['unpol_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_EIC_3_unpol_bn['qT_Q']),df_F_EIC_3_unpol_bn['xs'],color='r',label='Factorized bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/unpol_bn_eic3.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic3['qt_to_Q']),df_T_eic3['unpol_rc'],color='b',label='Tra rc rough')
#plt.plot(np.asarray(df_F_eic3_unpol_rc['qT_Q']),df_F_eic3_unpol_rc['xs'],color='r',label='Fac rc rough')

plt.plot(np.asarray(df_T_eic3_unpol['qt_to_Q']),df_T_eic3_unpol['unpol_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_EIC_3_unpol_rc['qT_Q']),df_F_EIC_3_unpol_rc['xs'],color='r',label='Factorized rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/unpol_rc_eic3.pdf')

# %%
plt.figure()
F_Born_eic3 = np.asarray(df_F_EIC_3_unpol_bn['xs'])
T_Born_eic3 = np.asarray(df_T_eic3_unpol['unpol_bn'])
R_Born_eic3 = F_Born_eic3/T_Born_eic3
plt.plot(np.asarray(df_F_EIC_3_unpol_bn['qT_Q'])*0.5*5,R_Born_eic3,color='b')
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$R_{Born}$',fontsize=16)
plt.xlim(0,1.8)
#plt.ylim(0.94,1.06)
#plt.title('including unpol')
plt.tick_params(direction='in',width=2)
plt.savefig('results/compare/Fine/compare_born_unpol_Pt_eic3.pdf')

plt.figure()
F_RC_eic3 = np.asarray(df_F_EIC_3_unpol_rc['xs'])
T_RC_eic3 = np.asarray(df_T_eic3_unpol['unpol_rc'])
RC_F = F_Born_eic3/F_RC_eic3
RC_T = (T_Born_eic3/T_RC_eic3)
plt.plot(np.asarray(df_F_EIC_3_unpol_rc['qT_Q'])*0.5*5,RC_F/RC_T,label='$RC_F/RC_T')
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
plt.ylim(1,1.2)
plt.xlim(0,1)
#plt.title('including unpol')
plt.savefig('results/compare/Fine/compare_RC_unpol_Pt_eic3.pdf')

fig1 = plt.figure()
ax1 = fig1.add_subplot()
fig2 = plt.figure()
ax2 = fig2.add_subplot()
F_bnerr_eic3 = np.asarray(df_F_EIC_3_unpol_bn['xs_err'])
T_bnerr_eic3 = np.asarray(df_T_eic3_unpol['unpol_bn_err'])
F_RCerr_eic3 = np.asarray(df_F_EIC_3_unpol_rc['xs_err'])
T_RCerr_eic3 = np.asarray(df_T_eic3_unpol['unpol_rc_err'])
RC_Fs,RCerr_Fs=Get_error(F_Born_eic3,F_bnerr_eic3,F_RC_eic3,F_RCerr_eic3)
RC_Ts,RCerr_Ts=Get_error(T_Born_eic3,T_bnerr_eic3,T_RC_eic3,T_RCerr_eic3)
RC_ratios,RC_ratioerrs=Get_error(RC_Fs,RCerr_Fs,RC_Ts,RCerr_Ts)

plt.figure()
plt.plot(np.asarray(df_F_EIC_3_unpol_bn['qT_Q'].to_list())*0.5*5,RC_Fs,color='red',label='Factorized')
plt.plot(np.asarray(df_F_EIC_3_unpol_bn['qT_Q'].to_list())*0.5*5,RC_Ts,color='blue',label='Traditional')
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel(r'$\textbf{RC}$',fontsize=16)
plt.legend()

plt.xlim(0,1)
plt.savefig('results/compare/Fine/RCs_both_eic3_Pt.pdf')

ax1.fill_between(np.asarray(df_F_EIC_3_unpol_bn['qT_Q'].to_list()),np.asarray(RC_Fs)-np.asarray(RCerr_Fs),np.asarray(RC_Fs)+np.asarray(RCerr_Fs),color='red',alpha=0.25,linewidth=0)
ax1.fill_between(np.asarray(df_F_EIC_3_unpol_bn['qT_Q'].to_list()),np.asarray(RC_Ts)-np.asarray(RCerr_Ts),np.asarray(RC_Ts)+np.asarray(RCerr_Ts),color='blue',alpha=0.25,linewidth=0)
ax1.plot(np.asarray(df_F_EIC_3_unpol_bn['qT_Q'].to_list()),RC_Fs,color='red',label='Factorized')
ax1.plot(np.asarray(df_F_EIC_3_unpol_bn['qT_Q'].to_list()),RC_Ts,color='blue',label='Traditional')
ax1.set_xlabel('$qT/Q$',fontsize=16)
ax1.set_ylabel('RC',fontsize=16)
ax1.legend()
fig1.savefig('results/compare/Fine/RCs_both_eic3.pdf')
ax2.fill_between(np.asarray(df_F_EIC_3_unpol_bn['qT_Q'].to_list()),np.asarray(RC_ratios)-np.asarray(RC_ratioerrs),np.asarray(RC_ratios)+np.asarray(RC_ratioerrs),color='black',alpha=0.25,linewidth=0)
ax2.plot(np.asarray(df_F_EIC_3_unpol_bn['qT_Q'].to_list()),RC_ratios,color='black')
ax2.set_xlabel('$qT/Q$',fontsize=16)
ax2.set_ylabel('$RC_F/RC_T$',fontsize=16)
fig2.savefig('results/compare/Fine/compare_RC_unpol_eic3.pdf')
plt.figure()
plt.plot(np.asarray(df_F_EIC_3_unpol_rc['qT_Q'].to_list()),(np.asarray(RC_Fs)-np.asarray(RC_Ts))/(np.asarray(RC_Ts)-np.asarray(1)),color = 'black')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel(r'$\frac{RC_F-RC_T}{RC_T}$',fontsize=16)
plt.ylim(0,0.5)
plt.xlim(0,0.8)
plt.savefig('results/compare/Fine/compare_RC_with1_unpol_eic3.pdf')

plt.figure()
F_Born_eic3 = np.asarray(df_F_EIC_3_unpol_bn['xs'])+np.asarray(df_F_EIC_3_siv_bn['xs'])+np.asarray(df_F_EIC_3_col_bn['xs'])
T_Born_eic3 = np.asarray(df_T_eic3_unpol['unpol_bn'])+np.asarray(df_T_eic3_unpol['sivers_bn'])+np.asarray(df_T_eic3_unpol['collins_bn'])
R_Born_eic3 = F_Born_eic3/T_Born_eic3
plt.plot(np.asarray(df_F_EIC_3_unpol_bn['qT_Q']),R_Born_eic3,color='b')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$R_{Born}$',fontsize=16)
#plt.ylim(0.94,1.06)
#plt.title('including both')
plt.savefig('results/compare/Fine/compare_born_both_eic3.pdf')


plt.figure()
F_RC_eic3 = np.asarray(df_F_EIC_3_unpol_rc['xs'])+np.asarray(df_F_EIC_3_siv_rc['xs'])+np.asarray(df_F_EIC_3_col_rc['xs'])
T_RC_eic3 = np.asarray(df_T_eic3_unpol['unpol_rc'])+np.asarray(df_T_eic3_siv['sivers_rc'])+np.asarray(df_T_eic3_col['collins_rc'])
RC_F = F_Born_eic3/F_RC_eic3
RC_T = (T_Born_eic3/T_RC_eic3)
plt.plot(np.asarray(df_F_EIC_3_unpol_rc['qT_Q']),RC_F/RC_T,label='$RC_F/RC_T')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
#plt.ylim(0.9,1.2)
#plt.title('including both')
plt.savefig('results/compare/Fine/compare_RC_both_eic3.pdf')

# %%
T_bn_qtQ_eic3 = df_T_eic3_siv['qt_to_Q'].to_list()
T_bn_siv_eic3 = df_T_eic3_siv['sivers_bn'].to_list()
F_bn_qtQ_EIC_3 = df_F_EIC_3_siv_bn['qT_Q'].to_list()
F_bn_siv_EIC_3 = df_F_EIC_3_siv_bn['xs'].to_list()
T_rc_qtQ_eic3 = df_T_eic3_siv['qt_to_Q'].to_list()
T_rc_siv_eic3 = df_T_eic3_siv['sivers_rc'].to_list()
F_rc_qtQ_EIC_3 = df_F_EIC_3_siv_rc['qT_Q'].to_list()
F_rc_siv_EIC_3 = df_F_EIC_3_siv_rc['xs'].to_list()
RC_F_siv_eic3 = np.asarray(F_bn_siv_EIC_3)/np.asarray(F_rc_siv_EIC_3)
RC_T_siv_eic3 = np.asarray(T_bn_siv_eic3)/np.asarray(T_rc_siv_eic3)
plt.plot(T_bn_qtQ_eic3,RC_T_siv_eic3,color='r',label='Traditional RC')
plt.plot(F_bn_qtQ_EIC_3,RC_F_siv_eic3,color='b',label='Factorized RC')
plt.xlabel('qT/Q',fontsize =16)
plt.ylabel('RC from siv',fontsize =16)
plt.legend()
plt.savefig('results/compare/Fine/RCs_siv_both_eic3.pdf')

plt.figure()
T_bn_qtQ_eic3 = df_T_eic3_col['qt_to_Q'].to_list()
T_bn_col_eic3 = df_T_eic3_col['collins_bn'].to_list()
F_bn_qtQ_EIC_3 = df_F_EIC_3_col_bn['qT_Q'].to_list()
F_bn_col_EIC_3 = df_F_EIC_3_col_bn['xs'].to_list()
T_rc_qtQ_eic3 = df_T_eic3_col['qt_to_Q'].to_list()
T_rc_col_eic3 = df_T_eic3_col['collins_rc'].to_list()
F_rc_qtQ_EIC_3 = df_F_EIC_3_col_rc['qT_Q'].to_list()
F_rc_col_EIC_3 = df_F_EIC_3_col_rc['xs'].to_list()
RC_F_col_eic3 = np.asarray(F_bn_col_EIC_3)/np.asarray(F_rc_col_EIC_3)
RC_T_col_eic3 = np.asarray(T_bn_col_eic3)/np.asarray(T_rc_col_eic3)
plt.plot(T_bn_qtQ_eic3,RC_T_col_eic3,color='r',label='Traditional RC')
plt.plot(F_bn_qtQ_EIC_3,RC_F_col_eic3,color='b',label='Factorized RC')
plt.xlabel('qT/Q',fontsize =16)
plt.ylabel('RC from col',fontsize =16)
plt.legend()
plt.savefig('results/compare/Fine/RCs_col_both_eic3.pdf')

plt.figure()
RC_FT_siv = RC_F_siv_eic3/RC_T_siv_eic3
plt.plot(T_bn_qtQ_eic3,RC_FT_siv,label='siv')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
plt.legend()
plt.ylim(0.9,1.2)
plt.savefig('results/compare/Fine/compare_RC_siv_eic3.pdf')
plt.figure()
plt.plot(T_bn_qtQ_eic3,(np.asarray(RC_F_siv_eic3)-np.asarray(RC_T_siv_eic3))/(np.asarray(RC_T_siv_eic3)-np.asarray(1)),color = 'black')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel(r'$\frac{RC_F-RC_T}{RC_T}$ siv',fontsize=16)
plt.ylim(0,0.5)
plt.xlim(0,0.8)
plt.savefig('results/compare/Fine/compare_RC_with1_siv_eic3.pdf')
plt.figure()
RC_FT_col = RC_F_col_eic3/RC_T_col_eic3
plt.plot(T_bn_qtQ_eic3,RC_FT_col,label='col')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
plt.legend()
plt.ylim(0.9,1.2)
plt.savefig('results/compare/Fine/compare_RC_col_eic3.pdf')
plt.figure()
plt.plot(T_bn_qtQ_eic3,(np.asarray(RC_F_col_eic3)-np.asarray(RC_T_col_eic3))/(np.asarray(RC_T_col_eic3)-np.asarray(1)),color = 'black')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel(r'$\frac{RC_F-RC_T}{RC_T}$ col',fontsize=16)
plt.ylim(0,0.5)
plt.xlim(0,0.8)
plt.savefig('results/compare/Fine/compare_RC_with1_col_eic3.pdf')

# %%
print(np.array(eval(str([0.7,0.8]))))

# %%
print(np.array([0,1]))
