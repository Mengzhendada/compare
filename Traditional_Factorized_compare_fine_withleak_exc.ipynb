# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
from matplotlib import rc, rcParams
rc('text', usetex=True)
rc('axes', linewidth=1.5)
rc('axes', labelweight='bold')
rc('axes',labelsize=20)
rc('axes.formatter',min_exponent=0)
rc('font', weight='bold')
rc('font', size=16)
rc('xtick',direction='in')
rc('ytick',direction='in')
rc('xtick.major',width=1)
rc('ytick.major',width=1)
rc('xtick.major',size=6)
rc('ytick.major',size=6)
rc('xtick.minor',visible=True)
rc('ytick.minor',visible=True)
rc('xtick.minor',size=3)
rc('ytick.minor',size=3)
rc('xaxis',labellocation='right')
rc('yaxis',labellocation='top')
rc('lines',linewidth='2')
rcParams['text.latex.preamble'] = r'\usepackage{sfmath} \boldmath'

# %%
#    JLab 1: S=10.3 GeV2, Q=1.52 GeV, x=0.32, z=0.55
#    JLab 2: Eb=12 GeV, Q2=8 GeV2, x=0.48, z=0.375
#    JLab 3: Eb=24 GeV, Q2=15 GeV2, x=0.48, z=0.375
#    EIC 1: sqrt(S)=140 GeV, Q=3 GeV, y=0.4, z=0.5
#    EIC 2: sqrt(S)=140 GeV, Q=10 GeV, y=0.4, z=0.5
#    EIC 3: sqrt(S)=140 GeV, Q=5 GeV, x=0.01, z=0.5
#    qt_to_Q = PhT/z/Q

def Get_error(value1,error1,value2,error2):
    ratios=[]
    ratios_err=[]
    for i in range(0,len(value1)):
        ratio = value1[i]/value2[i]
        ratio_err = ratio*math.sqrt((error1[i]/value1[i])**2+(error2[i]/value2[i])**2)
        ratios.append(ratio)
        ratios_err.append(ratio_err)
    return ratios,ratios_err
    #return value1/value2,(value1/value2)*math.sqrt((error1/value1)**2+(error2/value2)**2)

# %%
df_T_eic3_unpol = pd.read_csv('results/Tra-results/results-fine/without-vac-pol/eic3-unpol.txt',delim_whitespace=True)
qt_to_Q = df_T_eic3_unpol['qt_to_Q']

# %%
df_T_eic3_unpol = pd.read_csv('results/Tra-results/results-fine/results/eic3-unpol.txt',delim_whitespace=True)
df_T_eic3_unpol.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_T_eic3_unpol.head()
df_T_eic3_siv = pd.read_csv('results/Tra-results/results-fine/results/eic3-siv.txt',delim_whitespace=True)
df_T_eic3_siv.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_T_eic3_siv.head()
df_T_eic3_col = pd.read_csv('results/Tra-results/results-fine/results/eic3-col.txt',delim_whitespace=True)
df_T_eic3_col.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_T_eic3_col.head()
# Out:
#     qt_to_Q  unpol_bn  unpol_bn_err  unpol_rc  unpol_rc_err     sivers_bn
# 0  0.050000       0.0           0.0       0.0           0.0 -2.335336e-13  \
# 1  0.059732       0.0           0.0       0.0           0.0 -2.730296e-13
# 2  0.069463       0.0           0.0       0.0           0.0 -3.098080e-13
# 3  0.079195       0.0           0.0       0.0           0.0 -3.435874e-13
# 4  0.088926       0.0           0.0       0.0           0.0 -3.737510e-13
#
#    sivers_bn_err     sivers_rc  sivers_rc_err    collins_bn  collins_bn_err
# 0   6.320409e-13  7.525849e-09   3.760098e-10  3.160314e-07    8.206669e-22  \
# 1   7.396788e-13  8.976000e-09   3.869016e-10  3.698522e-07    4.543231e-22
# 2   8.396008e-13  1.036148e-08   4.000868e-10  4.198150e-07    2.816222e-22
# 3   9.309126e-13  1.145285e-08   4.102047e-10  4.654724e-07    5.449051e-22
# 4   1.012867e-12  1.264111e-08   4.222470e-10  5.064509e-07    4.241573e-22
#
#      collins_rc  collins_rc_err
# ...

# %%
df_T_eic2_unpol = pd.read_csv('results/Tra-results/results-fine/results/eic2-unpol.txt',delim_whitespace=True)
df_T_eic2_unpol.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_T_eic2_unpol.head()
df_T_eic2_siv = pd.read_csv('results/Tra-results/results-fine/results/eic2-siv.txt',delim_whitespace=True)
df_T_eic2_siv.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_T_eic2_siv.head()
df_T_eic2_col = pd.read_csv('results/Tra-results/results-fine/results/eic2-col.txt',delim_whitespace=True)
df_T_eic2_col.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_T_eic2_col.head()
# Out:
#     qt_to_Q  unpol_bn  unpol_bn_err  unpol_rc  unpol_rc_err     sivers_bn
# 0  0.050000       0.0           0.0       0.0           0.0 -2.014018e-14  \
# 1  0.059732       0.0           0.0       0.0           0.0 -2.206695e-14
# 2  0.069463       0.0           0.0       0.0           0.0 -2.329537e-14
# 3  0.079195       0.0           0.0       0.0           0.0 -2.364713e-14
# 4  0.088926       0.0           0.0       0.0           0.0 -2.345383e-14
#
#    sivers_bn_err     sivers_rc  sivers_rc_err    collins_bn  collins_bn_err
# 0   5.407394e-14  9.263554e-10   3.180643e-11  2.703791e-08    3.961891e-22  \
# 1   5.949476e-14  1.010280e-09   3.270475e-11  2.974841e-08    2.514993e-22
# 2   6.279807e-14  1.093546e-09   3.448726e-11  3.140012e-08    2.703432e-22
# 3   6.404209e-14  1.096885e-09   3.265041e-11  3.202215e-08    5.745719e-23
# 4   6.339239e-14  1.092940e-09   3.201859e-11  3.169729e-08    1.495103e-22
#
#      collins_rc  collins_rc_err
# ...

# %%
df_T_eic1_unpol = pd.read_csv('results/Tra-results/results-fine/results/eic1-unpol.txt',delim_whitespace=True)
df_T_eic1_unpol.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_T_eic1_unpol.head()
df_T_eic1_siv = pd.read_csv('results/Tra-results/results-fine/results/eic1-siv.txt',delim_whitespace=True)
df_T_eic1_siv.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_T_eic1_siv.head()
df_T_eic1_col = pd.read_csv('results/Tra-results/results-fine/results/eic1-col.txt',delim_whitespace=True)
df_T_eic1_col.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_T_eic1_col.head()
# Out:
#     qt_to_Q  unpol_bn  unpol_bn_err  unpol_rc  unpol_rc_err     sivers_bn
# 0  0.050000       0.0           0.0       0.0           0.0 -3.186839e-14  \
# 1  0.059732       0.0           0.0       0.0           0.0 -3.843649e-14
# 2  0.069463       0.0           0.0       0.0           0.0 -4.234919e-14
# 3  0.079195       0.0           0.0       0.0           0.0 -5.177561e-14
# 4  0.088926       0.0           0.0       0.0           0.0 -5.515984e-14
#
#    sivers_bn_err     sivers_rc  sivers_rc_err    collins_bn  collins_bn_err
# 0   8.845906e-14  6.569207e-10   5.728854e-11  4.423106e-08    1.463938e-21  \
# 1   1.048961e-13  7.978608e-10   5.621160e-11  5.244985e-08    4.528545e-22
# 2   1.209267e-13  9.430549e-10   5.884963e-11  6.046543e-08    4.483170e-21
# 3   1.364915e-13  1.086756e-09   6.319458e-11  6.824813e-08    2.812321e-21
# 4   1.515343e-13  1.215899e-09   6.234478e-11  7.576979e-08    1.447221e-21
#
#      collins_rc  collins_rc_err
# ...

# %%
column_names=['x','z','Q','qT_Q','xs','xs_err']
df_F_EIC_1_siv_rc = pd.read_csv('results/Fac-results/Fine/EIC_1_siv_rc.txt',delim_whitespace=True,names=column_names)
df_F_EIC_1_siv_bn = pd.read_csv('results/Fac-results/Fine/EIC_1_siv_born.txt',delim_whitespace=True,names=column_names)
df_F_EIC_1_col_rc = pd.read_csv('results/Fac-results/Fine/EIC_1_col_rc.txt',delim_whitespace=True,names=column_names)
df_F_EIC_1_col_bn = pd.read_csv('results/Fac-results/Fine/EIC_1_col_born.txt',delim_whitespace=True,names=column_names)
df_F_EIC_1_unpol_rc = pd.read_csv('results/Fac-results/Fine/EIC_1_unpol_rc.txt',delim_whitespace=True,names=column_names)
df_F_EIC_1_unpol_bn = pd.read_csv('results/Fac-results/Fine/EIC_1_unpol_born.txt',delim_whitespace=True,names=column_names)
df_F_EIC_1_siv_rc.head()
print((df_F_EIC_1_unpol_bn['qT_Q']))
print((df_F_EIC_1_siv_bn['qT_Q']))
print((df_F_EIC_1_col_bn['qT_Q']))
# Out:
# 0      0.050000
# 1      0.059732
# 2      0.069463
# 3      0.079195
# 4      0.088926
#          ...
# 145    1.461074
# 146    1.470805
# 147    1.480537
# 148    1.490268
# 149    1.500000
# Name: qT_Q, Length: 150, dtype: float64
# 0      0.050000
# 1      0.059732
# 2      0.069463
# 3      0.079195
# 4      0.088926
#          ...
# 145    1.461074
# 146    1.470805
# 147    1.480537
# 148    1.490268
# 149    1.500000
# Name: qT_Q, Length: 150, dtype: float64
# 0      0.050000
# 1      0.059732
# 2      0.069463
# 3      0.079195
# 4      0.088926
#          ...
# 145    1.461074
# 146    1.470805
# 147    1.480537
# 148    1.490268
# 149    1.500000
# Name: qT_Q, Length: 150, dtype: float64

# %%
column_names=['x','z','Q','qT_Q','xs','xs_err']
df_F_EIC_1_sivleak_rc = pd.read_csv('results/Fac-results/Fine/EIC_1_sivleak_rc.txt',delim_whitespace=True,names=column_names)
df_F_EIC_1_colleak_rc = pd.read_csv('results/Fac-results/Fine/EIC_1_colleak_rc.txt',delim_whitespace=True,names=column_names)
df_F_EIC_1_sivleak_rc.head()
print((df_F_EIC_1_sivleak_rc['qT_Q']))
print((df_F_EIC_1_colleak_rc['qT_Q']))
# Out:
# 0    0.050000
# 1    0.059732
# 2    0.069463
# 3    0.079195
# 4    0.088926
# Name: qT_Q, dtype: float64
# 0     0.050000
# 1     0.059732
# 2     0.069463
# 3     0.079195
# 4     0.088926
#         ...
# 93    0.955034
# 94    0.964765
# 95    0.974497
# 96    0.984228
# 97    0.993960
# Name: qT_Q, Length: 98, dtype: float64

# %%
df_F_EIC_2_siv_rc = pd.read_csv('results/Fac-results/Fine/EIC_2_siv_rc.txt',delim_whitespace=True,names=column_names)
df_F_EIC_2_siv_bn = pd.read_csv('results/Fac-results/Fine/EIC_2_siv_born.txt',delim_whitespace=True,names=column_names)
df_F_EIC_2_col_rc = pd.read_csv('results/Fac-results/Fine/EIC_2_col_rc.txt',delim_whitespace=True,names=column_names)
df_F_EIC_2_col_bn = pd.read_csv('results/Fac-results/Fine/EIC_2_col_born.txt',delim_whitespace=True,names=column_names)
df_F_EIC_2_unpol_rc = pd.read_csv('results/Fac-results/Fine/EIC_2_unpol_rc.txt',delim_whitespace=True,names=column_names)
df_F_EIC_2_unpol_bn = pd.read_csv('results/Fac-results/Fine/EIC_2_unpol_born.txt',delim_whitespace=True,names=column_names)
df_F_EIC_2_siv_rc.head()
# Out:
#           x    z     Q      qT_Q            xs        xs_err
# 0  0.012755  0.5  10.0  0.050000  1.560565e-07  2.099299e-10
# 1  0.012755  0.5  10.0  0.059732  1.651158e-07  3.150433e-10
# 2  0.012755  0.5  10.0  0.069463  1.687828e-07  2.018478e-10
# 3  0.012755  0.5  10.0  0.079195  1.647366e-07  3.585504e-10
# 4  0.012755  0.5  10.0  0.088926  1.557056e-07  2.895705e-10

# %%
df_F_EIC_2_sivleak_rc = pd.read_csv('results/Fac-results/Fine/EIC_2_sivleak_rc.txt',delim_whitespace=True,names=column_names)
df_F_EIC_2_colleak_rc = pd.read_csv('results/Fac-results/Fine/EIC_2_colleak_rc.txt',delim_whitespace=True,names=column_names)
df_F_EIC_2_sivleak_rc.head()
# Out:
#           x    z     Q      qT_Q            xs        xs_err
# 0  0.012755  0.5  10.0  0.050000  9.032560e-10  8.483488e-12
# 1  0.012755  0.5  10.0  0.059732  9.750755e-10  9.169842e-12
# 2  0.012755  0.5  10.0  0.069463  1.043395e-09  1.022428e-11
# 3  0.012755  0.5  10.0  0.079195  1.069851e-09  1.062608e-11
# 4  0.012755  0.5  10.0  0.088926  1.056768e-09  1.012042e-11

# %%
df_F_EIC_3_siv_rc = pd.read_csv('results/Fac-results/Fine/EIC_3_siv_rc.txt',delim_whitespace=True,names=column_names)
df_F_EIC_3_siv_bn = pd.read_csv('results/Fac-results/Fine/EIC_3_siv_born.txt',delim_whitespace=True,names=column_names)
df_F_EIC_3_col_rc = pd.read_csv('results/Fac-results/Fine/EIC_3_col_rc.txt',delim_whitespace=True,names=column_names)
df_F_EIC_3_col_bn = pd.read_csv('results/Fac-results/Fine/EIC_3_col_born.txt',delim_whitespace=True,names=column_names)
df_F_EIC_3_unpol_rc = pd.read_csv('results/Fac-results/Fine/EIC_3_unpol_rc.txt',delim_whitespace=True,names=column_names)
df_F_EIC_3_unpol_bn = pd.read_csv('results/Fac-results/Fine/EIC_3_unpol_born.txt',delim_whitespace=True,names=column_names)
df_F_EIC_3_siv_rc.head()
# Out:
#       x    z    Q      qT_Q        xs        xs_err
# 0  0.01  0.5  5.0  0.050000  0.000002  4.470925e-09
# 1  0.01  0.5  5.0  0.059732  0.000002  2.581447e-09
# 2  0.01  0.5  5.0  0.069463  0.000002  2.753829e-09
# 3  0.01  0.5  5.0  0.079195  0.000002  2.438992e-09
# 4  0.01  0.5  5.0  0.088926  0.000003  6.792245e-09

# %%
df_F_EIC_3_sivleak_rc = pd.read_csv('results/Fac-results/Fine/EIC_3_sivleak_rc.txt',delim_whitespace=True,names=column_names)
df_F_EIC_3_colleak_rc = pd.read_csv('results/Fac-results/Fine/EIC_3_colleak_rc.txt',delim_whitespace=True,names=column_names)
df_F_EIC_3_sivleak_rc.head()
# Out:
#       x    z    Q      qT_Q            xs        xs_err
# 0  0.01  0.5  5.0  0.050000  7.304346e-09  7.190087e-11
# 1  0.01  0.5  5.0  0.059732  8.514264e-09  8.463621e-11
# 2  0.01  0.5  5.0  0.069463  9.720145e-09  9.655652e-11
# 3  0.01  0.5  5.0  0.079195  1.082022e-08  1.064098e-10
# 4  0.01  0.5  5.0  0.088926  1.166474e-08  1.165399e-10

# %%
print(df_T_eic1_unpol['qt_to_Q'])
# Out:
# 0      0.050000
# 1      0.059732
# 2      0.069463
# 3      0.079195
# 4      0.088926
#          ...
# 145    1.461074
# 146    1.470805
# 147    1.480537
# 148    1.490268
# 149    1.500000
# Name: qt_to_Q, Length: 150, dtype: float64

# %%
df_T_

# %%
#plt.plot(np.asarray(df_T_eic1['qt_to_Q']),df_T_eic1['sivers_bn'],color='b',label='Tra bn rough')
#plt.plot(np.asarray(df_F_eic1_siv_bn['qT_Q']),df_F_eic1_siv_bn['xs'],color='r',label='Fac bn rough')

plt.plot(np.asarray(df_T_eic1_siv['qt_to_Q']),df_T_eic1_siv['sivers_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_EIC_1_siv_bn['qT_Q']),df_F_EIC_1_siv_bn['xs'],color='r',label='Factorized bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
#plt.savefig('results/compare/Fine/justsiv_bn_eic1.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic1['qt_to_Q']),df_T_eic1['sivers_rc'],color='b',label='Tra rc rough')
#plt.plot(np.asarray(df_F_eic1_siv_rc['qT_Q']),df_F_eic1_siv_rc['xs'],color='r',label='Fac rc rough')

plt.plot(np.asarray(df_T_eic1_siv['qt_to_Q']),df_T_eic1_siv['sivers_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_EIC_1_siv_rc['qT_Q']),df_F_EIC_1_siv_rc['xs'],color='r',label='Factorized rc')
plt.plot(np.asarray(df_T_eic1_col['qt_to_Q']),df_T_eic1_col['sivers_rc'],color='b',linestyle=':',label='Traditional rc')
plt.plot(np.asarray(df_F_EIC_1_sivleak_rc['qT_Q']),df_F_EIC_1_sivleak_rc['xs'],color='r',linestyle=':',label='Factorized rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_leak_rc_eic1.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic1['qt_to_Q']),df_T_eic1['collins_bn'],color='b',label='Tra bn rough')
#plt.plot(np.asarray(df_F_eic1_col_bn['qT_Q']),df_F_eic1_col_bn['xs'],color='r',label='Fac bn rough')

plt.plot(np.asarray(df_T_eic1_col['qt_to_Q']),df_T_eic1_col['collins_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_EIC_1_col_bn['qT_Q']),df_F_EIC_1_col_bn['xs'],color='r',label='Factorized bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
#plt.savefig('results/compare/Fine/justcol_bn_eic1.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic1['qt_to_Q']),df_T_eic1['collins_rc'],color='b',label='Tra rc rough')
#plt.plot(np.asarray(df_F_eic1_col_rc['qT_Q']),df_F_eic1_col_rc['xs'],color='r',label='Fac rc rough')

plt.plot(np.asarray(df_T_eic1_col['qt_to_Q']),df_T_eic1_col['collins_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_EIC_1_col_rc['qT_Q']),df_F_EIC_1_col_rc['xs'],color='r',label='Factorized rc')
plt.plot(np.asarray(df_T_eic1_siv['qt_to_Q']),df_T_eic1_siv['collins_rc'],color='b',linestyle=':',label='Traditional rc')
plt.plot(np.asarray(df_F_EIC_1_colleak_rc['qT_Q']),df_F_EIC_1_colleak_rc['xs'],color='r',linestyle=':',label='Factorized rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_leak_rc_eic1.pdf')

# %%
#plt.plot(np.asarray(df_T_eic1['qt_to_Q']),df_T_eic1['sivers_bn'],color='b',label='Tra bn rough')
#plt.plot(np.asarray(df_F_eic1_siv_bn['qT_Q']),df_F_eic1_siv_bn['xs'],color='r',label='Fac bn rough')

plt.plot(np.asarray(df_T_eic1_siv['qt_to_Q'])*0.5*3,df_T_eic1_siv['sivers_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_EIC_1_siv_bn['qT_Q'])*0.5*3,df_F_EIC_1_siv_bn['xs'],color='r',label='Factorized bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$P_{hT}$ $(GeV/c)$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
#plt.savefig('results/compare/Fine/justsiv_bn_eic1.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic1['qt_to_Q']),df_T_eic1['sivers_rc'],color='b',label='Tra rc rough')
#plt.plot(np.asarray(df_F_eic1_siv_rc['qT_Q']),df_F_eic1_siv_rc['xs'],color='r',label='Fac rc rough')

plt.plot(np.asarray(df_T_eic1_siv['qt_to_Q'])*0.5*3,df_T_eic1_siv['sivers_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_EIC_1_siv_rc['qT_Q'])*0.5*3,df_F_EIC_1_siv_rc['xs'],color='r',label='Factorized rc')
plt.plot(np.asarray(df_T_eic1_col['qt_to_Q'])*0.5*3,df_T_eic1_col['sivers_rc'],color='b',linestyle=':',label='Traditional rc')
plt.plot(np.asarray(df_F_EIC_1_sivleak_rc['qT_Q'])*0.5*3,df_F_EIC_1_sivleak_rc['xs'],color='r',linestyle=':',label='Factorized rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$P_{hT}$ $(GeV/c)$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_leak_rc_eic1_Pt.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic1['qt_to_Q']),df_T_eic1['collins_bn'],color='b',label='Tra bn rough')
#plt.plot(np.asarray(df_F_eic1_col_bn['qT_Q']),df_F_eic1_col_bn['xs'],color='r',label='Fac bn rough')

plt.plot(np.asarray(df_T_eic1_col['qt_to_Q'])*0.5*3,df_T_eic1_col['collins_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_EIC_1_col_bn['qT_Q'])*0.5*3,df_F_EIC_1_col_bn['xs'],color='r',label='Factorized bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$P_{hT}$ $(GeV/c)$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
#plt.savefig('results/compare/Fine/justcol_bn_eic1.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic1['qt_to_Q']),df_T_eic1['collins_rc'],color='b',label='Tra rc rough')
#plt.plot(np.asarray(df_F_eic1_col_rc['qT_Q']),df_F_eic1_col_rc['xs'],color='r',label='Fac rc rough')

plt.plot(np.asarray(df_T_eic1_col['qt_to_Q'])*0.5*3,df_T_eic1_col['collins_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_EIC_1_col_rc['qT_Q'])*0.5*3,df_F_EIC_1_col_rc['xs'],color='r',label='Factorized rc')
plt.plot(np.asarray(df_T_eic1_siv['qt_to_Q'])*0.5*3,df_T_eic1_siv['collins_rc'],color='b',linestyle=':',label='Traditional rc')
plt.plot(np.asarray(df_F_EIC_1_colleak_rc['qT_Q'])*0.5*3,df_F_EIC_1_colleak_rc['xs'],color='r',linestyle=':',label='Factorized rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$P_{hT}$ $(GeV/c)$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_leak_rc_eic1_Pt.pdf')

# %%
plt.figure()
F_Born_eic1 = np.asarray(df_F_EIC_1_unpol_bn['xs'])
T_Born_eic1 = np.asarray(df_T_eic1_unpol['unpol_bn'])
R_Born_eic1 = F_Born_eic1/T_Born_eic1
plt.plot(np.asarray(df_F_EIC_1_unpol_bn['qT_Q'])*0.5*3,R_Born_eic1,color='b')
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$R_{Born}$',fontsize=16)
plt.ylim(0.94,1.06)
plt.title('including unpol')
#plt.savefig('results/compare/Fine/compare_born_unpol_eic1.pdf')


plt.figure()
F_RC_eic1 = np.asarray(df_F_EIC_1_unpol_rc['xs'])
T_RC_eic1 = np.asarray(df_T_eic1_unpol['unpol_rc'])
RC_F = (F_Born_eic1/F_RC_eic1)
RC_T = (T_Born_eic1/T_RC_eic1)
plt.plot(np.asarray(df_F_EIC_1_unpol_rc['qT_Q'])*0.5*3,RC_F/RC_T,label='$RC_F/RC_T')
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
plt.ylim(1,1.1)
plt.xlim(0,1.2)
#plt.title('including unpol')
#plt.savefig('results/compare/Fine/compare_RC_unpol_Pt_eic1.pdf')

fig1 = plt.figure()
ax1 = fig1.add_subplot()
fig2 = plt.figure()
ax2 = fig2.add_subplot()
F_bnerr_eic1 = np.asarray(df_F_EIC_1_unpol_bn['xs_err'])
T_bnerr_eic1 = np.asarray(df_T_eic1_unpol['unpol_bn_err'])
F_RCerr_eic1 = np.asarray(df_F_EIC_1_unpol_rc['xs_err'])
T_RCerr_eic1 = np.asarray(df_T_eic1_unpol['unpol_rc_err'])
RC_Fs,RCerr_Fs=Get_error(F_Born_eic1,F_bnerr_eic1,F_RC_eic1,F_RCerr_eic1)
RC_Ts,RCerr_Ts=Get_error(T_Born_eic1,T_bnerr_eic1,T_RC_eic1,T_RCerr_eic1)
RC_ratios,RC_ratioerrs=Get_error(RC_Fs,RCerr_Fs,RC_Ts,RCerr_Ts)

ax1.fill_between(np.asarray(df_F_EIC_1_unpol_rc['qT_Q'].to_list()),np.asarray(RC_Fs)-np.asarray(RCerr_Fs),np.asarray(RC_Fs)+np.asarray(RCerr_Fs),color='red',alpha=0.25,linewidth=0)
ax1.fill_between(np.asarray(df_F_EIC_1_unpol_rc['qT_Q'].to_list()),np.asarray(RC_Ts)-np.asarray(RCerr_Ts),np.asarray(RC_Ts)+np.asarray(RCerr_Ts),color='blue',alpha=0.25,linewidth=0)
ax1.plot(np.asarray(df_F_EIC_1_unpol_rc['qT_Q'].to_list()),RC_Fs,color='red',label='Factorized')
ax1.plot(np.asarray(df_F_EIC_1_unpol_rc['qT_Q'].to_list()),RC_Ts,color='blue',label='Traditional')
ax1.set_xlabel('$qT/Q$',fontsize=16)
ax1.set_ylabel('RC',fontsize=16)
ax1.legend()
#fig1.savefig('results/compare/Fine/RCs_both_eic1.pdf')
ax2.fill_between(np.asarray(df_F_EIC_1_unpol_rc['qT_Q'].to_list()),np.asarray(RC_ratios)-np.asarray(RC_ratioerrs),np.asarray(RC_ratios)+np.asarray(RC_ratioerrs),color='black',alpha=0.25,linewidth=0)
ax2.plot(np.asarray(df_F_EIC_1_unpol_rc['qT_Q'].to_list()),RC_ratios,color='black')
ax2.set_xlabel('$qT/Q$',fontsize=16)
ax2.set_ylabel('$RC_F/RC_T$',fontsize=16)
#fig2.savefig('results/compare/Fine/compare_RC_unpol_eic1.pdf')

plt.figure()
F_Born_eic1 = np.asarray(df_F_EIC_1_unpol_bn['xs'])+np.asarray(df_F_EIC_1_siv_bn['xs'])+np.asarray(df_F_EIC_1_col_bn['xs'])
T_Born_eic1 = np.asarray(df_T_eic1_unpol['unpol_bn'])+np.asarray(df_T_eic1_unpol['sivers_bn'])+np.asarray(df_T_eic1_unpol['collins_bn'])
R_Born_eic1 = F_Born_eic1/T_Born_eic1
plt.plot(np.asarray(df_F_EIC_1_unpol_bn['qT_Q']),R_Born_eic1,color='b')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$R_{Born}$',fontsize=16)
plt.ylim(0.94,1.06)
plt.title('including both unpol and pol')
#plt.savefig('results/compare/Fine/compare_born_both_eic1.pdf')



plt.figure()
F_RC_eic1 = np.asarray(df_F_EIC_1_unpol_rc['xs'])+np.asarray(df_F_EIC_1_siv_rc['xs'])+np.asarray(df_F_EIC_1_col_rc['xs'])
T_RC_eic1 = np.asarray(df_T_eic1_unpol['unpol_rc'])+np.asarray(df_T_eic1_siv['sivers_rc'])+np.asarray(df_T_eic1_col['collins_rc'])
RC_F = (F_Born_eic1/F_RC_eic1)
RC_T = (T_Born_eic1/T_RC_eic1)
plt.plot(np.asarray(df_F_EIC_1_unpol_rc['qT_Q']),RC_F/RC_T,label='$RC_F/RC_T')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
#plt.ylim(0.9,1.2)
plt.title('including both unpol and pol')
#plt.savefig('results/compare/Fine/compare_RC_both_eic1.pdf')

plt.figure()
#supposed to be this, but sivleak is almost zero
#F_RC_eic1 = np.asarray(df_F_EIC_1_unpol_rc['xs'])+np.asarray(df_F_EIC_1_siv_rc['xs'])+np.asarray(df_F_EIC_1_sivleak_rc['xs'])+np.asarray(df_F_EIC_1_col_rc['xs'])+np.asarray(df_F_EIC_1_colleak_rc['xs'])
#T_RC_eic1 = np.asarray(df_T_eic1_unpol['unpol_rc'])+np.asarray(df_T_eic1_siv['sivers_rc'])+np.asarray(df_T_eic1_siv['collins_rc'])+np.asarray(df_T_eic1_col['collins_rc'])+np.asarray(df_T_eic1_siv['collins_rc'])
nlen = len(df_F_EIC_1_colleak_rc['xs'])
F_RC_eic1 = np.asarray(df_F_EIC_1_unpol_rc['xs'])[:nlen]+np.asarray(df_F_EIC_1_siv_rc['xs'])[:nlen]+np.asarray(df_F_EIC_1_col_rc['xs'])[:nlen]+np.asarray(df_F_EIC_1_colleak_rc['xs'])
T_RC_eic1 = np.asarray(df_T_eic1_unpol['unpol_rc'])+np.asarray(df_T_eic1_siv['sivers_rc'])+np.asarray(df_T_eic1_col['collins_rc'])+np.asarray(df_T_eic1_siv['collins_rc'])
RC_F = (F_Born_eic1[:nlen]/F_RC_eic1)
RC_T = (T_Born_eic1/T_RC_eic1)[:nlen]
plt.plot(np.asarray(df_F_EIC_1_unpol_rc['qT_Q'])[:nlen],RC_F/RC_T,label='$RC_F/RC_T')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
#plt.ylim(0.9,1.2)
plt.title('including both unpol and pol and leak')
plt.savefig('results/compare/Fine/compare_RC_both_leak_eic1.pdf')

# %%
plt.figure()

F_rc_colleak_EIC_1 = df_F_EIC_1_colleak_rc['xs'].to_list()
nlen_eic1 = len(df_F_EIC_1_colleak_rc['xs'])
T_rc_colleak_eic1 = df_T_eic1_siv['collins_rc'][:nlen_eic1].to_list()
T_bn_qtQ_eic1 = df_T_eic1_col['qt_to_Q'][:nlen_eic1].to_list()
T_bn_col_eic1 = df_T_eic1_col['collins_bn'][:nlen_eic1].to_list()
F_bn_qtQ_EIC_1 = df_F_EIC_1_col_bn['qT_Q'][:nlen_eic1].to_list()
F_bn_col_EIC_1 = df_F_EIC_1_col_bn['xs'][:nlen_eic1].to_list()
T_rc_qtQ_eic1 = df_T_eic1_col['qt_to_Q'][:nlen_eic1].to_list()
T_rc_col_eic1 = df_T_eic1_col['collins_rc'][:nlen_eic1].to_list()
F_rc_qtQ_EIC_1 = df_F_EIC_1_col_rc['qT_Q'][:nlen_eic1].to_list()
F_rc_col_EIC_1 = df_F_EIC_1_col_rc['xs'][:nlen_eic1].to_list()

RC_F_col_eic1 = np.asarray(F_bn_col_EIC_1)/(np.asarray(F_rc_col_EIC_1)+np.asarray(F_rc_colleak_EIC_1))
RC_T_col_eic1 = np.asarray(T_bn_col_eic1)/(np.asarray(T_rc_col_eic1)+np.asarray(T_rc_colleak_eic1))
plt.plot(T_bn_qtQ_eic1,RC_T_col_eic1,color='r',label='Traditional RC')
plt.plot(F_bn_qtQ_EIC_1,RC_F_col_eic1,color='b',label='Factorized RC')
plt.xlabel('qT/Q',fontsize =16)
plt.ylabel('RC from col',fontsize =16)
plt.legend()
plt.savefig('results/compare/Fine/RCs_col_both_eic1_withleak.pdf')


plt.figure()
RC_FT_col = RC_F_col_eic1/RC_T_col_eic1
plt.plot(T_bn_qtQ_eic1,RC_FT_col,label='col')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
plt.legend()
plt.ylim(0.9,1.2)
plt.savefig('results/compare/Fine/compare_RC_col_eic1_withleak.pdf')

# %%
#plt.plot(np.asarray(df_T_eic2['qt_to_Q']),df_T_eic2['sivers_bn'],color='b',label='Tra bn rough')
#plt.plot(np.asarray(df_F_eic2_siv_bn['qT_Q']),df_F_eic2_siv_bn['xs'],color='r',label='Fac bn rough')

plt.plot(np.asarray(df_T_eic2_siv['qt_to_Q']),df_T_eic2_siv['sivers_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_EIC_2_siv_bn['qT_Q']),df_F_EIC_2_siv_bn['xs'],color='r',label='Factorized bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
#plt.savefig('results/compare/Fine/justsiv_bn_eic2.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic2['qt_to_Q']),df_T_eic2['sivers_rc'],color='b',label='Tra rc rough')
#plt.plot(np.asarray(df_F_eic2_siv_rc['qT_Q']),df_F_eic2_siv_rc['xs'],color='r',label='Fac rc rough')

plt.plot(np.asarray(df_T_eic2_siv['qt_to_Q']),df_T_eic2_siv['sivers_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_EIC_2_siv_rc['qT_Q']),df_F_EIC_2_siv_rc['xs'],color='r',label='Factorized rc')
plt.plot(np.asarray(df_T_eic2_col['qt_to_Q']),df_T_eic2_col['sivers_rc'],color='b',linestyle=':',label='Traditional rc')
plt.plot(np.asarray(df_F_EIC_2_sivleak_rc['qT_Q']),df_F_EIC_2_sivleak_rc['xs'],color='r',linestyle=':',label='Factorized rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_leak_rc_eic2.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic2['qt_to_Q']),df_T_eic2['collins_bn'],color='b',label='Tra bn rough')
#plt.plot(np.asarray(df_F_eic2_col_bn['qT_Q']),df_F_eic2_col_bn['xs'],color='r',label='Fac bn rough')

plt.plot(np.asarray(df_T_eic2_col['qt_to_Q']),df_T_eic2_col['collins_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_EIC_2_col_bn['qT_Q']),df_F_EIC_2_col_bn['xs'],color='r',label='Factorized bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
#plt.savefig('results/compare/Fine/justcol_bn_eic2.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic2['qt_to_Q']),df_T_eic2['collins_rc'],color='b',label='Tra rc rough')
#plt.plot(np.asarray(df_F_eic2_col_rc['qT_Q']),df_F_eic2_col_rc['xs'],color='r',label='Fac rc rough')

plt.plot(np.asarray(df_T_eic2_col['qt_to_Q']),df_T_eic2_col['collins_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_EIC_2_col_rc['qT_Q']),df_F_EIC_2_col_rc['xs'],color='r',label='Factorized rc')
plt.plot(np.asarray(df_T_eic2_siv['qt_to_Q']),df_T_eic2_siv['collins_rc'],color='b',linestyle=':',label='Traditional rc')
plt.plot(np.asarray(df_F_EIC_2_colleak_rc['qT_Q']),df_F_EIC_2_colleak_rc['xs'],color='r',linestyle=':',label='Factorized rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_leak_rc_eic2.pdf')

# %%
plt.figure()
F_Born_eic2 = np.asarray(df_F_EIC_2_unpol_bn['xs'])[:81]
T_Born_eic2 = np.asarray(df_T_eic2_unpol['unpol_bn'])[:81]
R_Born_eic2 = F_Born_eic2/T_Born_eic2
plt.plot(np.asarray(df_F_EIC_2_unpol_bn['qT_Q'])[:81]*0.5*10,R_Born_eic2,color='b')
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$R_{Born}$',fontsize=16)
plt.ylim(0.94,1.06)
plt.title('including unpol')
#plt.savefig('results/compare/Fine/compare_born_unpol_eic2.pdf')


plt.figure()
F_RC_eic2 = np.asarray(df_F_EIC_2_unpol_rc['xs'])[:81]
T_RC_eic2 = np.asarray(df_T_eic2_unpol['unpol_rc'])[:81]
RC_F = (F_Born_eic2/F_RC_eic2)
RC_T = (T_Born_eic2/T_RC_eic2)
plt.plot(np.asarray(df_F_EIC_2_unpol_rc['qT_Q'])[:81]*0.5*10,RC_F/RC_T,label='$RC_F/RC_T')
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
plt.ylim(1,1.1)
plt.xlim(0,1.2)
#plt.title('including unpol')
#plt.savefig('results/compare/Fine/compare_RC_unpol_Pt_eic2.pdf')

fig1 = plt.figure()
ax1 = fig1.add_subplot()
fig2 = plt.figure()
ax2 = fig2.add_subplot()
F_bnerr_eic2 = np.asarray(df_F_EIC_2_unpol_bn['xs_err'])[:81]
T_bnerr_eic2 = np.asarray(df_T_eic2_unpol['unpol_bn_err'])[:81]
F_RCerr_eic2 = np.asarray(df_F_EIC_2_unpol_rc['xs_err'])[:81]
T_RCerr_eic2 = np.asarray(df_T_eic2_unpol['unpol_rc_err'])[:81]
RC_Fs,RCerr_Fs=Get_error(F_Born_eic2,F_bnerr_eic2,F_RC_eic2,F_RCerr_eic2)
RC_Ts,RCerr_Ts=Get_error(T_Born_eic2,T_bnerr_eic2,T_RC_eic2,T_RCerr_eic2)
RC_ratios,RC_ratioerrs=Get_error(RC_Fs,RCerr_Fs,RC_Ts,RCerr_Ts)

ax1.fill_between(np.asarray(df_F_EIC_2_unpol_rc['qT_Q'][:81].to_list()),np.asarray(RC_Fs)-np.asarray(RCerr_Fs),np.asarray(RC_Fs)+np.asarray(RCerr_Fs),color='red',alpha=0.25,linewidth=0)
ax1.fill_between(np.asarray(df_F_EIC_2_unpol_rc['qT_Q'][:81].to_list()),np.asarray(RC_Ts)-np.asarray(RCerr_Ts),np.asarray(RC_Ts)+np.asarray(RCerr_Ts),color='blue',alpha=0.25,linewidth=0)
ax1.plot(np.asarray(df_F_EIC_2_unpol_rc['qT_Q'][:81].to_list()),RC_Fs,color='red',label='Factorized')
ax1.plot(np.asarray(df_F_EIC_2_unpol_rc['qT_Q'][:81].to_list()),RC_Ts,color='blue',label='Traditional')
ax1.set_xlabel('$qT/Q$',fontsize=16)
ax1.set_ylabel('RC',fontsize=16)
ax1.legend()
#fig1.savefig('results/compare/Fine/RCs_both_eic2.pdf')
ax2.fill_between(np.asarray(df_F_EIC_2_unpol_rc['qT_Q'][:81].to_list()),np.asarray(RC_ratios)-np.asarray(RC_ratioerrs),np.asarray(RC_ratios)+np.asarray(RC_ratioerrs),color='black',alpha=0.25,linewidth=0)
ax2.plot(np.asarray(df_F_EIC_2_unpol_rc['qT_Q'][:81].to_list()),RC_ratios,color='black')
ax2.set_xlabel('$qT/Q$',fontsize=16)
ax2.set_ylabel('$RC_F/RC_T$',fontsize=16)
#fig2.savefig('results/compare/Fine/compare_RC_unpol_eic2.pdf')

plt.figure()
F_Born_eic2 = np.asarray(df_F_EIC_2_unpol_bn['xs'])+np.asarray(df_F_EIC_2_siv_bn['xs'])[:81]+np.asarray(df_F_EIC_2_col_bn['xs'])[:81]
T_Born_eic2 = np.asarray(df_T_eic2_unpol['unpol_bn'])+np.asarray(df_T_eic2_unpol['sivers_bn'])+np.asarray(df_T_eic2_unpol['collins_bn'])
R_Born_eic2 = F_Born_eic2/T_Born_eic2[:81]
plt.plot(np.asarray(df_F_EIC_2_unpol_bn['qT_Q'])[:81],R_Born_eic2,color='b')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$R_{Born}$',fontsize=16)
plt.ylim(0.94,1.06)
plt.title('including both unpol and pol')
#plt.savefig('results/compare/Fine/compare_born_both_eic2.pdf')



plt.figure()
F_RC_eic2 = np.asarray(df_F_EIC_2_unpol_rc['xs'])+np.asarray(df_F_EIC_2_siv_rc['xs'])+np.asarray(df_F_EIC_2_col_rc['xs'])
T_RC_eic2 = np.asarray(df_T_eic2_unpol['unpol_rc'])+np.asarray(df_T_eic2_siv['sivers_rc'])+np.asarray(df_T_eic2_col['collins_rc'])
RC_F = F_Born_eic2/F_RC_eic2[:81]
RC_T = (T_Born_eic2/T_RC_eic2)[:81]
plt.plot(np.asarray(df_F_EIC_2_unpol_bn['qT_Q']),RC_F/RC_T,label='$RC_F/RC_T')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
#plt.ylim(0.9,1.2)
plt.title('including both')
#plt.savefig('results/compare/Fine/compare_RC_both_eic2.pdf')

plt.figure()
#supposed to be this, but sivleak is almost zero
#F_RC_eic2 = np.asarray(df_F_EIC_2_unpol_rc['xs'])+np.asarray(df_F_EIC_2_siv_rc['xs'])+np.asarray(df_F_EIC_2_sivleak_rc['xs'])+np.asarray(df_F_EIC_2_col_rc['xs'])+np.asarray(df_F_EIC_2_colleak_rc['xs'])
#T_RC_eic2 = np.asarray(df_T_eic2_unpol['unpol_rc'])+np.asarray(df_T_eic2_siv['sivers_rc'])+np.asarray(df_T_eic2_siv['collins_rc'])+np.asarray(df_T_eic2_col['collins_rc'])+np.asarray(df_T_eic2_siv['collins_rc'])
nlen = len(df_F_EIC_2_colleak_rc['xs'])
F_RC_eic2 = np.asarray(df_F_EIC_2_unpol_rc['xs'])[:nlen]+np.asarray(df_F_EIC_2_siv_rc['xs'])[:nlen]+np.asarray(df_F_EIC_2_col_rc['xs'])[:nlen]+np.asarray(df_F_EIC_2_colleak_rc['xs'])
T_RC_eic2 = np.asarray(df_T_eic2_unpol['unpol_rc'])+np.asarray(df_T_eic2_siv['sivers_rc'])+np.asarray(df_T_eic2_col['collins_rc'])+np.asarray(df_T_eic2_siv['collins_rc'])
RC_F = (F_Born_eic2[:nlen]/F_RC_eic2)
RC_T = (T_Born_eic2/T_RC_eic2)[:nlen]
plt.plot(np.asarray(df_F_EIC_2_unpol_rc['qT_Q'])[:nlen],RC_F/RC_T,label='$RC_F/RC_T')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
#plt.ylim(0.9,1.2)
plt.title('including both unpol and pol and leak')
plt.savefig('results/compare/Fine/compare_RC_both_leak_eic2.pdf')

# %%
plt.figure()

F_rc_colleak_EIC_2 = df_F_EIC_2_colleak_rc['xs'].to_list()
nlen_eic2 = len(df_F_EIC_2_colleak_rc['xs'])
T_rc_colleak_eic2 = df_T_eic2_siv['collins_rc'][:nlen_eic2].to_list()
T_bn_qtQ_eic2 = df_T_eic2_col['qt_to_Q'][:nlen_eic2].to_list()
T_bn_col_eic2 = df_T_eic2_col['collins_bn'][:nlen_eic2].to_list()
F_bn_qtQ_EIC_2 = df_F_EIC_2_col_bn['qT_Q'][:nlen_eic2].to_list()
F_bn_col_EIC_2 = df_F_EIC_2_col_bn['xs'][:nlen_eic2].to_list()
T_rc_qtQ_eic2 = df_T_eic2_col['qt_to_Q'][:nlen_eic2].to_list()
T_rc_col_eic2 = df_T_eic2_col['collins_rc'][:nlen_eic2].to_list()
F_rc_qtQ_EIC_2 = df_F_EIC_2_col_rc['qT_Q'][:nlen_eic2].to_list()
F_rc_col_EIC_2 = df_F_EIC_2_col_rc['xs'][:nlen_eic2].to_list()

RC_F_col_eic2 = np.asarray(F_bn_col_EIC_2)/(np.asarray(F_rc_col_EIC_2)+np.asarray(F_rc_colleak_EIC_2))
RC_T_col_eic2 = np.asarray(T_bn_col_eic2)/(np.asarray(T_rc_col_eic2)+np.asarray(T_rc_colleak_eic2))
plt.plot(T_bn_qtQ_eic2,RC_T_col_eic2,color='r',label='Traditional RC')
plt.plot(F_bn_qtQ_EIC_2,RC_F_col_eic2,color='b',label='Factorized RC')
plt.xlabel('qT/Q',fontsize =16)
plt.ylabel('RC from col',fontsize =16)
plt.legend()
plt.savefig('results/compare/Fine/RCs_col_both_eic2_withleak.pdf')


plt.figure()
RC_FT_col = RC_F_col_eic2/RC_T_col_eic2
plt.plot(T_bn_qtQ_eic2,RC_FT_col,label='col')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
plt.legend()
plt.ylim(0.9,1.2)
plt.savefig('results/compare/Fine/compare_RC_col_eic2_withleak.pdf')

# %%
#plt.plot(np.asarray(df_T_eic3['qt_to_Q']),df_T_eic3['sivers_bn'],color='b',label='Tra bn rough')
#plt.plot(np.asarray(df_F_eic3_siv_bn['qT_Q']),df_F_eic3_siv_bn['xs'],color='r',label='Fac bn rough')

plt.plot(np.asarray(df_T_eic3_siv['qt_to_Q']),df_T_eic3_siv['sivers_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_EIC_3_siv_bn['qT_Q']),df_F_EIC_3_siv_bn['xs'],color='r',label='Factorized bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
#plt.savefig('results/compare/Fine/justsiv_bn_eic3.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic3['qt_to_Q']),df_T_eic3['sivers_rc'],color='b',label='Tra rc rough')
#plt.plot(np.asarray(df_F_eic3_siv_rc['qT_Q']),df_F_eic3_siv_rc['xs'],color='r',label='Fac rc rough')

plt.plot(np.asarray(df_T_eic3_siv['qt_to_Q']),df_T_eic3_siv['sivers_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_EIC_3_siv_rc['qT_Q']),df_F_EIC_3_siv_rc['xs'],color='r',label='Factorized rc')
plt.plot(np.asarray(df_T_eic3_col['qt_to_Q']),df_T_eic3_col['sivers_rc'],color='b',linestyle=':',label='Traditional rc')
plt.plot(np.asarray(df_F_EIC_3_sivleak_rc['qT_Q']),df_F_EIC_3_sivleak_rc['xs'],color='r',linestyle=':',label='Factorized rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_leak_rc_eic3.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic3['qt_to_Q']),df_T_eic3['collins_bn'],color='b',label='Tra bn rough')
#plt.plot(np.asarray(df_F_eic3_col_bn['qT_Q']),df_F_eic3_col_bn['xs'],color='r',label='Fac bn rough')

plt.plot(np.asarray(df_T_eic3_col['qt_to_Q']),df_T_eic3_col['collins_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_EIC_3_col_bn['qT_Q']),df_F_EIC_3_col_bn['xs'],color='r',label='Factorized bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
#plt.savefig('results/compare/Fine/justcol_bn_eic3.pdf')

plt.figure()
#plt.plot(np.asarray(df_T_eic3['qt_to_Q']),df_T_eic3['collins_rc'],color='b',label='Tra rc rough')
#plt.plot(np.asarray(df_F_eic3_col_rc['qT_Q']),df_F_eic3_col_rc['xs'],color='r',label='Fac rc rough')

plt.plot(np.asarray(df_T_eic3_col['qt_to_Q']),df_T_eic3_col['collins_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_EIC_3_col_rc['qT_Q']),df_F_EIC_3_col_rc['xs'],color='r',label='Factorized rc')
plt.plot(np.asarray(df_T_eic3_siv['qt_to_Q']),df_T_eic3_siv['collins_rc'],color='b',linestyle=':',label='Traditional rc')
plt.plot(np.asarray(df_F_EIC_3_colleak_rc['qT_Q']),df_F_EIC_3_colleak_rc['xs'],color='r',linestyle=':',label='Factorized rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_leak_rc_eic3.pdf')

# %%
plt.figure()
F_Born_eic3 = np.asarray(df_F_EIC_3_unpol_bn['xs'])
T_Born_eic3 = np.asarray(df_T_eic3_unpol['unpol_bn'])
R_Born_eic3 = F_Born_eic3/T_Born_eic3
plt.plot(np.asarray(df_F_EIC_3_unpol_bn['qT_Q'])*0.5*3,R_Born_eic3,color='b')
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$R_{Born}$',fontsize=16)
plt.ylim(0.94,1.06)
plt.title('including unpol')
#plt.savefig('results/compare/Fine/compare_born_unpol_eic3.pdf')


plt.figure()
F_RC_eic3 = np.asarray(df_F_EIC_3_unpol_rc['xs'])
T_RC_eic3 = np.asarray(df_T_eic3_unpol['unpol_rc'])
RC_F = (F_Born_eic3/F_RC_eic3)
RC_T = (T_Born_eic3/T_RC_eic3)
plt.plot(np.asarray(df_F_EIC_3_unpol_rc['qT_Q'])*0.5*3,RC_F/RC_T,label='$RC_F/RC_T')
plt.xlabel('$P_{hT}(GeV/c)$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
plt.ylim(1,1.1)
plt.xlim(0,1.2)
#plt.title('including unpol')
#plt.savefig('results/compare/Fine/compare_RC_unpol_Pt_eic3.pdf')

fig1 = plt.figure()
ax1 = fig1.add_subplot()
fig2 = plt.figure()
ax2 = fig2.add_subplot()
F_bnerr_eic3 = np.asarray(df_F_EIC_3_unpol_bn['xs_err'])
T_bnerr_eic3 = np.asarray(df_T_eic3_unpol['unpol_bn_err'])
F_RCerr_eic3 = np.asarray(df_F_EIC_3_unpol_rc['xs_err'])
T_RCerr_eic3 = np.asarray(df_T_eic3_unpol['unpol_rc_err'])
RC_Fs,RCerr_Fs=Get_error(F_Born_eic3,F_bnerr_eic3,F_RC_eic3,F_RCerr_eic3)
RC_Ts,RCerr_Ts=Get_error(T_Born_eic3,T_bnerr_eic3,T_RC_eic3,T_RCerr_eic3)
RC_ratios,RC_ratioerrs=Get_error(RC_Fs,RCerr_Fs,RC_Ts,RCerr_Ts)

ax1.fill_between(np.asarray(df_F_EIC_3_unpol_rc['qT_Q'].to_list()),np.asarray(RC_Fs)-np.asarray(RCerr_Fs),np.asarray(RC_Fs)+np.asarray(RCerr_Fs),color='red',alpha=0.25,linewidth=0)
ax1.fill_between(np.asarray(df_F_EIC_3_unpol_rc['qT_Q'].to_list()),np.asarray(RC_Ts)-np.asarray(RCerr_Ts),np.asarray(RC_Ts)+np.asarray(RCerr_Ts),color='blue',alpha=0.25,linewidth=0)
ax1.plot(np.asarray(df_F_EIC_3_unpol_rc['qT_Q'].to_list()),RC_Fs,color='red',label='Factorized')
ax1.plot(np.asarray(df_F_EIC_3_unpol_rc['qT_Q'].to_list()),RC_Ts,color='blue',label='Traditional')
ax1.set_xlabel('$qT/Q$',fontsize=16)
ax1.set_ylabel('RC',fontsize=16)
ax1.legend()
#fig1.savefig('results/compare/Fine/RCs_both_eic3.pdf')
ax2.fill_between(np.asarray(df_F_EIC_3_unpol_rc['qT_Q'].to_list()),np.asarray(RC_ratios)-np.asarray(RC_ratioerrs),np.asarray(RC_ratios)+np.asarray(RC_ratioerrs),color='black',alpha=0.25,linewidth=0)
ax2.plot(np.asarray(df_F_EIC_3_unpol_rc['qT_Q'].to_list()),RC_ratios,color='black')
ax2.set_xlabel('$qT/Q$',fontsize=16)
ax2.set_ylabel('$RC_F/RC_T$',fontsize=16)
#fig2.savefig('results/compare/Fine/compare_RC_unpol_eic3.pdf')

plt.figure()
F_Born_eic3 = np.asarray(df_F_EIC_3_unpol_bn['xs'])+np.asarray(df_F_EIC_3_siv_bn['xs'])+np.asarray(df_F_EIC_3_col_bn['xs'])
T_Born_eic3 = np.asarray(df_T_eic3_unpol['unpol_bn'])+np.asarray(df_T_eic3_unpol['sivers_bn'])+np.asarray(df_T_eic3_unpol['collins_bn'])
R_Born_eic3 = F_Born_eic3/T_Born_eic3
plt.plot(np.asarray(df_F_EIC_3_unpol_bn['qT_Q']),R_Born_eic3,color='b')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$R_{Born}$',fontsize=16)
plt.ylim(0.94,1.06)
plt.title('including both unpol and pol')
#plt.savefig('results/compare/Fine/compare_born_both_eic3.pdf')



plt.figure()
F_RC_eic3 = np.asarray(df_F_EIC_3_unpol_rc['xs'])+np.asarray(df_F_EIC_3_siv_rc['xs'])+np.asarray(df_F_EIC_3_col_rc['xs'])
T_RC_eic3 = np.asarray(df_T_eic3_unpol['unpol_rc'])+np.asarray(df_T_eic3_siv['sivers_rc'])+np.asarray(df_T_eic3_col['collins_rc'])
RC_F = (F_Born_eic3/F_RC_eic3)
RC_T = (T_Born_eic3/T_RC_eic3)
plt.plot(np.asarray(df_F_EIC_3_unpol_rc['qT_Q']),RC_F/RC_T,label='$RC_F/RC_T')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
#plt.ylim(0.9,1.2)
plt.title('including both unpol and pol')
#plt.savefig('results/compare/Fine/compare_RC_both_eic3.pdf')

plt.figure()
#supposed to be this, but sivleak is almost zero
#F_RC_eic3 = np.asarray(df_F_EIC_3_unpol_rc['xs'])+np.asarray(df_F_EIC_3_siv_rc['xs'])+np.asarray(df_F_EIC_3_sivleak_rc['xs'])+np.asarray(df_F_EIC_3_col_rc['xs'])+np.asarray(df_F_EIC_3_colleak_rc['xs'])
#T_RC_eic3 = np.asarray(df_T_eic3_unpol['unpol_rc'])+np.asarray(df_T_eic3_siv['sivers_rc'])+np.asarray(df_T_eic3_siv['collins_rc'])+np.asarray(df_T_eic3_col['collins_rc'])+np.asarray(df_T_eic3_siv['collins_rc'])
nlen = len(df_F_EIC_3_colleak_rc['xs'])
F_RC_eic3 = np.asarray(df_F_EIC_3_unpol_rc['xs'])[:nlen]+np.asarray(df_F_EIC_3_siv_rc['xs'])[:nlen]+np.asarray(df_F_EIC_3_col_rc['xs'])[:nlen]+np.asarray(df_F_EIC_3_colleak_rc['xs'])
T_RC_eic3 = np.asarray(df_T_eic3_unpol['unpol_rc'])+np.asarray(df_T_eic3_siv['sivers_rc'])+np.asarray(df_T_eic3_col['collins_rc'])+np.asarray(df_T_eic3_siv['collins_rc'])
RC_F = (F_Born_eic3[:nlen]/F_RC_eic3)
RC_T = (T_Born_eic3/T_RC_eic3)[:nlen]
plt.plot(np.asarray(df_F_EIC_3_unpol_rc['qT_Q'])[:nlen],RC_F/RC_T,label='$RC_F/RC_T')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
#plt.ylim(0.9,1.2)
plt.title('including both unpol and pol and leak')
plt.savefig('results/compare/Fine/compare_RC_both_leak_eic3.pdf')

# %%
plt.figure()

F_rc_colleak_EIC_3 = df_F_EIC_3_colleak_rc['xs'].to_list()
nlen_eic3 = len(df_F_EIC_3_colleak_rc['xs'])
T_rc_colleak_eic3 = df_T_eic3_siv['collins_rc'][:nlen_eic3].to_list()
T_bn_qtQ_eic3 = df_T_eic3_col['qt_to_Q'][:nlen_eic3].to_list()
T_bn_col_eic3 = df_T_eic3_col['collins_bn'][:nlen_eic3].to_list()
F_bn_qtQ_EIC_3 = df_F_EIC_3_col_bn['qT_Q'][:nlen_eic3].to_list()
F_bn_col_EIC_3 = df_F_EIC_3_col_bn['xs'][:nlen_eic3].to_list()
T_rc_qtQ_eic3 = df_T_eic3_col['qt_to_Q'][:nlen_eic3].to_list()
T_rc_col_eic3 = df_T_eic3_col['collins_rc'][:nlen_eic3].to_list()
F_rc_qtQ_EIC_3 = df_F_EIC_3_col_rc['qT_Q'][:nlen_eic3].to_list()
F_rc_col_EIC_3 = df_F_EIC_3_col_rc['xs'][:nlen_eic3].to_list()

RC_F_col_eic3 = np.asarray(F_bn_col_EIC_3)/(np.asarray(F_rc_col_EIC_3)+np.asarray(F_rc_colleak_EIC_3))
RC_T_col_eic3 = np.asarray(T_bn_col_eic3)/(np.asarray(T_rc_col_eic3)+np.asarray(T_rc_colleak_eic3))
plt.plot(T_bn_qtQ_eic3,RC_T_col_eic3,color='r',label='Traditional RC')
plt.plot(F_bn_qtQ_EIC_3,RC_F_col_eic3,color='b',label='Factorized RC')
plt.xlabel('qT/Q',fontsize =16)
plt.ylabel('RC from col',fontsize =16)
plt.legend()
plt.savefig('results/compare/Fine/RCs_col_both_eic3_withleak.pdf')


plt.figure()
RC_FT_col = RC_F_col_eic3/RC_T_col_eic3
plt.plot(T_bn_qtQ_eic3,RC_FT_col,label='col')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
plt.legend()
plt.ylim(0.9,1.2)
plt.savefig('results/compare/Fine/compare_RC_col_eic3_withleak.pdf')
