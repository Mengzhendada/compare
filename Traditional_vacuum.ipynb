# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
#    JLab 1: S=10.3 GeV2, Q=1.52 GeV, x=0.32, z=0.55
#    JLab 2: Eb=12 GeV, Q2=8 GeV2, x=0.48, z=0.375
#    JLab 3: Eb=24 GeV, Q2=15 GeV2, x=0.48, z=0.375
#    EIC 1: sqrt(S)=140 GeV, Q=3 GeV, y=0.4, z=0.5
#    EIC 2: sqrt(S)=140 GeV, Q=10 GeV, y=0.4, z=0.5
#    EIC 3: sqrt(S)=140 GeV, Q=5 GeV, x=0.01, z=0.5
#    qt_to_Q = PhT/x/Q

def Get_error(value1,error1,value2,error2):
    ratios=[]
    ratios_err=[]
    for i in range(0,len(value1)):
        ratio = value1[i]/value2[i]
        ratio_err = ratio*math.sqrt((error1[i]/value1[i])**2+(error2[i]/value2[i])**2)
        ratios.append(ratio)
        ratios_err.append(ratio_err)
    return ratios,ratios_err
    #return value1/value2,(value1/value2)*math.sqrt((error1/value1)**2+(error2/value2)**2)

# %%
df_Novac_eic3_unpol = pd.read_csv('results/Tra-results/results-fine/without-vac-pol/eic3-unpol.txt',delim_whitespace=True)
df_Novac_eic3_unpol.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_Novac_eic3_unpol.head()
df_Novac_eic3_siv = pd.read_csv('results/Tra-results/results-fine/without-vac-pol/eic3-siv.txt',delim_whitespace=True)
df_Novac_eic3_siv.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_Novac_eic3_siv.head()
df_Novac_eic3_col = pd.read_csv('results/Tra-results/results-fine/without-vac-pol/eic3-col.txt',delim_whitespace=True)
df_Novac_eic3_col.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_Novac_eic3_col.head()
# Out:
#     qt_to_Q  unpol_bn  unpol_bn_err  unpol_rc  unpol_rc_err     sivers_bn  \
# 0  0.050000       0.0           0.0       0.0           0.0 -2.335336e-13
# 1  0.059732       0.0           0.0       0.0           0.0 -2.730296e-13
# 2  0.069463       0.0           0.0       0.0           0.0 -3.098080e-13
# 3  0.079195       0.0           0.0       0.0           0.0 -3.435874e-13
# 4  0.088926       0.0           0.0       0.0           0.0 -3.737510e-13
#
#    sivers_bn_err     sivers_rc  sivers_rc_err    collins_bn  collins_bn_err  \
# 0   6.320409e-13  7.525863e-09   3.760097e-10  3.160314e-07    8.206669e-22
# 1   7.396788e-13  8.976017e-09   3.869016e-10  3.698522e-07    4.543231e-22
# 2   8.396008e-13  1.036149e-08   4.000867e-10  4.198150e-07    2.816222e-22
# 3   9.309126e-13  1.145287e-08   4.102046e-10  4.654724e-07    5.449051e-22
# 4   1.012867e-12  1.264114e-08   4.222469e-10  5.064509e-07    4.241573e-22
#
#      collins_rc  collins_rc_err
# ...

# %%
df_vac_eic3_unpol = pd.read_csv('results/Tra-results/results-fine/with-vac-pol/eic3-unpol.txt',delim_whitespace=True)
df_vac_eic3_unpol.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_vac_eic3_unpol.head()
df_vac_eic3_siv = pd.read_csv('results/Tra-results/results-fine/with-vac-pol/eic3-siv.txt',delim_whitespace=True)
df_vac_eic3_siv.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_vac_eic3_siv.head()
df_vac_eic3_col = pd.read_csv('results/Tra-results/results-fine/with-vac-pol/eic3-col.txt',delim_whitespace=True)
df_vac_eic3_col.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_vac_eic3_col.head()
# Out:
#     qt_to_Q  unpol_bn  unpol_bn_err  unpol_rc  unpol_rc_err     sivers_bn  \
# 0  0.050000       0.0           0.0       0.0           0.0 -2.335336e-13
# 1  0.059732       0.0           0.0       0.0           0.0 -2.730296e-13
# 2  0.069463       0.0           0.0       0.0           0.0 -3.098080e-13
# 3  0.079195       0.0           0.0       0.0           0.0 -3.435874e-13
# 4  0.088926       0.0           0.0       0.0           0.0 -3.737510e-13
#
#    sivers_bn_err     sivers_rc  sivers_rc_err    collins_bn  collins_bn_err  \
# 0   6.320409e-13  7.525849e-09   3.760098e-10  3.160314e-07    8.206669e-22
# 1   7.396788e-13  8.976000e-09   3.869016e-10  3.698522e-07    4.543231e-22
# 2   8.396008e-13  1.036148e-08   4.000868e-10  4.198150e-07    2.816222e-22
# 3   9.309126e-13  1.145285e-08   4.102047e-10  4.654724e-07    5.449051e-22
# 4   1.012867e-12  1.264111e-08   4.222470e-10  5.064509e-07    4.241573e-22
#
#      collins_rc  collins_rc_err
# ...

# %%
df_Novac_eic2_unpol = pd.read_csv('results/Tra-results/results-fine/without-vac-pol/e
#
#    sivers_bn_err     sivers_rc  sivers_rc_err    collins_bn  collins_bn_err  \
# 0   2.690789e-13  1.014509e-09   1.027368e-10  1.345441e-07    2.195126e-23
# 1   3.177401e-13  1.233860e-09   1.057959e-10  1.588755e-07    1.934628e-23
# 2   3.644923e-13  1.477930e-09   1.102541e-10  1.822525e-07    1.717848e-23
# 3   4.090762e-13  1.710661e-09   1.157045e-10  2.045452e-07    1.462104e-23
# 4   4.512543e-13  1.902223e-09   1.218717e-10  2.256350e-07    1.241682e-23
#
#      collins_rc  collins_rc_err
# ...

# %%
df_Novac_jlab2_unpol = pd.read_csv('results/Tra-results/results-fine/without-vac-pol/jlab2-unpol.txt',delim_whitespace=True)
df_Novac_jlab2_unpol.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_Novac_jlab2_unpol.head()
df_Novac_jlab2_siv = pd.read_csv('results/Tra-results/results-fine/without-vac-pol/jlab2-siv.txt',delim_whitespace=True)
df_Novac_jlab2_siv.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_Novac_jlab2_siv.head()
df_Novac_jlab2_col = pd.read_csv('results/Tra-results/results-fine/without-vac-pol/jlab2-col.txt',delim_whitespace=True)
df_Novac_jlab2_col.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_Novac_jlab2_col.head()
# Out:
#     qt_to_Q  unpol_bn  unpol_bn_err  unpol_rc  unpol_rc_err     sivers_bn  \
# 0  0.050000       0.0           0.0       0.0           0.0 -1.168907e-13
# 1  0.059732       0.0           0.0       0.0           0.0 -1.387847e-13
# 2  0.069463       0.0           0.0       0.0           0.0 -1.602315e-13
# 3  0.079195       0.0           0.0       0.0           0.0 -1.811643e-13
# 4  0.088926       0.0           0.0       0.0           0.0 -2.015195e-13
#
#    sivers_bn_err     sivers_rc  sivers_rc_err    collins_bn  collins_bn_err  \
# 0   3.169540e-13  5.009011e-10   1.044600e-10  1.584825e-07    3.179393e-23
# 1   3.763217e-13  6.217290e-10   1.092959e-10  1.881674e-07    2.590268e-23
# 2   4.344758e-13  8.006840e-10   1.137947e-10  2.172454e-07    2.282189e-23
# 3   4.912361e-13  9.437246e-10   1.196564e-10  2.456266e-07    2.006832e-23
# 4   5.464298e-13  1.112485e-09   1.261362e-10  2.732244e-07    1.794043e-23
#
#      collins_rc  collins_rc_err
# ...

# %%
df_vac_jlab2_unpol = pd.read_csv('results/Tra-results/results-fine/with-vac-pol/jlab2-unpol.txt',delim_whitespace=True)
df_vac_jlab2_unpol.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_vac_jlab2_unpol.head()
df_vac_jlab2_siv = pd.read_csv('results/Tra-results/results-fine/with-vac-pol/jlab2-siv.txt',delim_whitespace=True)
df_vac_jlab2_siv.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_vac_jlab2_siv.head()
df_vac_jlab2_col = pd.read_csv('results/Tra-results/results-fine/with-vac-pol/jlab2-col.txt',delim_whitespace=True)
df_vac_jlab2_col.columns=['qt_to_Q','unpol_bn','unpol_bn_err','unpol_rc','unpol_rc_err','sivers_bn','sivers_bn_err','sivers_rc','sivers_rc_err','collins_bn','collins_bn_err','collins_rc','collins_rc_err']
df_vac_jlab2_col.head()
# Out:
#     qt_to_Q  unpol_bn  unpol_bn_err  unpol_rc  unpol_rc_err     sivers_bn  \
# 0  0.050000       0.0           0.0       0.0           0.0 -1.168907e-13
# 1  0.059732       0.0           0.0       0.0           0.0 -1.387847e-13
# 2  0.069463       0.0           0.0       0.0           0.0 -1.602315e-13
# 3  0.079195       0.0           0.0       0.0           0.0 -1.811643e-13
# 4  0.088926       0.0           0.0       0.0           0.0 -2.015195e-13
#
#    sivers_bn_err     sivers_rc  sivers_rc_err    collins_bn  collins_bn_err  \
# 0   3.169540e-13  5.008954e-10   1.044600e-10  1.584825e-07    3.179393e-23
# 1   3.763217e-13  6.217221e-10   1.092959e-10  1.881674e-07    2.590268e-23
# 2   4.344758e-13  8.006761e-10   1.137948e-10  2.172454e-07    2.282189e-23
# 3   4.912361e-13  9.437156e-10   1.196565e-10  2.456266e-07    2.006832e-23
# 4   5.464298e-13  1.112475e-09   1.261363e-10  2.732244e-07    1.794043e-23
#
#      collins_rc  collins_rc_err
# ...

# %%
plt.plot(np.asarray(df_Novac_jlab2_unpol['qt_to_Q']),df_Novac_jlab2_unpol['unpol_bn'],color='b',label='without vac bn')
plt.plot(np.asarray(df_vac_jlab2_unpol['qt_to_Q']),df_vac_jlab2_unpol['unpol_bn'],color='r',label='with vac bn')
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('Unpol $d\sigma$',fontsize =16)
#plt.savefig('results/compare/Fine/Unpol_bn_vac_jlab2.pdf')

plt.figure()
plt.plot(np.asarray(df_Novac_jlab2_unpol['qt_to_Q']),df_Novac_jlab2_unpol['unpol_rc'],color='b',label='without vac rc')
plt.plot(np.asarray(df_vac_jlab2_unpol['qt_to_Q']),df_vac_jlab2_unpol['unpol_rc'],color='r',label='with vac rc')
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('Unpol $d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/Unpol_rc_vac_jlab2.pdf')

plt.figure()
plt.plot(np.asarray(df_Novac_jlab2_unpol['qt_to_Q']),np.asarray(df_Novac_jlab2_unpol['unpol_rc'])/np.asarray(df_vac_jlab2_unpol['unpol_rc']))
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('Unpol Novac/vac',fontsize =16)
plt.savefig('results/compare/Fine/Unpol_rc_Rvac_jlab2.pdf')
# Out:
# /var/folders/ll/8_2_l77j4yl2zjb6stl8d9b00000gn/T/ipykernel_7507/3859827218.py:17: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(np.asarray(df_Novac_jlab2_unpol['qt_to_Q']),np.asarray(df_Novac_jlab2_unpol['unpol_rc'])/np.asarray(df_vac_jlab2_unpol['unpol_rc']))

# %%
plt.plot(np.asarray(df_Novac_jlab2_siv['qt_to_Q']),df_Novac_jlab2_siv['sivers_bn'],color='b',label='without vac bn')
plt.plot(np.asarray(df_vac_jlab2_siv['qt_to_Q']),df_vac_jlab2_siv['sivers_bn'],color='r',label='with vac bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_bn_vac_jlab2.pdf')

plt.figure()
plt.plot(np.asarray(df_Novac_jlab2_siv['qt_to_Q']),df_Novac_jlab2_siv['sivers_rc'],color='b',label='without vac rc')
plt.plot(np.asarray(df_vac_jlab2_siv['qt_to_Q']),df_vac_jlab2_siv['sivers_rc'],color='r',label='with vac rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_rc_vac_jlab2.pdf')
plt.figure()
plt.plot(np.asarray(df_Novac_jlab2_siv['qt_to_Q']),np.asarray(df_Novac_jlab2_siv['sivers_rc'])/np.asarray(df_vac_jlab2_siv['sivers_rc']),color='k')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('siv novac/vac',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_rc_Rvac_jlab2.pdf')



plt.figure()
plt.plot(np.asarray(df_Novac_jlab2_col['qt_to_Q']),df_Novac_jlab2_col['collins_bn'],color='b',label='without vac bn')
plt.plot(np.asarray(df_vac_jlab2_col['qt_to_Q']),df_vac_jlab2_col['collins_bn'],color='r',label='with vac bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_bn_vac_jlab2.pdf')

plt.figure()
plt.plot(np.asarray(df_Novac_jlab2_col['qt_to_Q']),df_Novac_jlab2_col['collins_rc'],color='b',label='without vac rc')
plt.plot(np.asarray(df_vac_jlab2_col['qt_to_Q']),df_vac_jlab2_col['collins_rc'],color='r',label='with vac rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_rc_vac_jlab2.pdf')
plt.figure()
plt.plot(np.asarray(df_Novac_jlab2_col['qt_to_Q']),np.asarray(df_Novac_jlab2_col['collins_rc'])/np.asarray(df_vac_jlab2_col['collins_rc']),color='k')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('col novac/vac',fontsize =16)
plt.savefig('results/compare/Fine/justcol_rc_Rvac_jlab2.pdf')
# Out:
# /var/folders/ll/8_2_l77j4yl2zjb6stl8d9b00000gn/T/ipykernel_7507/434319391.py:18: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(np.asarray(df_Novac_jlab2_siv['qt_to_Q']),np.asarray(df_Novac_jlab2_siv['sivers_rc'])/np.asarray(df_vac_jlab2_siv['sivers_rc']),color='k')
# /var/folders/ll/8_2_l77j4yl2zjb6stl8d9b00000gn/T/ipykernel_7507/434319391.py:43: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(np.asarray(df_Novac_jlab2_col['qt_to_Q']),np.asarray(df_Novac_jlab2_col['collins_rc'])/np.asarray(df_vac_jlab2_col['collins_rc']),color='k')

# %%
plt.plot(np.asarray(df_Novac_jlab3_unpol['qt_to_Q']),df_Novac_jlab3_unpol['unpol_bn'],color='b',label='without vac bn')
plt.plot(np.asarray(df_vac_jlab3_unpol['qt_to_Q']),df_vac_jlab3_unpol['unpol_bn'],color='r',label='with vac bn')
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('Unpol $d\sigma$',fontsize =16)
#plt.savefig('results/compare/Fine/Unpol_bn_vac_jlab3.pdf')

plt.figure()
plt.plot(np.asarray(df_Novac_jlab3_unpol['qt_to_Q']),df_Novac_jlab3_unpol['unpol_rc'],color='b',label='without vac rc')
plt.plot(np.asarray(df_vac_jlab3_unpol['qt_to_Q']),df_vac_jlab3_unpol['unpol_rc'],color='r',label='with vac rc')
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('Unpol $d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/Unpol_rc_vac_jlab3.pdf')

plt.figure()
plt.plot(np.asarray(df_Novac_jlab3_unpol['qt_to_Q']),np.asarray(df_Novac_jlab3_unpol['unpol_rc'])/np.asarray(df_vac_jlab3_unpol['unpol_rc']))
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('Unpol Novac/vac',fontsize =16)
plt.savefig('results/compare/Fine/Unpol_rc_Rvac_jlab3.pdf')
# Out:
# /var/folders/ll/8_2_l77j4yl2zjb6stl8d9b00000gn/T/ipykernel_7507/314409546.py:17: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(np.asarray(df_Novac_jlab3_unpol['qt_to_Q']),np.asarray(df_Novac_jlab3_unpol['unpol_rc'])/np.asarray(df_vac_jlab3_unpol['unpol_rc']))

# %%
plt.plot(np.asarray(df_Novac_jlab3_siv['qt_to_Q']),df_Novac_jlab3_siv['sivers_bn'],color='b',label='without vac bn')
plt.plot(np.asarray(df_vac_jlab3_siv['qt_to_Q']),df_vac_jlab3_siv['sivers_bn'],color='r',label='with vac bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_bn_vac_jlab3.pdf')

plt.figure()
plt.plot(np.asarray(df_Novac_jlab3_siv['qt_to_Q']),df_Novac_jlab3_siv['sivers_rc'],color='b',label='without vac rc')
plt.plot(np.asarray(df_vac_jlab3_siv['qt_to_Q']),df_vac_jlab3_siv['sivers_rc'],color='r',label='with vac rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_rc_vac_jlab3.pdf')
plt.figure()
plt.plot(np.asarray(df_Novac_jlab3_siv['qt_to_Q']),np.asarray(df_Novac_jlab3_siv['sivers_rc'])/np.asarray(df_vac_jlab3_siv['sivers_rc']),color='k')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('siv novac/vac',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_rc_Rvac_jlab3.pdf')



plt.figure()
plt.plot(np.asarray(df_Novac_jlab3_col['qt_to_Q']),df_Novac_jlab3_col['collins_bn'],color='b',label='without vac bn')
plt.plot(np.asarray(df_vac_jlab3_col['qt_to_Q']),df_vac_jlab3_col['collins_bn'],color='r',label='with vac bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_bn_vac_jlab3.pdf')

plt.figure()
plt.plot(np.asarray(df_Novac_jlab3_col['qt_to_Q']),df_Novac_jlab3_col['collins_rc'],color='b',label='without vac rc')
plt.plot(np.asarray(df_vac_jlab3_col['qt_to_Q']),df_vac_jlab3_col['collins_rc'],color='r',label='with vac rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_rc_vac_jlab3.pdf')
plt.figure()
plt.plot(np.asarray(df_Novac_jlab3_col['qt_to_Q']),np.asarray(df_Novac_jlab3_col['collins_rc'])/np.asarray(df_vac_jlab3_col['collins_rc']),color='k')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('col novac/vac',fontsize =16)
plt.savefig('results/compare/Fine/justcol_rc_Rvac_jlab3.pdf')
# Out:
# /var/folders/ll/8_2_l77j4yl2zjb6stl8d9b00000gn/T/ipykernel_7507/3957756106.py:18: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(np.asarray(df_Novac_jlab3_siv['qt_to_Q']),np.asarray(df_Novac_jlab3_siv['sivers_rc'])/np.asarray(df_vac_jlab3_siv['sivers_rc']),color='k')
# /var/folders/ll/8_2_l77j4yl2zjb6stl8d9b00000gn/T/ipykernel_7507/3957756106.py:43: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(np.asarray(df_Novac_jlab3_col['qt_to_Q']),np.asarray(df_Novac_jlab3_col['collins_rc'])/np.asarray(df_vac_jlab3_col['collins_rc']),color='k')

# %%
plt.plot(np.asarray(df_Novac_eic1_unpol['qt_to_Q']),df_Novac_eic1_unpol['unpol_bn'],color='b',label='without vac bn')
plt.plot(np.asarray(df_vac_eic1_unpol['qt_to_Q']),df_vac_eic1_unpol['unpol_bn'],color='r',label='with vac bn')
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('Unpol $d\sigma$',fontsize =16)
#plt.savefig('results/compare/Fine/Unpol_bn_vac_eic1.pdf')

plt.figure()
plt.plot(np.asarray(df_Novac_eic1_unpol['qt_to_Q']),df_Novac_eic1_unpol['unpol_rc'],color='b',label='without vac rc')
plt.plot(np.asarray(df_vac_eic1_unpol['qt_to_Q']),df_vac_eic1_unpol['unpol_rc'],color='r',label='with vac rc')
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('Unpol $d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/Unpol_rc_vac_eic1.pdf')

plt.figure()
plt.plot(np.asarray(df_Novac_eic1_unpol['qt_to_Q']),np.asarray(df_Novac_eic1_unpol['unpol_rc'])/np.asarray(df_vac_eic1_unpol['unpol_rc']))
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('Unpol Novac/vac',fontsize =16)
plt.savefig('results/compare/Fine/Unpol_rc_Rvac_eic1.pdf')

# %%
plt.plot(np.asarray(df_Novac_eic1_siv['qt_to_Q']),df_Novac_eic1_siv['sivers_bn'],color='b',label='without vac bn')
plt.plot(np.asarray(df_vac_eic1_siv['qt_to_Q']),df_vac_eic1_siv['sivers_bn'],color='r',label='with vac bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_bn_vac_eic1.pdf')

plt.figure()
plt.plot(np.asarray(df_Novac_eic1_siv['qt_to_Q']),df_Novac_eic1_siv['sivers_rc'],color='b',label='without vac rc')
plt.plot(np.asarray(df_vac_eic1_siv['qt_to_Q']),df_vac_eic1_siv['sivers_rc'],color='r',label='with vac rc')
plt.plot(np.asarray(df_Novac_eic1_col['qt_to_Q']),df_Novac_eic1_col['sivers_rc'],color='b',linestyle=':',label='leak without vac rc')
plt.plot(np.asarray(df_vac_eic1_col['qt_to_Q']),df_vac_eic1_col['sivers_rc'],color='r',linestyle=':',label='leak with vac rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_rc_vac_eic1.pdf')
plt.figure()
plt.plot(np.asarray(df_Novac_eic1_siv['qt_to_Q']),np.asarray(df_Novac_eic1_siv['sivers_rc'])/np.asarray(df_vac_eic1_siv['sivers_rc']),color='k')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('siv novac/vac',fontsize =16)
plt.axhline(1,color = 'black',linestyle = ':')
plt.savefig('results/compare/Fine/justsiv_rc_Rvac_eic1.pdf')
plt.figure()
plt.plot(np.asarray(df_Novac_eic1_siv['qt_to_Q']),(np.asarray(df_Novac_eic1_siv['sivers_rc'])+np.asarray(df_Novac_eic1_col['sivers_rc']))/(np.asarray(df_vac_eic1_siv['sivers_rc'])+np.asarray(df_vac_eic1_col['sivers_rc'])),color='k')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('siv with leak novac/vac',fontsize =16)
plt.axhline(1,color = 'black',linestyle = ':')
plt.savefig('results/compare/Fine/justsiv_rc_Rvac_withleak_eic1.pdf')

plt.figure()
plt.plot(np.asarray(df_Novac_eic1_col['qt_to_Q']),df_Novac_eic1_col['collins_bn'],color='b',label='without vac bn')
plt.plot(np.asarray(df_vac_eic1_col['qt_to_Q']),df_vac_eic1_col['collins_bn'],color='r',label='with vac bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_bn_vac_eic1.pdf')

plt.figure()
plt.plot(np.asarray(df_Novac_eic1_col['qt_to_Q']),df_Novac_eic1_col['collins_rc'],color='b',label='without vac rc')
plt.plot(np.asarray(df_vac_eic1_col['qt_to_Q']),df_vac_eic1_col['collins_rc'],color='r',label='with vac rc')
plt.plot(np.asarray(df_Novac_eic1_siv['qt_to_Q']),df_Novac_eic1_siv['collins_rc'],color='b',linestyle=':',label='leak without vac rc')
plt.plot(np.asarray(df_vac_eic1_siv['qt_to_Q']),df_vac_eic1_siv['collins_rc'],color='r',linestyle=':',label='leak with vac rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_rc_vac_eic1.pdf')
plt.figure()
plt.plot(np.asarray(df_Novac_eic1_col['qt_to_Q']),np.asarray(df_Novac_eic1_col['collins_rc'])/np.asarray(df_vac_eic1_col['collins_rc']),color='k')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('col novac/vac',fontsize =16)
plt.axhline(1,color = 'black',linestyle = ':')
plt.savefig('results/compare/Fine/justcol_rc_Rvac_eic1.pdf')
plt.figure()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('col with leak novac/vac',fontsize =16)
plt.ylim(0.8,1.2)
plt.plot(np.asarray(df_Novac_eic1_col['qt_to_Q']),(np.asarray(df_Novac_eic1_col['collins_rc'])+np.asarray(df_Novac_eic1_siv['collins_rc']))/(np.asarray(df_vac_eic1_col['collins_rc'])+np.asarray(df_vac_eic1_siv['collins_rc'])),color='k')
plt.axhline(1,color = 'black',linestyle = ':')
plt.savefig('results/compare/Fine/justcol_rc_Rvac_withleak_eic1.pdf')

plt.figure()

plt.plot(np.asarray(df_Novac_eic1_siv['qt_to_Q']),np.asarray(df_Novac_eic1_siv['collins_rc'])/np.asarray(df_vac_eic1_siv['collins_rc']),color='b',linestyle=':')
plt.ylim(0.99,1.01)
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('col just leak novac/vac',fontsize =16)
# Out:
# Text(0, 0.5, 'col just leak novac/vac')

# %%
plt.plot(np.asarray(df_Novac_eic2_unpol['qt_to_Q']),df_Novac_eic2_unpol['unpol_bn'],color='b',label='without vac bn')
plt.plot(np.asarray(df_vac_eic2_unpol['qt_to_Q']),df_vac_eic2_unpol['unpol_bn'],color='r',label='with vac bn')
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('Unpol $d\sigma$',fontsize =16)
#plt.savefig('results/compare/Fine/Unpol_bn_vac_eic2.pdf')

plt.figure()
plt.plot(np.asarray(df_Novac_eic2_unpol['qt_to_Q']),df_Novac_eic2_unpol['unpol_rc'],color='b',label='without vac rc')
plt.plot(np.asarray(df_vac_eic2_unpol['qt_to_Q']),df_vac_eic2_unpol['unpol_rc'],color='r',label='with vac rc')
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('Unpol $d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/Unpol_rc_vac_eic2.pdf')

plt.figure()
plt.plot(np.asarray(df_Novac_eic2_unpol['qt_to_Q']),np.asarray(df_Novac_eic2_unpol['unpol_rc'])/np.asarray(df_vac_eic2_unpol['unpol_rc']))
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('Unpol Novac/vac',fontsize =16)
plt.savefig('results/compare/Fine/Unpol_rc_Rvac_eic2.pdf')

# %%
plt.plot(np.asarray(df_Novac_eic2_siv['qt_to_Q']),df_Novac_eic2_siv['sivers_bn'],color='b',label='without vac bn')
plt.plot(np.asarray(df_vac_eic2_siv['qt_to_Q']),df_vac_eic2_siv['sivers_bn'],color='r',label='with vac bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_bn_vac_eic2.pdf')

plt.figure()
plt.plot(np.asarray(df_Novac_eic2_siv['qt_to_Q']),df_Novac_eic2_siv['sivers_rc'],color='b',label='without vac rc')
plt.plot(np.asarray(df_vac_eic2_siv['qt_to_Q']),df_vac_eic2_siv['sivers_rc'],color='r',label='with vac rc')
plt.plot(np.asarray(df_Novac_eic2_col['qt_to_Q']),df_Novac_eic2_col['sivers_rc'],color='b',linestyle=':',label='leak without vac rc')
plt.plot(np.asarray(df_vac_eic2_col['qt_to_Q']),df_vac_eic2_col['sivers_rc'],color='r',linestyle=':',label='leak with vac rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_rc_vac_eic2.pdf')
plt.figure()
plt.plot(np.asarray(df_Novac_eic2_siv['qt_to_Q']),np.asarray(df_Novac_eic2_siv['sivers_rc'])/np.asarray(df_vac_eic2_siv['sivers_rc']),color='k')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('siv novac/vac',fontsize =16)
plt.axhline(1,color = 'black',linestyle = ':')
plt.savefig('results/compare/Fine/justsiv_rc_Rvac_eic2.pdf')
plt.figure()
plt.plot(np.asarray(df_Novac_eic2_siv['qt_to_Q']),(np.asarray(df_Novac_eic2_siv['sivers_rc'])+np.asarray(df_Novac_eic2_col['sivers_rc']))/(np.asarray(df_vac_eic2_siv['sivers_rc'])+np.asarray(df_vac_eic2_col['sivers_rc'])),color='k')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('siv with leak novac/vac',fontsize =16)
plt.axhline(1,color = 'black',linestyle = ':')
plt.savefig('results/compare/Fine/justsiv_rc_Rvac_withleak_eic2.pdf')

plt.figure()
plt.plot(np.asarray(df_Novac_eic2_col['qt_to_Q']),df_Novac_eic2_col['collins_bn'],color='b',label='without vac bn')
plt.plot(np.asarray(df_vac_eic2_col['qt_to_Q']),df_vac_eic2_col['collins_bn'],color='r',label='with vac bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_bn_vac_eic2.pdf')

plt.figure()
plt.plot(np.asarray(df_Novac_eic2_col['qt_to_Q']),df_Novac_eic2_col['collins_rc'],color='b',label='without vac rc')
plt.plot(np.asarray(df_vac_eic2_col['qt_to_Q']),df_vac_eic2_col['collins_rc'],color='r',label='with vac rc')
plt.plot(np.asarray(df_Novac_eic2_siv['qt_to_Q']),df_Novac_eic2_siv['collins_rc'],color='b',linestyle=':',label='leak without vac rc')
plt.plot(np.asarray(df_vac_eic2_siv['qt_to_Q']),df_vac_eic2_siv['collins_rc'],color='r',linestyle=':',label='leak with vac rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_rc_vac_eic2.pdf')
plt.figure()
plt.plot(np.asarray(df_Novac_eic2_col['qt_to_Q']),np.asarray(df_Novac_eic2_col['collins_rc'])/np.asarray(df_vac_eic2_col['collins_rc']),color='k')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('col novac/vac',fontsize =16)
plt.axhline(1,color = 'black',linestyle = ':')
plt.savefig('results/compare/Fine/justcol_rc_Rvac_eic2.pdf')
plt.figure()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('col with leak novac/vac',fontsize =16)
plt.ylim(0.8,1.2)
plt.plot(np.asarray(df_Novac_eic2_col['qt_to_Q']),(np.asarray(df_Novac_eic2_col['collins_rc'])+np.asarray(df_Novac_eic2_siv['collins_rc']))/(np.asarray(df_vac_eic2_col['collins_rc'])+np.asarray(df_vac_eic2_siv['collins_rc'])),color='k')
plt.axhline(1,color = 'black',linestyle = ':')
plt.savefig('results/compare/Fine/justcol_rc_Rvac_withleak_eic2.pdf')

plt.figure()

plt.plot(np.asarray(df_Novac_eic2_siv['qt_to_Q']),np.asarray(df_Novac_eic2_siv['collins_rc'])/np.asarray(df_vac_eic2_siv['collins_rc']),color='b',linestyle=':')
plt.ylim(0.99,1.01)
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('col just leak novac/vac',fontsize =16)
# Out:
# Text(0, 0.5, 'col just leak novac/vac')

# %%
plt.plot(np.asarray(df_Novac_eic3_unpol['qt_to_Q']),df_Novac_eic3_unpol['unpol_bn'],color='b',label='without vac bn')
plt.plot(np.asarray(df_vac_eic3_unpol['qt_to_Q']),df_vac_eic3_unpol['unpol_bn'],color='r',label='with vac bn')
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('Unpol $d\sigma$',fontsize =16)
#plt.savefig('results/compare/Fine/Unpol_bn_vac_eic3.pdf')

plt.figure()
plt.plot(np.asarray(df_Novac_eic3_unpol['qt_to_Q']),df_Novac_eic3_unpol['unpol_rc'],color='b',label='without vac rc')
plt.plot(np.asarray(df_vac_eic3_unpol['qt_to_Q']),df_vac_eic3_unpol['unpol_rc'],color='r',label='with vac rc')
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('Unpol $d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/Unpol_rc_vac_eic3.pdf')

plt.figure()
plt.plot(np.asarray(df_Novac_eic3_unpol['qt_to_Q']),np.asarray(df_Novac_eic3_unpol['unpol_rc'])/np.asarray(df_vac_eic3_unpol['unpol_rc']))
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('Unpol Novac/vac',fontsize =16)
plt.savefig('results/compare/Fine/Unpol_rc_Rvac_eic3.pdf')

# %%
plt.plot(np.asarray(df_Novac_eic3_siv['qt_to_Q']),df_Novac_eic3_siv['sivers_bn'],color='b',label='without vac bn')
plt.plot(np.asarray(df_vac_eic3_siv['qt_to_Q']),df_vac_eic3_siv['sivers_bn'],color='r',label='with vac bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_bn_vac_eic3.pdf')

plt.figure()
plt.plot(np.asarray(df_Novac_eic3_siv['qt_to_Q']),df_Novac_eic3_siv['sivers_rc'],color='b',label='without vac rc')
plt.plot(np.asarray(df_vac_eic3_siv['qt_to_Q']),df_vac_eic3_siv['sivers_rc'],color='r',label='with vac rc')
plt.plot(np.asarray(df_Novac_eic3_col['qt_to_Q']),df_Novac_eic3_col['sivers_rc'],color='b',linestyle=':',label='leak without vac rc')
plt.plot(np.asarray(df_vac_eic3_col['qt_to_Q']),df_vac_eic3_col['sivers_rc'],color='r',linestyle=':',label='leak with vac rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justsiv_rc_vac_eic3.pdf')
plt.figure()
plt.plot(np.asarray(df_Novac_eic3_siv['qt_to_Q']),np.asarray(df_Novac_eic3_siv['sivers_rc'])/np.asarray(df_vac_eic3_siv['sivers_rc']),color='k')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('siv novac/vac',fontsize =16)
plt.axhline(1,color = 'black',linestyle = ':')
plt.savefig('results/compare/Fine/justsiv_rc_Rvac_eic3.pdf')
plt.figure()
plt.plot(np.asarray(df_Novac_eic3_siv['qt_to_Q']),(np.asarray(df_Novac_eic3_siv['sivers_rc'])+np.asarray(df_Novac_eic3_col['sivers_rc']))/(np.asarray(df_vac_eic3_siv['sivers_rc'])+np.asarray(df_vac_eic3_col['sivers_rc'])),color='k')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('siv with leak novac/vac',fontsize =16)
plt.axhline(1,color = 'black',linestyle = ':')
plt.savefig('results/compare/Fine/justsiv_rc_Rvac_withleak_eic3.pdf')

plt.figure()
plt.plot(np.asarray(df_Novac_eic3_col['qt_to_Q']),df_Novac_eic3_col['collins_bn'],color='b',label='without vac bn')
plt.plot(np.asarray(df_vac_eic3_col['qt_to_Q']),df_vac_eic3_col['collins_bn'],color='r',label='with vac bn')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_bn_vac_eic3.pdf')

plt.figure()
plt.plot(np.asarray(df_Novac_eic3_col['qt_to_Q']),df_Novac_eic3_col['collins_rc'],color='b',label='without vac rc')
plt.plot(np.asarray(df_vac_eic3_col['qt_to_Q']),df_vac_eic3_col['collins_rc'],color='r',label='with vac rc')
plt.plot(np.asarray(df_Novac_eic3_siv['qt_to_Q']),df_Novac_eic3_siv['collins_rc'],color='b',linestyle=':',label='leak without vac rc')
plt.plot(np.asarray(df_vac_eic3_siv['qt_to_Q']),df_vac_eic3_siv['collins_rc'],color='r',linestyle=':',label='leak with vac rc')
#plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/Fine/justcol_rc_vac_eic3.pdf')
plt.figure()
plt.plot(np.asarray(df_Novac_eic3_col['qt_to_Q']),np.asarray(df_Novac_eic3_col['collins_rc'])/np.asarray(df_vac_eic3_col['collins_rc']),color='k')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('col novac/vac',fontsize =16)
plt.axhline(1,color = 'black',linestyle = ':')
plt.savefig('results/compare/Fine/justcol_rc_Rvac_eic3.pdf')
plt.figure()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('col with leak novac/vac',fontsize =16)
plt.ylim(0.8,1.2)
plt.plot(np.asarray(df_Novac_eic3_col['qt_to_Q']),(np.asarray(df_Novac_eic3_col['collins_rc'])+np.asarray(df_Novac_eic3_siv['collins_rc']))/(np.asarray(df_vac_eic3_col['collins_rc'])+np.asarray(df_vac_eic3_siv['collins_rc'])),color='k')
plt.axhline(1,color = 'black',linestyle = ':')
plt.savefig('results/compare/Fine/justcol_rc_Rvac_withleak_eic3.pdf')

plt.figure()

plt.plot(np.asarray(df_Novac_eic3_siv['qt_to_Q']),np.asarray(df_Novac_eic3_siv['collins_rc'])/np.asarray(df_vac_eic3_siv['collins_rc']),color='b',linestyle=':')
plt.ylim(0.99,1.01)
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('col just leak novac/vac',fontsize =16)
# Out:
# Text(0, 0.5, 'col just leak novac/vac')
