# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
columns_name = ['x','z','Q','qT_Q','xs','xs_err']
df_F_JLab_2_unpol_rc = pd.read_csv('results/Fac-results/Fine/JLab_2_unpol_rc.txt',delim_whitespace=True,names=columns_name)
df_F_JLab2_zeta_s95_xi_all = pd.read_csv('results/Fac-results/zeta_xi_check/JLab_2_unpol_rc_zeta_s95_xi_all.txt',delim_whitespace=True,names=columns_name)
print(df_F_JLab2_zeta_s95_xi_all.head())
df_F_JLab2_zeta_g95_xi_all = pd.read_csv('results/Fac-results/zeta_xi_check/JLab_2_unpol_rc_zeta_g95_xi_all.txt',delim_whitespace=True,names=columns_name)
print(df_F_JLab2_zeta_g95_xi_all.head())
df_F_JLab2_zeta_s98_xi_all = pd.read_csv('results/Fac-results/zeta_xi_check/JLab_2_unpol_rc_zeta_s98_xi_all.txt',delim_whitespace=True,names=columns_name)
print(df_F_JLab2_zeta_s98_xi_all.head())
df_F_JLab2_zeta_g98_xi_all = pd.read_csv('results/Fac-results/zeta_xi_check/JLab_2_unpol_rc_zeta_g98_xi_all.txt',delim_whitespace=True,names=columns_name)
print(df_F_JLab2_zeta_g98_xi_all.head())
df_F_JLab2_zeta_s95_xi_1 = pd.read_csv('results/Fac-results/zeta_xi_check/JLab_2_unpol_rc_zeta_s95_xi_1.txt',delim_whitespace=True,names=columns_name)
print(df_F_JLab2_zeta_s95_xi_1.head())
df_F_JLab2_zeta_g95_xi_1 = pd.read_csv('results/Fac-results/zeta_xi_check/JLab_2_unpol_rc_zeta_g95_xi_1.txt',delim_whitespace=True,names=columns_name)
print(df_F_JLab2_zeta_g95_xi_1.head())
df_F_JLab2_zeta_s98_xi_1 = pd.read_csv('results/Fac-results/zeta_xi_check/JLab_2_unpol_rc_zeta_s98_xi_1.txt',delim_whitespace=True,names=columns_name)
print(df_F_JLab2_zeta_s98_xi_1.head())
df_F_JLab2_zeta_g98_xi_1 = pd.read_csv('results/Fac-results/zeta_xi_check/JLab_2_unpol_rc_zeta_g98_xi_1.txt',delim_whitespace=True,names=columns_name)
print(df_F_JLab2_zeta_g98_xi_1.head())
# Out:
#       x      z         Q      qT_Q        xs        xs_err
# 0  0.48  0.375  2.828427  0.050000  0.000003  1.612163e-09
# 1  0.48  0.375  2.828427  0.059732  0.000003  3.073042e-09
# 2  0.48  0.375  2.828427  0.069463  0.000003  2.959908e-09
# 3  0.48  0.375  2.828427  0.079195  0.000003  2.442936e-09
# 4  0.48  0.375  2.828427  0.088926  0.000003  3.144247e-09
#       x      z         Q      qT_Q        xs        xs_err
# 0  0.48  0.375  2.828427  0.050000  0.000073  6.717410e-10
# 1  0.48  0.375  2.828427  0.059732  0.000072  5.144209e-10
# 2  0.48  0.375  2.828427  0.069463  0.000072  6.328721e-10
# 3  0.48  0.375  2.828427  0.079195  0.000071  1.126221e-09
# 4  0.48  0.375  2.828427  0.088926  0.000071  7.507651e-10
#       x      z         Q      qT_Q        xs        xs_err
# 0  0.48  0.375  2.828427  0.050000  0.000006  6.789215e-09
# 1  0.48  0.375  2.828427  0.059732  0.000006  6.635718e-09
# 2  0.48  0.375  2.828427  0.069463  0.000006  7.382076e-09
# ...

# %%
columns_name = ['x','z','Q','qT_Q','xs','xs_err']
df_F_JLab_3_unpol_rc = pd.read_csv('results/Fac-results/Fine/JLab_3_unpol_rc.txt',delim_whitespace=True,names=columns_name)
df_F_JLab3_zeta_s95_xi_all = pd.read_csv('results/Fac-results/zeta_xi_check/JLab_3_unpol_rc_zeta_s95_xi_all.txt',delim_whitespace=True,names=columns_name)
print(df_F_JLab3_zeta_s95_xi_all.head())
df_F_JLab3_zeta_g95_xi_all = pd.read_csv('results/Fac-results/zeta_xi_check/JLab_3_unpol_rc_zeta_g95_xi_all.txt',delim_whitespace=True,names=columns_name)
print(df_F_JLab3_zeta_g95_xi_all.head())
df_F_JLab3_zeta_s98_xi_all = pd.read_csv('results/Fac-results/zeta_xi_check/JLab_3_unpol_rc_zeta_s98_xi_all.txt',delim_whitespace=True,names=columns_name)
print(df_F_JLab3_zeta_s98_xi_all.head())
df_F_JLab3_zeta_g98_xi_all = pd.read_csv('results/Fac-results/zeta_xi_check/JLab_3_unpol_rc_zeta_g98_xi_all.txt',delim_whitespace=True,names=columns_name)
print(df_F_JLab3_zeta_g98_xi_all.head())
df_F_JLab3_zeta_s95_xi_1 = pd.read_csv('results/Fac-results/zeta_xi_check/JLab_3_unpol_rc_zeta_s95_xi_1.txt',delim_whitespace=True,names=columns_name)
print(df_F_JLab3_zeta_s95_xi_1.head())
df_F_JLab3_zeta_g95_xi_1 = pd.read_csv('results/Fac-results/zeta_xi_check/JLab_3_unpol_rc_zeta_g95_xi_1.txt',delim_whitespace=True,names=columns_name)
print(df_F_JLab3_zeta_g95_xi_1.head())
df_F_JLab3_zeta_s98_xi_1 = pd.read_csv('results/Fac-results/zeta_xi_check/JLab_3_unpol_rc_zeta_s98_xi_1.txt',delim_whitespace=True,names=columns_name)
print(df_F_JLab3_zeta_s98_xi_1.head())
df_F_JLab3_zeta_g98_xi_1 = pd.read_csv('results/Fac-results/zeta_xi_check/JLab_3_unpol_rc_zeta_g98_xi_1.txt',delim_whitespace=True,names=columns_name)
print(df_F_JLab3_zeta_g98_xi_1.head())
# Out:
#       x      z         Q      qT_Q        xs        xs_err
# 0  0.48  0.375  3.872983  0.050000  0.000001  1.240288e-09
# 1  0.48  0.375  3.872983  0.059732  0.000001  1.484672e-09
# 2  0.48  0.375  3.872983  0.069463  0.000001  8.426013e-10
# 3  0.48  0.375  3.872983  0.079195  0.000001  1.434810e-09
# 4  0.48  0.375  3.872983  0.088926  0.000001  1.062367e-09
#       x      z         Q      qT_Q        xs        xs_err
# 0  0.48  0.375  3.872983  0.050000  0.000035  2.863817e-10
# 1  0.48  0.375  3.872983  0.059732  0.000034  4.828523e-10
# 2  0.48  0.375  3.872983  0.069463  0.000034  6.965614e-10
# 3  0.48  0.375  3.872983  0.079195  0.000034  5.453181e-10
# 4  0.48  0.375  3.872983  0.088926  0.000033  8.998390e-10
#       x      z         Q      qT_Q        xs        xs_err
# 0  0.48  0.375  3.872983  0.050000  0.000003  3.076540e-09
# 1  0.48  0.375  3.872983  0.059732  0.000003  3.134566e-09
# 2  0.48  0.375  3.872983  0.069463  0.000003  4.510800e-09
# ...

# %%
columns_name = ['x','z','Q','qT_Q','xs','xs_err']
df_F_EIC1_unpol_rc = pd.read_csv('results/Fac-results/Fine/EIC_1_unpol_rc.txt',delim_whitespace=True,names=columns_name)
df_F_EIC1_zeta_s95_xi_all = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_1_unpol_rc_zeta_s95_xi_all.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC1_zeta_s95_xi_all.head())
df_F_EIC1_zeta_g95_xi_all = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_1_unpol_rc_zeta_g95_xi_all.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC1_zeta_g95_xi_all.head())
df_F_EIC1_zeta_s98_xi_all = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_1_unpol_rc_zeta_s98_xi_all.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC1_zeta_s98_xi_all.head())
df_F_EIC1_zeta_g98_xi_all = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_1_unpol_rc_zeta_g98_xi_all.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC1_zeta_g98_xi_all.head())
df_F_EIC1_zeta_s95_xi_1 = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_1_unpol_rc_zeta_s95_xi_1.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC1_zeta_s95_xi_1.head())
df_F_EIC1_zeta_g95_xi_1 = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_1_unpol_rc_zeta_g95_xi_1.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC1_zeta_g95_xi_1.head())
df_F_EIC1_zeta_s98_xi_1 = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_1_unpol_rc_zeta_s98_xi_1.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC1_zeta_s98_xi_1.head())
df_F_EIC1_zeta_g98_xi_1 = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_1_unpol_rc_zeta_g98_xi_1.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC1_zeta_g98_xi_1.head())
# Out:
#           x    z    Q      qT_Q        xs        xs_err
# 0  0.001148  0.5  3.0  0.050000  0.001528  1.073358e-06
# 1  0.001148  0.5  3.0  0.059732  0.001523  1.174423e-06
# 2  0.001148  0.5  3.0  0.069463  0.001513  1.291917e-06
# 3  0.001148  0.5  3.0  0.079195  0.001501  6.329196e-07
# 4  0.001148  0.5  3.0  0.088926  0.001490  7.831858e-07
#           x    z    Q      qT_Q        xs        xs_err
# 0  0.001148  0.5  3.0  0.050000  0.065136  5.920050e-07
# 1  0.001148  0.5  3.0  0.059732  0.064547  8.084813e-07
# 2  0.001148  0.5  3.0  0.069463  0.063859  8.648367e-07
# 3  0.001148  0.5  3.0  0.079195  0.063074  1.116669e-06
# 4  0.001148  0.5  3.0  0.088926  0.062200  6.216791e-07
#           x    z    Q      qT_Q        xs    xs_err
# 0  0.001148  0.5  3.0  0.050000  0.004199  0.000006
# 1  0.001148  0.5  3.0  0.059732  0.004165  0.000004
# 2  0.001148  0.5  3.0  0.069463  0.004135  0.000005
# 3  0.001148  0.5  3.0  0.079195  0.004091  0.000004
# ...

# %%
columns_name = ['x','z','Q','qT_Q','xs','xs_err']
df_F_EIC2_unpol_rc = pd.read_csv('results/Fac-results/Fine/EIC_2_unpol_rc.txt',delim_whitespace=True,names=columns_name)
df_F_EIC2_zeta_s95_xi_all = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_2_unpol_rc_zeta_s95_xi_all.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC2_zeta_s95_xi_all.head())
df_F_EIC2_zeta_g95_xi_all = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_2_unpol_rc_zeta_g95_xi_all.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC2_zeta_g95_xi_all.head())
df_F_EIC2_zeta_s98_xi_all = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_2_unpol_rc_zeta_s98_xi_all.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC2_zeta_s98_xi_all.head())
df_F_EIC2_zeta_g98_xi_all = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_2_unpol_rc_zeta_g98_xi_all.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC2_zeta_g98_xi_all.head())
df_F_EIC2_zeta_s95_xi_1 = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_2_unpol_rc_zeta_s95_xi_1.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC2_zeta_s95_xi_1.head())
df_F_EIC2_zeta_g95_xi_1 = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_2_unpol_rc_zeta_g95_xi_1.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC2_zeta_g95_xi_1.head())
df_F_EIC2_zeta_s98_xi_1 = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_2_unpol_rc_zeta_s98_xi_1.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC2_zeta_s98_xi_1.head())
df_F_EIC2_zeta_g98_xi_1 = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_2_unpol_rc_zeta_g98_xi_1.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC2_zeta_g98_xi_1.head())
# Out:
#           x    z     Q      qT_Q        xs        xs_err
# 0  0.012755  0.5  10.0  0.050000  0.000001  2.117269e-09
# 1  0.012755  0.5  10.0  0.059732  0.000001  2.332147e-09
# 2  0.012755  0.5  10.0  0.069463  0.000001  3.483391e-09
# 3  0.012755  0.5  10.0  0.079195  0.000001  4.878719e-09
# 4  0.012755  0.5  10.0  0.088926  0.000002  4.488835e-09
#           x    z     Q      qT_Q        xs        xs_err
# 0  0.012755  0.5  10.0  0.050000  0.000274  2.336417e-08
# 1  0.012755  0.5  10.0  0.059732  0.000248  2.805883e-08
# 2  0.012755  0.5  10.0  0.069463  0.000221  3.022946e-08
# 3  0.012755  0.5  10.0  0.079195  0.000193  2.647351e-08
# 4  0.012755  0.5  10.0  0.088926  0.000166  2.803053e-08
#           x    z     Q      qT_Q        xs        xs_err
# 0  0.012755  0.5  10.0  0.050000  0.000010  1.399943e-08
# 1  0.012755  0.5  10.0  0.059732  0.000010  1.732395e-08
# 2  0.012755  0.5  10.0  0.069463  0.000009  1.331290e-08
# ...

# %%
columns_name = ['x','z','Q','qT_Q','xs','xs_err']
df_F_EIC3_unpol_rc = pd.read_csv('results/Fac-results/Fine/EIC_3_unpol_rc.txt',delim_whitespace=True,names=columns_name)
df_F_EIC3_zeta_s95_xi_all = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_3_unpol_rc_zeta_s95_xi_all.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC3_zeta_s95_xi_all.head())
df_F_EIC3_zeta_g95_xi_all = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_3_unpol_rc_zeta_g95_xi_all.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC3_zeta_g95_xi_all.head())
df_F_EIC3_zeta_s98_xi_all = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_3_unpol_rc_zeta_s98_xi_all.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC3_zeta_s98_xi_all.head())
df_F_EIC3_zeta_g98_xi_all = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_3_unpol_rc_zeta_g98_xi_all.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC3_zeta_g98_xi_all.head())
df_F_EIC3_zeta_s95_xi_1 = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_3_unpol_rc_zeta_s95_xi_1.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC3_zeta_s95_xi_1.head())
df_F_EIC3_zeta_g95_xi_1 = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_3_unpol_rc_zeta_g95_xi_1.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC3_zeta_g95_xi_1.head())
df_F_EIC3_zeta_s98_xi_1 = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_3_unpol_rc_zeta_s98_xi_1.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC3_zeta_s98_xi_1.head())
df_F_EIC3_zeta_g98_xi_1 = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_3_unpol_rc_zeta_g98_xi_1.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC3_zeta_g98_xi_1.head())
# Out:
#       x    z    Q      qT_Q            xs        xs_err
# 0  0.01  0.5  5.0  0.050000  1.690427e-08  2.297981e-11
# 1  0.01  0.5  5.0  0.059732  1.795531e-08  2.061183e-11
# 2  0.01  0.5  5.0  0.069463  1.920786e-08  2.474323e-11
# 3  0.01  0.5  5.0  0.079195  2.069582e-08  4.023593e-11
# 4  0.01  0.5  5.0  0.088926  2.248121e-08  3.843993e-11
#       x    z    Q      qT_Q        xs        xs_err
# 0  0.01  0.5  5.0  0.050000  0.006570  3.171919e-07
# 1  0.01  0.5  5.0  0.059732  0.006409  2.943110e-07
# 2  0.01  0.5  5.0  0.069463  0.006225  2.239165e-07
# 3  0.01  0.5  5.0  0.079195  0.006018  2.750343e-07
# 4  0.01  0.5  5.0  0.088926  0.005795  3.347903e-07
#       x    z    Q      qT_Q        xs        xs_err
# 0  0.01  0.5  5.0  0.050000  0.000038  4.231259e-08
# 1  0.01  0.5  5.0  0.059732  0.000038  5.364460e-08
# 2  0.01  0.5  5.0  0.069463  0.000038  2.550875e-08
# 3  0.01  0.5  5.0  0.079195  0.000038  5.297844e-08
# 4  0.01  0.5  5.0  0.088926  0.000038  4.388860e-08
# ...

# %%
plt.plot(np.asarray(df_F_JLab_2_unpol_rc['qT_Q']),df_F_JLab_2_unpol_rc['xs'],color='r',label='Factorized rc')
plt.plot(np.asarray(df_F_JLab_2_unpol_rc['qT_Q']),df_F_JLab2_zeta_s95_xi_all['xs'],color='b',linestyle='-.',label=r'$\zeta:[0,0.95]$')
plt.plot(np.asarray(df_F_JLab_2_unpol_rc['qT_Q']),df_F_JLab2_zeta_g95_xi_all['xs'],color='b',linestyle=':',label=r'$\zeta:[0.95,1]$')
plt.plot(np.asarray(df_F_JLab_2_unpol_rc['qT_Q']),np.asarray(df_F_JLab2_zeta_g95_xi_all['xs'])+np.asarray(df_F_JLab2_zeta_s95_xi_all['xs']),color='b',linestyle='-',label=r'$\zeta:[0,1]$')
plt.plot(np.asarray(df_F_JLab_2_unpol_rc['qT_Q']),df_F_JLab2_zeta_s98_xi_all['xs'],color='m',linestyle='-.',label=r'$\zeta:[0,0.98]$')
plt.plot(np.asarray(df_F_JLab_2_unpol_rc['qT_Q']),df_F_JLab2_zeta_g98_xi_all['xs'],color='m',linestyle=':',label=r'$\zeta:[0.98,1]$')
plt.plot(np.asarray(df_F_JLab_2_unpol_rc['qT_Q']),np.asarray(df_F_JLab2_zeta_g98_xi_all['xs'])+np.asarray(df_F_JLab2_zeta_s98_xi_all['xs']),color='m',linestyle='-',label=r'$\zeta:[0,1]$')
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$d\sigma$',fontsize =16)
plt.savefig('results/compare/Fac_check/JLab2_Fac_check.pdf')

plt.figure()
plt.plot(np.asarray(df_F_JLab_2_unpol_rc['qT_Q']),np.asarray(df_F_JLab_2_unpol_rc['xs'])/(np.asarray(df_F_JLab2_zeta_g95_xi_all['xs'])+np.asarray(df_F_JLab2_zeta_s95_xi_all['xs'])),color='b',label=r'$\zeta_c=0.95$')
plt.plot(np.asarray(df_F_JLab_2_unpol_rc['qT_Q']),np.asarray(df_F_JLab_2_unpol_rc['xs'])/(np.asarray(df_F_JLab2_zeta_g98_xi_all['xs'])+np.asarray(df_F_JLab2_zeta_s98_xi_all['xs'])),color='m',label=r'$\zeta_c=0.98$')
plt.ylim(0.9,1.1)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel(r'$\frac{d\sigma(\zeta:[0,1])}{(d\sigma(\zeta[0,\zeta_c])+d\sigma(\zeta[\zeta_c,1]))}$',fontsize =16)
plt.savefig('results/compare/Fac_check/JLab2_Fac_ratio.pdf')

plt.figure()

# %%
plt.plot(np.asarray(df_F_JLab_3_unpol_rc['qT_Q']),df_F_JLab_3_unpol_rc['xs'],color='r',label='Factorized rc')
plt.plot(np.asarray(df_F_JLab_3_unpol_rc['qT_Q']),df_F_JLab3_zeta_s95_xi_all['xs'],color='b',linestyle='-.',label=r'$\zeta:[0,0.95]$')
plt.plot(np.asarray(df_F_JLab_3_unpol_rc['qT_Q']),df_F_JLab3_zeta_g95_xi_all['xs'],color='b',linestyle=':',label=r'$\zeta:[0.95,1]$')
plt.plot(np.asarray(df_F_JLab_3_unpol_rc['qT_Q']),np.asarray(df_F_JLab3_zeta_g95_xi_all['xs'])+np.asarray(df_F_JLab3_zeta_s95_xi_all['xs']),color='b',linestyle='-',label=r'$\zeta:[0,1]$')
plt.plot(np.asarray(df_F_JLab_3_unpol_rc['qT_Q']),df_F_JLab3_zeta_s98_xi_all['xs'],color='m',linestyle='-.',label=r'$\zeta:[0,0.98]$')
plt.plot(np.asarray(df_F_JLab_3_unpol_rc['qT_Q']),df_F_JLab3_zeta_g98_xi_all['xs'],color='m',linestyle=':',label=r'$\zeta:[0.98,1]$')
plt.plot(np.asarray(df_F_JLab_3_unpol_rc['qT_Q']),np.asarray(df_F_JLab3_zeta_g98_xi_all['xs'])+np.asarray(df_F_JLab3_zeta_s98_xi_all['xs']),color='m',linestyle='-',label=r'$\zeta:[0,1]$')
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$d\sigma$',fontsize =16)
plt.savefig('results/compare/Fac_check/JLab3_Fac_check.pdf')

plt.figure()
plt.plot(np.asarray(df_F_JLab_3_unpol_rc['qT_Q']),np.asarray(df_F_JLab_3_unpol_rc['xs'])/(np.asarray(df_F_JLab3_zeta_g95_xi_all['xs'])+np.asarray(df_F_JLab3_zeta_s95_xi_all['xs'])),color='b',label=r'$\zeta_c=0.95$')
plt.plot(np.asarray(df_F_JLab_3_unpol_rc['qT_Q']),np.asarray(df_F_JLab_3_unpol_rc['xs'])/(np.asarray(df_F_JLab3_zeta_g98_xi_all['xs'])+np.asarray(df_F_JLab3_zeta_s98_xi_all['xs'])),color='m',label=r'$\zeta_c=0.98$')
plt.ylim(0.9,1.1)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel(r'$\frac{d\sigma(\zeta:[0,1])}{(d\sigma(\zeta[0,\zeta_c])+d\sigma(\zeta[\zeta_c,1]))}$',fontsize =16)
plt.savefig('results/compare/Fac_check/JLab3_Fac_ratio.pdf')
plt.figure()

# %%
plt.plot(np.asarray(df_F_EIC3_unpol_rc['qT_Q']),df_F_EIC3_unpol_rc['xs'],color='r',label='Factorized rc')
plt.plot(np.asarray(df_F_EIC3_unpol_rc['qT_Q']),df_F_EIC3_zeta_s95_xi_all['xs'],color='b',linestyle='-.',label=r'$\zeta:[0,0.95]$')
plt.plot(np.asarray(df_F_EIC3_unpol_rc['qT_Q']),df_F_EIC3_zeta_g95_xi_all['xs'],color='b',linestyle=':',label=r'$\zeta:[0.95,1]$')
plt.plot(np.asarray(df_F_EIC3_unpol_rc['qT_Q']),np.asarray(df_F_EIC3_zeta_g95_xi_all['xs'])+np.asarray(df_F_EIC3_zeta_s95_xi_all['xs']),color='b',linestyle='-',label=r'$\zeta:[0,1]$')
plt.plot(np.asarray(df_F_EIC3_unpol_rc['qT_Q']),df_F_EIC3_zeta_s98_xi_all['xs'],color='m',linestyle='-.',label=r'$\zeta:[0,0.98]$')
plt.plot(np.asarray(df_F_EIC3_unpol_rc['qT_Q']),df_F_EIC3_zeta_g98_xi_all['xs'],color='m',linestyle=':',label=r'$\zeta:[0.98,1]$')
plt.plot(np.asarray(df_F_EIC3_unpol_rc['qT_Q']),np.asarray(df_F_EIC3_zeta_g98_xi_all['xs'])+np.asarray(df_F_EIC3_zeta_s98_xi_all['xs']),color='m',linestyle='-',label=r'$\zeta:[0,1]$')
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$d\sigma$',fontsize =16)
plt.savefig('results/compare/Fac_check/EIC3_Fac_check.pdf')

plt.figure()
plt.plot(np.asarray(df_F_EIC3_unpol_rc['qT_Q']),np.asarray(df_F_EIC3_unpol_rc['xs'])/(np.asarray(df_F_EIC3_zeta_g95_xi_all['xs'])+np.asarray(df_F_EIC3_zeta_s95_xi_all['xs'])),color='b',label=r'$\zeta_c=0.95$')
plt.plot(np.asarray(df_F_EIC3_unpol_rc['qT_Q']),np.asarray(df_F_EIC3_unpol_rc['xs'])/(np.asarray(df_F_EIC3_zeta_g98_xi_all['xs'])+np.asarray(df_F_EIC3_zeta_s98_xi_all['xs'])),color='m',label=r'$\zeta_c=0.98$')
plt.ylim(0.9,1.1)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel(r'$\frac{d\sigma(\zeta:[0,1])}{(d\sigma(\zeta[0,\zeta_c])+d\sigma(\zeta[\zeta_c,1]))}$',fontsize =16)
plt.savefig('results/compare/Fac_check/EIC3_Fac_ratio.pdf')
plt.figure()

# %%
plt.plot(np.asarray(df_F_EIC2_unpol_rc['qT_Q']),df_F_EIC2_unpol_rc['xs'],color='r',label='Factorized rc')
plt.plot(np.asarray(df_F_EIC2_unpol_rc['qT_Q'][:144]),df_F_EIC2_zeta_s95_xi_all['xs'],color='b',linestyle='-.',label=r'$\zeta:[0,0.95]$')
plt.plot(np.asarray(df_F_EIC2_unpol_rc['qT_Q'][:143]),df_F_EIC2_zeta_g95_xi_all['xs'],color='b',linestyle=':',label=r'$\zeta:[0.95,1]$')
plt.plot(np.asarray(df_F_EIC2_unpol_rc['qT_Q'][:143]),np.asarray(df_F_EIC2_zeta_g95_xi_all['xs'][:143])+np.asarray(df_F_EIC2_zeta_s95_xi_all['xs'][:143]),color='b',linestyle='-',label=r'$\zeta:[0,1]$')
plt.plot(np.asarray(df_F_EIC2_unpol_rc['qT_Q'][:143]),df_F_EIC2_zeta_s98_xi_all['xs'][:143],color='m',linestyle='-.',label=r'$\zeta:[0,0.98]$')
plt.plot(np.asarray(df_F_EIC2_unpol_rc['qT_Q'][:143]),df_F_EIC2_zeta_g98_xi_all['xs'][:143],color='m',linestyle=':',label=r'$\zeta:[0.98,1]$')
plt.plot(np.asarray(df_F_EIC2_unpol_rc['qT_Q'][:143]),np.asarray(df_F_EIC2_zeta_g98_xi_all['xs'][:143])+np.asarray(df_F_EIC2_zeta_s98_xi_all['xs'][:143]),color='m',linestyle='-',label=r'$\zeta:[0,1]$')
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$d\sigma$',fontsize =16)
plt.savefig('results/compare/Fac_check/EIC2_Fac_check.pdf')

plt.figure()
plt.plot(np.asarray(df_F_EIC2_unpol_rc['qT_Q'][:143]),np.asarray(df_F_EIC2_unpol_rc['xs'][:143])/(np.asarray(df_F_EIC2_zeta_g95_xi_all['xs'][:143])+np.asarray(df_F_EIC2_zeta_s95_xi_all['xs'][:143])),color='b',label=r'$\zeta_c=0.95$')
plt.plot(np.asarray(df_F_EIC2_unpol_rc['qT_Q'][:143]),np.asarray(df_F_EIC2_unpol_rc['xs'][:143])/(np.asarray(df_F_EIC2_zeta_g98_xi_all['xs'][:143])+np.asarray(df_F_EIC2_zeta_s98_xi_all['xs'][:143])),color='m',label=r'$\zeta_c=0.98$')
plt.ylim(0.9,1.1)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel(r'$\frac{d\sigma(\zeta:[0,1])}{(d\sigma(\zeta[0,\zeta_c])+d\sigma(\zeta[\zeta_c,1]))}$',fontsize =16)
plt.savefig('results/compare/Fac_check/EIC2_Fac_ratio.pdf')
plt.figure()

# %%
plt.plot(np.asarray(df_F_EIC1_unpol_rc['qT_Q']),df_F_EIC1_unpol_rc['xs'],color='r',label='Factorized rc')
plt.plot(np.asarray(df_F_EIC1_unpol_rc['qT_Q']),df_F_EIC1_zeta_s95_xi_all['xs'],color='b',linestyle='-.',label=r'$\zeta:[0,0.95]$')
plt.plot(np.asarray(df_F_EIC1_unpol_rc['qT_Q']),df_F_EIC1_zeta_g95_xi_all['xs'],color='b',linestyle=':',label=r'$\zeta:[0.95,1]$')
plt.plot(np.asarray(df_F_EIC1_unpol_rc['qT_Q']),np.asarray(df_F_EIC1_zeta_g95_xi_all['xs'])+np.asarray(df_F_EIC1_zeta_s95_xi_all['xs']),color='b',linestyle='-',label=r'$\zeta:[0,1]$')
plt.plot(np.asarray(df_F_EIC1_unpol_rc['qT_Q']),df_F_EIC1_zeta_s98_xi_all['xs'],color='m',linestyle='-.',label=r'$\zeta:[0,0.98]$')
plt.plot(np.asarray(df_F_EIC1_unpol_rc['qT_Q']),df_F_EIC1_zeta_g98_xi_all['xs'],color='m',linestyle=':',label=r'$\zeta:[0.98,1]$')
plt.plot(np.asarray(df_F_EIC1_unpol_rc['qT_Q']),np.asarray(df_F_EIC1_zeta_g98_xi_all['xs'])+np.asarray(df_F_EIC1_zeta_s98_xi_all['xs']),color='m',linestyle='-',label=r'$\zeta:[0,1]$')
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$d\sigma$',fontsize =16)
plt.savefig('results/compare/Fac_check/EIC1_Fac_check.pdf')

plt.figure()
plt.plot(np.asarray(df_F_EIC1_unpol_rc['qT_Q']),np.asarray(df_F_EIC1_unpol_rc['xs'])/(np.asarray(df_F_EIC1_zeta_g95_xi_all['xs'])+np.asarray(df_F_EIC1_zeta_s95_xi_all['xs'])),color='b',label=r'$\zeta_c=0.95$')
plt.plot(np.asarray(df_F_EIC1_unpol_rc['qT_Q']),np.asarray(df_F_EIC1_unpol_rc['xs'])/(np.asarray(df_F_EIC1_zeta_g98_xi_all['xs'])+np.asarray(df_F_EIC1_zeta_s98_xi_all['xs'])),color='m',label=r'$\zeta_c=0.98$')
plt.ylim(0.9,1.1)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel(r'$\frac{d\sigma(\zeta:[0,1])}{(d\sigma(\zeta[0,\zeta_c])+d\sigma(\zeta[\zeta_c,1]))}$',fontsize =16)
plt.savefig('results/compare/Fac_check/EIC1_Fac_ratio.pdf')
plt.figure()

# %%
df_F_JLab2_zeta_all_xi_1 = pd.read_csv('results/Fac-results/zeta_xi_check/JLab_2_unpol_rc_zeta_all_xi_1.txt',delim_whitespace=True,names=columns_name)
print(df_F_JLab2_zeta_all_xi_1.head())
df_F_JLab2_zeta_1_xi_all = pd.read_csv('results/Fac-results/zeta_xi_check/JLab_2_unpol_rc_zeta_1_xi_all.txt',delim_whitespace=True,names=columns_name)
print(df_F_JLab2_zeta_1_xi_all.head())
plt.plot(np.asarray(df_F_JLab_2_unpol_rc['qT_Q']),df_F_JLab_2_unpol_rc['xs'],color='r',label=r'$\zeta:[0,1],\xi:[0,1]$')
plt.plot(df_F_JLab2_zeta_all_xi_1['qT_Q'],df_F_JLab2_zeta_1_xi_all['xs'],label=r'$\zeta:[0,1],\xi=1$')
plt.plot(df_F_JLab2_zeta_1_xi_all['qT_Q'],df_F_JLab2_zeta_all_xi_1['xs'],label=r'$\zeta=1,\xi:[0,1]$')
plt.legend()
plt.xlabel('qT/Q',fontsize=16)
plt.ylabel('xs',fontsize=16)
plt.savefig('results/compare/Fac_check/JLab2_radia_cuts.pdf')
# Out:
#       x      z         Q      qT_Q        xs        xs_err
# 0  0.48  0.375  2.828427  0.050000  0.000019  2.522810e-10
# 1  0.48  0.375  2.828427  0.059732  0.000019  3.075105e-10
# 2  0.48  0.375  2.828427  0.069463  0.000018  2.813579e-10
# 3  0.48  0.375  2.828427  0.079195  0.000018  1.974918e-10
# 4  0.48  0.375  2.828427  0.088926  0.000018  2.181709e-10
#       x      z         Q      qT_Q        xs        xs_err
# 0  0.48  0.375  2.828427  0.050000  0.000019  1.315016e-10
# 1  0.48  0.375  2.828427  0.059732  0.000019  4.208446e-10
# 2  0.48  0.375  2.828427  0.069463  0.000019  4.477331e-10
# 3  0.48  0.375  2.828427  0.079195  0.000019  1.485214e-10
# 4  0.48  0.375  2.828427  0.088926  0.000019  1.622461e-10

# %%
df_F_JLab3_zeta_all_xi_1 = pd.read_csv('results/Fac-results/zeta_xi_check/JLab_3_unpol_rc_zeta_all_xi_1.txt',delim_whitespace=True,names=columns_name)
print(df_F_JLab3_zeta_all_xi_1.head())
df_F_JLab3_zeta_1_xi_all = pd.read_csv('results/Fac-results/zeta_xi_check/JLab_3_unpol_rc_zeta_1_xi_all.txt',delim_whitespace=True,names=columns_name)
print(df_F_JLab3_zeta_1_xi_all.head())
plt.plot(np.asarray(df_F_JLab_3_unpol_rc['qT_Q']),df_F_JLab_3_unpol_rc['xs'],color='r',label=r'$\zeta:[0,1],\xi:[0,1]$')
plt.plot(df_F_JLab3_zeta_all_xi_1['qT_Q'],df_F_JLab3_zeta_1_xi_all['xs'],label=r'$\zeta:[0,1],\xi=1$')
plt.plot(df_F_JLab3_zeta_1_xi_all['qT_Q'],df_F_JLab3_zeta_all_xi_1['xs'],label=r'$\zeta=1,\xi:[0,1]$')
plt.legend()
plt.xlabel('qT/Q',fontsize=16)
plt.ylabel('xs',fontsize=16)
plt.savefig('results/compare/Fac_check/JLab3_radia_cuts.pdf')
# Out:
#       x      z         Q      qT_Q        xs        xs_err
# 0  0.48  0.375  3.872983  0.050000  0.000009  1.259718e-10
# 1  0.48  0.375  3.872983  0.059732  0.000009  1.507207e-10
# 2  0.48  0.375  3.872983  0.069463  0.000009  1.765881e-10
# 3  0.48  0.375  3.872983  0.079195  0.000009  1.274040e-10
# 4  0.48  0.375  3.872983  0.088926  0.000008  8.649997e-11
#       x      z         Q      qT_Q        xs        xs_err
# 0  0.48  0.375  3.872983  0.050000  0.000009  1.086251e-10
# 1  0.48  0.375  3.872983  0.059732  0.000009  1.478696e-10
# 2  0.48  0.375  3.872983  0.069463  0.000009  1.721346e-10
# 3  0.48  0.375  3.872983  0.079195  0.000009  7.376719e-11
# 4  0.48  0.375  3.872983  0.088926  0.000009  1.794274e-10

# %%
df_F_EIC3_zeta_all_xi_1 = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_3_unpol_rc_zeta_all_xi_1.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC3_zeta_all_xi_1.head())
df_F_EIC3_zeta_1_xi_all = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_3_unpol_rc_zeta_1_xi_all.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC3_zeta_1_xi_all.head())
plt.plot(np.asarray(df_F_EIC3_unpol_rc['qT_Q']),df_F_EIC3_unpol_rc['xs'],color='r',label=r'$\zeta:[0,1],\xi:[0,1]$')
plt.plot(df_F_EIC3_zeta_all_xi_1['qT_Q'],df_F_EIC3_zeta_1_xi_all['xs'],label=r'$\zeta:[0,1],\xi=1$')
plt.plot(df_F_EIC3_zeta_1_xi_all['qT_Q'],df_F_EIC3_zeta_all_xi_1['xs'],label=r'$\zeta=1,\xi:[0,1]$')
plt.legend()
plt.xlabel('qT/Q',fontsize=16)
plt.ylabel('xs',fontsize=16)
plt.savefig('results/compare/Fac_check/EIC3_radia_cuts.pdf')
# Out:
#       x    z    Q      qT_Q        xs        xs_err
# 0  0.01  0.5  5.0  0.050000  0.001809  5.970230e-08
# 1  0.01  0.5  5.0  0.059732  0.001764  5.405354e-08
# 2  0.01  0.5  5.0  0.069463  0.001712  8.419833e-08
# 3  0.01  0.5  5.0  0.079195  0.001654  5.113215e-08
# 4  0.01  0.5  5.0  0.088926  0.001592  1.110568e-07
#       x    z    Q      qT_Q        xs        xs_err
# 0  0.01  0.5  5.0  0.050000  0.001813  5.241723e-08
# 1  0.01  0.5  5.0  0.059732  0.001768  5.920353e-08
# 2  0.01  0.5  5.0  0.069463  0.001716  7.525233e-08
# 3  0.01  0.5  5.0  0.079195  0.001658  7.332267e-08
# 4  0.01  0.5  5.0  0.088926  0.001595  8.497821e-08

# %%
df_F_EIC2_zeta_all_xi_1 = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_2_unpol_rc_zeta_all_xi_1.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC2_zeta_all_xi_1.head())
df_F_EIC2_zeta_1_xi_all = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_2_unpol_rc_zeta_1_xi_all.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC2_zeta_1_xi_all.head())
plt.plot(np.asarray(df_F_EIC2_unpol_rc['qT_Q']),df_F_EIC2_unpol_rc['xs'],color='r',label=r'$\zeta:[0,1],\xi:[0,1]$')
plt.plot(df_F_EIC2_zeta_all_xi_1['qT_Q'],df_F_EIC2_zeta_1_xi_all['xs'],label=r'$\zeta:[0,1],\xi=1$')
plt.plot(df_F_EIC2_zeta_1_xi_all['qT_Q'],df_F_EIC2_zeta_all_xi_1['xs'],label=r'$\zeta=1,\xi:[0,1]$')
plt.legend()
plt.xlabel('qT/Q',fontsize=16)
plt.ylabel('xs',fontsize=16)
plt.savefig('results/compare/Fac_check/EIC2_radia_cuts.pdf')
# Out:
#           x    z     Q      qT_Q        xs        xs_err
# 0  0.012755  0.5  10.0  0.050000  0.000069  8.229596e-09
# 1  0.012755  0.5  10.0  0.059732  0.000062  5.464917e-09
# 2  0.012755  0.5  10.0  0.069463  0.000055  7.151103e-09
# 3  0.012755  0.5  10.0  0.079195  0.000048  9.973660e-09
# 4  0.012755  0.5  10.0  0.088926  0.000041  6.478277e-09
#           x    z     Q      qT_Q        xs        xs_err
# 0  0.012755  0.5  10.0  0.050000  0.000069  6.485774e-09
# 1  0.012755  0.5  10.0  0.059732  0.000062  7.042188e-09
# 2  0.012755  0.5  10.0  0.069463  0.000055  9.486547e-09
# 3  0.012755  0.5  10.0  0.079195  0.000048  4.721328e-09
# 4  0.012755  0.5  10.0  0.088926  0.000041  6.499891e-09

# %%
df_F_EIC1_zeta_all_xi_1 = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_1_unpol_rc_zeta_all_xi_1.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC1_zeta_all_xi_1.head())
df_F_EIC1_zeta_1_xi_all = pd.read_csv('results/Fac-results/zeta_xi_check/EIC_1_unpol_rc_zeta_1_xi_all.txt',delim_whitespace=True,names=columns_name)
print(df_F_EIC1_zeta_1_xi_all.head())
plt.plot(np.asarray(df_F_EIC1_unpol_rc['qT_Q']),df_F_EIC1_unpol_rc['xs'],color='r',label=r'$\zeta:[0,1],\xi:[0,1]$')
plt.plot(df_F_EIC1_zeta_all_xi_1['qT_Q'],df_F_EIC1_zeta_1_xi_all['xs'],label=r'$\zeta:[0,1],\xi=1$')
plt.plot(df_F_EIC1_zeta_1_xi_all['qT_Q'],df_F_EIC1_zeta_all_xi_1['xs'],label=r'$\zeta=1,\xi:[0,1]$')
plt.legend()
plt.xlabel('qT/Q',fontsize=16)
plt.ylabel('xs',fontsize=16)
plt.savefig('results/compare/Fac_check/EIC1_radia_cuts.pdf')
# Out:
#           x    z    Q      qT_Q        xs        xs_err
# 0  0.001148  0.5  3.0  0.050000  0.017281  3.936671e-07
# 1  0.001148  0.5  3.0  0.059732  0.017124  1.184177e-07
# 2  0.001148  0.5  3.0  0.069463  0.016939  3.106207e-07
# 3  0.001148  0.5  3.0  0.079195  0.016730  2.302889e-07
# 4  0.001148  0.5  3.0  0.088926  0.016497  2.128701e-07
#           x    z    Q      qT_Q        xs        xs_err
# 0  0.001148  0.5  3.0  0.050000  0.017195  1.947790e-07
# 1  0.001148  0.5  3.0  0.059732  0.017038  1.718209e-07
# 2  0.001148  0.5  3.0  0.069463  0.016855  3.086693e-07
# 3  0.001148  0.5  3.0  0.079195  0.016647  2.490545e-07
# 4  0.001148  0.5  3.0  0.088926  0.016415  2.228783e-07
