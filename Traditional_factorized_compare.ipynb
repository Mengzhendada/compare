# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
#    JLab 1: S=10.3 GeV2, Q=1.52 GeV, x=0.32, z=0.55
#    JLab 2: Eb=12 GeV, Q2=8 GeV2, x=0.48, z=0.375
#    JLab 3: Eb=24 GeV, Q2=15 GeV2, x=0.48, z=0.375
#    EIC 1: sqrt(S)=140 GeV, Q=3 GeV, y=0.4, z=0.5
#    EIC 2: sqrt(S)=140 GeV, Q=10 GeV, y=0.4, z=0.5
#    EIC 3: sqrt(S)=140 GeV, Q=5 GeV, x=0.01, z=0.5
#    qt_to_Q = PhT/x/Q

# %%
df_T_eic3 = pd.read_csv('results/Tra-results/inj-all/results-eic3.txt',delim_whitespace=True)
df_T_eic3.head()
# Out:
#    qt_to_Q  unpol_bn  err  unpol_rc     err.1  sivers_bn         err.2  \
# 0     0.05  0.009875  0.0  0.006987  0.000007   0.000003  6.320409e-13
# 1     0.10  0.008231  0.0  0.005876  0.000006   0.000004  1.093996e-12
# 2     0.15  0.006076  0.0  0.004404  0.000005   0.000004  1.289758e-12
# 3     0.20  0.003973  0.0  0.002950  0.000003   0.000004  1.227463e-12
# 4     0.25  0.002302  0.0  0.001773  0.000002   0.000002  9.945817e-13
#
#    sivers_rc         err.3    collins_bn         err.4    collins_rc  \
# 0   0.000002  3.126797e-09  3.160295e-07  5.216781e-12  3.091826e-07
# 1   0.000003  3.293999e-09  5.470140e-07  8.474286e-12  5.304833e-07
# 2   0.000003  3.233590e-09  6.448980e-07  8.986405e-12  6.170487e-07
# 3   0.000003  2.854644e-09  6.137501e-07  7.371301e-12  5.785355e-07
# 4   0.000002  2.250446e-09  4.973063e-07  4.931298e-12  4.614589e-07
#
#           err.5
# 0  3.031393e-09
# 1  3.545601e-09
# 2  3.501905e-09
# 3  2.883642e-09
# 4  2.266709e-09

# %%
df_T_eic2 = pd.read_csv('results/Tra-results/inj-all/results-eic2.txt',delim_whitespace=True)
df_T_eic2.head()
# Out:
#    qt_to_Q  unpol_bn  err  unpol_rc         err.1     sivers_bn         err.2  \
# 0     0.05  0.000375  0.0  0.000286  3.867324e-07  2.206934e-07  5.407394e-14
# 1     0.10  0.000181  0.0  0.000144  2.161711e-07  1.920459e-07  6.067086e-14
# 2     0.15  0.000054  0.0  0.000048  1.031903e-07  7.180035e-08  3.472763e-14
# 3     0.20  0.000010  0.0  0.000012  4.878019e-08  1.361080e-08  1.201876e-14
# 4     0.25  0.000001  0.0  0.000003  2.204611e-08  1.368685e-09  2.652511e-15
#
#       sivers_rc         err.3    collins_bn         err.4    collins_rc  \
# 0  1.624249e-07  2.622358e-10  2.703774e-08  4.413716e-13  2.870355e-08
# 1  1.464120e-07  2.254816e-10  3.033634e-08  3.840785e-13  3.084255e-08
# 2  5.965523e-08  1.167842e-10  1.736436e-08  1.435958e-13  1.692478e-08
# 3  1.452600e-08  5.235768e-11  6.009576e-09  2.722067e-14  5.959358e-09
# 4  3.184938e-09  3.013351e-11  1.326301e-09  2.737277e-15  1.574152e-09
#
#           err.5
# 0  2.606041e-10
# 1  2.139026e-10
# ...

# %%
df_T_eic1 = pd.read_csv('results/Tra-results/inj-all/results-eic1.txt',delim_whitespace=True)
df_T_eic1.head()
# Out:
#    qt_to_Q  unpol_bn  err  unpol_rc     err.1     sivers_bn         err.2  \
# 0     0.05  0.082480  0.0  0.069533  0.000043  3.774092e-07  8.845906e-14
# 1     0.10  0.077260  0.0  0.065246  0.000040  6.997227e-07  1.679496e-13
# 2     0.15  0.069283  0.0  0.058717  0.000035  9.249988e-07  2.310014e-13
# 3     0.20  0.059482  0.0  0.050651  0.000030  1.033288e-06  2.727945e-13
# 4     0.25  0.048891  0.0  0.041896  0.000025  1.028623e-06  2.917196e-13
#
#       sivers_rc         err.3    collins_bn         err.4    collins_rc  \
# 0  3.239327e-07  5.709146e-10  4.423078e-08  7.547923e-13  4.735671e-08
# 1  6.009038e-07  5.375377e-10  8.397719e-08  1.399397e-12  9.015673e-08
# 2  7.980158e-07  5.081603e-10  1.155040e-07  1.849934e-12  1.243344e-07
# 3  8.973868e-07  4.780440e-10  1.364012e-07  2.066504e-12  1.462214e-07
# 4  9.006197e-07  4.479895e-10  1.458641e-07  2.057175e-12  1.557995e-07
#
#           err.5
# 0  5.609107e-10
# 1  5.539318e-10
# 2  5.819247e-10
# 3  5.809468e-10
# ...

# %%
df_T_JLab2 = pd.read_csv('results/Tra-results/inj-all/results-jlab2.txt',delim_whitespace=True)
df_T_JLab2.head()
# Out:
#    qt_to_Q  unpol_bn  err  unpol_rc         err.1     sivers_bn         err.2  \
# 0     0.05  0.000087  0.0  0.000078  3.625538e-08  9.324191e-08  3.169540e-13
# 1     0.10  0.000084  0.0  0.000074  3.447479e-08  1.780502e-07  6.071224e-13
# 2     0.15  0.000078  0.0  0.000069  3.168681e-08  2.472486e-07  8.475334e-13
# 3     0.20  0.000071  0.0  0.000063  2.819474e-08  2.959165e-07  1.022076e-12
# 4     0.25  0.000062  0.0  0.000056  2.428449e-08  3.219349e-07  1.123214e-12
#
#       sivers_rc         err.3    collins_bn         err.4    collins_rc  \
# 0  8.091683e-08  9.741927e-11  1.584824e-07  1.864776e-13  1.411780e-07
# 1  1.547315e-07  1.581022e-10  3.035716e-07  3.560885e-13  2.704563e-07
# 2  2.150748e-07  2.039278e-10  4.237812e-07  4.944808e-13  3.779386e-07
# 3  2.577335e-07  2.331194e-10  5.110556e-07  5.918132e-13  4.564599e-07
# 4  2.808574e-07  2.447187e-10  5.616265e-07  6.438482e-13  5.026241e-07
#
#           err.5
# 0  1.064226e-10
# 1  1.573043e-10
# ...

# %%
df_T_JLab3 = pd.read_csv('results/Tra-results/inj-all/results-jlab3.txt',delim_whitespace=True)
df_T_JLab3.head()
# Out:
#    qt_to_Q  unpol_bn  err  unpol_rc         err.1     sivers_bn         err.2  \
# 0     0.05  0.000043  0.0  0.000037  2.096498e-08  6.185693e-08  2.690789e-13
# 1     0.10  0.000039  0.0  0.000034  1.918149e-08  1.134277e-07  4.960532e-13
# 2     0.15  0.000034  0.0  0.000030  1.660157e-08  1.472216e-07  6.498102e-13
# 3     0.20  0.000029  0.0  0.000025  1.363974e-08  1.602956e-07  7.172108e-13
# 4     0.25  0.000022  0.0  0.000020  1.056217e-08  1.544110e-07  7.039231e-13
#
#       sivers_rc         err.3    collins_bn         err.4    collins_rc  \
# 0  5.313214e-08  9.021821e-11  1.345441e-07  1.237098e-13  1.173145e-07
# 1  9.757435e-08  1.295567e-10  2.480351e-07  2.268479e-13  2.163655e-07
# 2  1.269337e-07  1.657668e-10  3.249163e-07  2.944334e-13  2.841048e-07
# 3  1.385687e-07  1.801856e-10  3.586177e-07  3.205806e-13  3.146250e-07
# 4  1.339305e-07  1.713741e-10  3.519736e-07  3.088118e-13  3.102912e-07
#
#           err.5
# 0  1.019848e-10
# 1  1.374672e-10
# ...

# %%
df_F_eic1_siv_rc = pd.read_csv('results/Fac-results/EIC_1_siv_rc.txt',delim_whitespace=True,skiprows=12)
df_F_eic1_siv_bn = pd.read_csv('results/Fac-results/EIC_1_siv_bn.txt',delim_whitespace=True,skiprows=12)
df_F_eic1_col_rc = pd.read_csv('results/Fac-results/EIC_1_col_rc.txt',delim_whitespace=True,skiprows=12)
df_F_eic1_col_bn = pd.read_csv('results/Fac-results/EIC_1_col_bn.txt',delim_whitespace=True,skiprows=12)
df_F_eic1_unpol_rc = pd.read_csv('results/Fac-results/EIC_1_unpol_rc.txt',delim_whitespace=True,skiprows=12)
df_F_eic1_unpol_bn = pd.read_csv('results/Fac-results/EIC_1_unpol_bn.txt',delim_whitespace=True,skiprows=12)

# %%
df_F_eic2_siv_rc = pd.read_csv('results/Fac-results/EIC_2_siv_rc.txt',delim_whitespace=True,skiprows=12)
df_F_eic2_siv_bn = pd.read_csv('results/Fac-results/EIC_2_siv_bn.txt',delim_whitespace=True,skiprows=12)
df_F_eic2_col_rc = pd.read_csv('results/Fac-results/EIC_2_col_rc.txt',delim_whitespace=True,skiprows=12)
df_F_eic2_col_bn = pd.read_csv('results/Fac-results/EIC_2_col_bn.txt',delim_whitespace=True,skiprows=12)
df_F_eic2_unpol_rc = pd.read_csv('results/Fac-results/EIC_2_unpol_rc.txt',delim_whitespace=True,skiprows=12)
df_F_eic2_unpol_bn = pd.read_csv('results/Fac-results/EIC_2_unpol_bn.txt',delim_whitespace=True,skiprows=12)
df_F_eic2_siv_rc.head()
# Out:
#          x    z     Q  qT_Q            xs        xs_err
# 0  0.01276  0.5  10.0  0.05  1.557159e-07  2.523402e-10
# 1  0.01276  0.5  10.0  0.10  1.401508e-07  3.119306e-10
# 2  0.01276  0.5  10.0  0.15  5.721907e-08  9.042177e-11
# 3  0.01276  0.5  10.0  0.20  1.390295e-08  4.360096e-11
# 4  0.01276  0.5  10.0  0.25  3.097754e-09  1.367846e-11

# %%
df_F_eic3_siv_rc = pd.read_csv('results/Fac-results/EIC_3_siv_rc.txt',delim_whitespace=True,skiprows=12)
df_F_eic3_siv_bn = pd.read_csv('results/Fac-results/EIC_3_siv_bn.txt',delim_whitespace=True,skiprows=12)
df_F_eic3_col_rc = pd.read_csv('results/Fac-results/EIC_3_col_rc.txt',delim_whitespace=True,skiprows=12)
df_F_eic3_col_bn = pd.read_csv('results/Fac-results/EIC_3_col_bn.txt',delim_whitespace=True,skiprows=12)
df_F_eic3_unpol_rc = pd.read_csv('results/Fac-results/EIC_3_unpol_rc.txt',delim_whitespace=True,skiprows=12)
df_F_eic3_unpol_bn = pd.read_csv('results/Fac-results/EIC_3_unpol_bn.txt',delim_whitespace=True,skiprows=12)

# %%
df_F_JLab2_siv_rc = pd.read_csv('results/Fac-results/JLab_2_siv_rc.txt',delim_whitespace=True,skiprows=12)
df_F_JLab2_siv_bn = pd.read_csv('results/Fac-results/JLab_2_siv_bn.txt',delim_whitespace=True,skiprows=12)
df_F_JLab2_col_rc = pd.read_csv('results/Fac-results/JLab_2_col_rc.txt',delim_whitespace=True,skiprows=12)
df_F_JLab2_col_bn = pd.read_csv('results/Fac-results/JLab_2_col_bn.txt',delim_whitespace=True,skiprows=12)
df_F_JLab2_unpol_rc = pd.read_csv('results/Fac-results/JLab_2_unpol_rc.txt',delim_whitespace=True,skiprows=12)
df_F_JLab2_unpol_bn = pd.read_csv('results/Fac-results/JLab_2_unpol_bn.txt',delim_whitespace=True,skiprows=12)
df_F_JLab2_siv_rc.head()
# Out:
#       x      z      Q  qT_Q            xs        xs_err
# 0  0.48  0.375  2.828  0.05  7.719933e-08  1.861372e-10
# 1  0.48  0.375  2.828  0.10  1.472958e-07  2.049414e-10
# 2  0.48  0.375  2.828  0.15  2.048385e-07  3.783916e-10
# 3  0.48  0.375  2.828  0.20  2.455732e-07  2.649667e-10
# 4  0.48  0.375  2.828  0.25  2.674858e-07  2.538224e-10

# %%
df_F_JLab3_siv_rc = pd.read_csv('results/Fac-results/JLab_3_siv_rc.txt',delim_whitespace=True,skiprows=12)
df_F_JLab3_siv_bn = pd.read_csv('results/Fac-results/JLab_3_siv_bn.txt',delim_whitespace=True,skiprows=12)
df_F_JLab3_col_rc = pd.read_csv('results/Fac-results/JLab_3_col_rc.txt',delim_whitespace=True,skiprows=12)
df_F_JLab3_col_bn = pd.read_csv('results/Fac-results/JLab_3_col_bn.txt',delim_whitespace=True,skiprows=12)
df_F_JLab3_unpol_rc = pd.read_csv('results/Fac-results/JLab_3_unpol_rc.txt',delim_whitespace=True,skiprows=12)
df_F_JLab3_unpol_bn = pd.read_csv('results/Fac-results/JLab_3_unpol_bn.txt',delim_whitespace=True,skiprows=12)
df_F_JLab3_siv_rc.head()
# Out:
#       x      z      Q  qT_Q            xs        xs_err
# 0  0.48  0.375  3.873  0.05  4.972561e-08  8.107923e-11
# 1  0.48  0.375  3.873  0.10  9.114326e-08  1.641612e-10
# 2  0.48  0.375  3.873  0.15  1.187068e-07  1.344097e-10
# 3  0.48  0.375  3.873  0.20  1.298106e-07  1.976303e-10
# 4  0.48  0.375  3.873  0.25  1.253627e-07  2.482014e-10

# %%
plt.plot(np.asarray(df_T_JLab2['qt_to_Q']),df_T_JLab2['sivers_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_JLab2_siv_bn['qT_Q']),df_F_JLab2_siv_bn['xs'],color='r',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/siv_bn_JLab2.pdf')
plt.figure()
plt.plot(np.asarray(df_T_JLab2['qt_to_Q']),df_T_JLab2['sivers_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_JLab2_siv_rc['qT_Q']),df_F_JLab2_siv_rc['xs'],color='r',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/siv_rc_JLab2.pdf')

# %%
plt.plot(np.asarray(df_T_JLab2['qt_to_Q']),df_T_JLab2['collins_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_JLab2_col_bn['qT_Q']),df_F_JLab2_col_bn['xs'],color='r',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/col_bn_JLab2.pdf')
plt.figure()
plt.plot(np.asarray(df_T_JLab2['qt_to_Q']),df_T_JLab2['collins_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_JLab2_col_rc['qT_Q']),df_F_JLab2_col_rc['xs'],color='r',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/col_rc_JLab2.pdf')

# %%
plt.plot(np.asarray(df_T_JLab2['qt_to_Q']),df_T_JLab2['unpol_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_JLab2_unpol_bn['qT_Q']),df_F_JLab2_unpol_bn['xs'],color='r',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$d\sigma$',fontsize =16)
plt.savefig('results/compare/unpol_bn_JLab2.pdf')

plt.figure()
plt.plot(np.asarray(df_T_JLab2['qt_to_Q']),df_T_JLab2['unpol_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_JLab2_unpol_rc['qT_Q']),df_F_JLab2_unpol_rc['xs'],color='r',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$d\sigma$',fontsize =16)
plt.savefig('results/compare/unpol_rc_JLab2.pdf')

# %%
plt.figure()
F_Born_JLab2 = np.asarray(df_F_JLab2_unpol_bn['xs'])+np.asarray(df_F_JLab2_siv_bn['xs'])+np.asarray(df_F_JLab2_col_bn['xs'])
T_Born_JLab2 = np.asarray(df_T_JLab2['unpol_bn'])+np.asarray(df_T_JLab2['sivers_bn'])+np.asarray(df_T_JLab2['collins_bn'])
R_Born_JLab2 = F_Born_JLab2/T_Born_JLab2[:12]
plt.plot(np.asarray(df_F_JLab2_unpol_bn['qT_Q']),R_Born_JLab2[:12],color='b')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$R_{Born}$',fontsize=16)
plt.ylim(0.94,1.06)
plt.savefig('results/compare/compare_born_JLab2.pdf')

plt.figure()
F_RC_JLab2 = np.asarray(df_F_JLab2_unpol_rc['xs'])+np.asarray(df_F_JLab2_siv_rc['xs'])+np.asarray(df_F_JLab2_col_rc['xs'])
T_RC_JLab2 = np.asarray(df_T_JLab2['unpol_rc'])+np.asarray(df_T_JLab2['sivers_rc'])+np.asarray(df_T_JLab2['collins_rc'])
RC_T = F_Born_JLab2/F_RC_JLab2
RC_F = (T_Born_JLab2/T_RC_JLab2)[:12]
plt.plot(np.asarray(df_F_JLab2_unpol_rc['qT_Q']),RC_F/RC_T,label='$RC_F/RC_T')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize =16)
plt.ylim(0.9,1.2)
plt.savefig('results/compare/compare_RC_JLab2.pdf')
# Out:
# /var/folders/ll/8_2_l77j4yl2zjb6stl8d9b00000gn/T/ipykernel_3871/1897364286.py:15: RuntimeWarning: invalid value encountered in true_divide
#   RC_F = (T_Born_JLab2/T_RC_JLab2)[:12]

# %%
plt.plot(np.asarray(df_T_JLab3['qt_to_Q']),df_T_JLab3['sivers_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_JLab3_siv_bn['qT_Q']),df_F_JLab3_siv_bn['xs'],color='r',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/siv_bn_JLab3.pdf')
plt.figure()
plt.plot(np.asarray(df_T_JLab3['qt_to_Q']),df_T_JLab3['sivers_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_JLab3_siv_rc['qT_Q']),df_F_JLab3_siv_rc['xs'],color='r',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =16)
plt.savefig('results/compare/siv_rc_JLab3.pdf')

# %%
plt.plot(np.asarray(df_T_JLab3['qt_to_Q']),df_T_JLab3['collins_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_JLab3_col_bn['qT_Q']),df_F_JLab3_col_bn['xs'],color='r',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize = 16)
plt.savefig('results/compare/col_bn_JLab3.pdf')
plt.figure()
plt.plot(np.asarray(df_T_JLab3['qt_to_Q']),df_T_JLab3['collins_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_JLab3_col_rc['qT_Q']),df_F_JLab3_col_rc['xs'],color='r',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize = 16)
plt.savefig('results/compare/col_rc_JLab3.pdf')

# %%
plt.plot(np.asarray(df_T_JLab3['qt_to_Q']),df_T_JLab3['unpol_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_JLab3_unpol_bn['qT_Q']),df_F_JLab3_unpol_bn['xs'],color='r',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$d\sigma$',fontsize = 16)
plt.savefig('results/compare/unpol_bn_JLab3.pdf')

plt.figure()
plt.plot(np.asarray(df_T_JLab3['qt_to_Q']),df_T_JLab3['unpol_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_JLab3_unpol_rc['qT_Q']),df_F_JLab3_unpol_rc['xs'],color='r',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$d\sigma$',fontsize = 16)
plt.savefig('results/compare/unpol_rc_JLab3.pdf')

# %%
plt.figure()
F_Born_JLab3 = np.asarray(df_F_JLab3_unpol_bn['xs'])+np.asarray(df_F_JLab3_siv_bn['xs'])+np.asarray(df_F_JLab3_col_bn['xs'])
T_Born_JLab3 = np.asarray(df_T_JLab3['unpol_bn'])+np.asarray(df_T_JLab3['sivers_bn'])+np.asarray(df_T_JLab3['collins_bn'])
R_Born_JLab3 = F_Born_JLab3/T_Born_JLab3[:12]
plt.plot(np.asarray(df_F_JLab3_unpol_bn['qT_Q']),R_Born_JLab3[:12],color='b')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$R_{Born}$',fontsize=16)
plt.ylim(0.94,1.06)
plt.savefig('results/compare/compare_born_JLab3.pdf')

plt.figure()
F_RC_JLab3 = np.asarray(df_F_JLab3_unpol_rc['xs'])+np.asarray(df_F_JLab3_siv_rc['xs'])+np.asarray(df_F_JLab3_col_rc['xs'])
T_RC_JLab3 = np.asarray(df_T_JLab3['unpol_rc'])+np.asarray(df_T_JLab3['sivers_rc'])+np.asarray(df_T_JLab3['collins_rc'])
RC_T = F_Born_JLab3/F_RC_JLab3
RC_F = (T_Born_JLab3/T_RC_JLab3)[:12]
plt.plot(np.asarray(df_F_JLab3_unpol_rc['qT_Q']),RC_F/RC_T,label='$RC_F/RC_T')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize = 16)
plt.ylim(0.9,1.2)
plt.savefig('results/compare/compare_RC_JLab3.pdf')
# Out:
# /var/folders/ll/8_2_l77j4yl2zjb6stl8d9b00000gn/T/ipykernel_3871/1059515434.py:15: RuntimeWarning: invalid value encountered in true_divide
#   RC_F = (T_Born_JLab3/T_RC_JLab3)[:12]

# %%
plt.plot(np.asarray(df_T_eic3['qt_to_Q']),df_T_eic3['sivers_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_eic3_siv_bn['qT_Q']),df_F_eic3_siv_bn['xs'],color='r',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize = 16)
plt.savefig('results/compare/siv_bn_eic3.pdf')
plt.figure()
plt.plot(np.asarray(df_T_eic3['qt_to_Q']),df_T_eic3['sivers_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_eic3_siv_rc['qT_Q']),df_F_eic3_siv_rc['xs'],color='r',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize = 16)
plt.savefig('results/compare/siv_rc_eic3.pdf')

# %%
plt.plot(np.asarray(df_T_eic3['qt_to_Q']),df_T_eic3['collins_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_eic3_col_bn['qT_Q']),df_F_eic3_col_bn['xs'],color='r',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize = 16)
plt.savefig('results/compare/col_bn_eic3.pdf')
plt.figure()
plt.plot(np.asarray(df_T_eic3['qt_to_Q']),df_T_eic3['collins_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_eic3_col_rc['qT_Q']),df_F_eic3_col_rc['xs'],color='r',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize = 16)
plt.savefig('results/compare/col_rc_eic3.pdf')

# %%
plt.plot(np.asarray(df_T_eic3['qt_to_Q']),df_T_eic3['unpol_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_eic3_unpol_bn['qT_Q']),df_F_eic3_unpol_bn['xs'],color='r',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$d\sigma$',fontsize = 16)
plt.savefig('results/compare/unpol_bn_eic3.pdf')

plt.figure()
plt.plot(np.asarray(df_T_eic3['qt_to_Q']),df_T_eic3['unpol_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_eic3_unpol_rc['qT_Q']),df_F_eic3_unpol_rc['xs'],color='r',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$d\sigma$',fontsize = 16)
plt.savefig('results/compare/unpol_rc_eic3.pdf')

# %%
plt.figure()
F_Born_eic3 = np.asarray(df_F_eic3_unpol_bn['xs'])+np.asarray(df_F_eic3_siv_bn['xs'])+np.asarray(df_F_eic3_col_bn['xs'])
T_Born_eic3 = np.asarray(df_T_eic3['unpol_bn'])+np.asarray(df_T_eic3['sivers_bn'])+np.asarray(df_T_eic3['collins_bn'])
R_Born_eic3 = F_Born_eic3/T_Born_eic3[:12]
plt.plot(np.asarray(df_F_eic3_unpol_bn['qT_Q']),R_Born_eic3[:12],color='b')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$R_{Born}$',fontsize=16)
plt.ylim(0.94,1.06)
plt.savefig('results/compare/compare_born_eic3.pdf')

plt.figure()
F_RC_eic3 = np.asarray(df_F_eic3_unpol_rc['xs'])+np.asarray(df_F_eic3_siv_rc['xs'])+np.asarray(df_F_eic3_col_rc['xs'])
T_RC_eic3 = np.asarray(df_T_eic3['unpol_rc'])+np.asarray(df_T_eic3['sivers_rc'])+np.asarray(df_T_eic3['collins_rc'])
RC_T = F_Born_eic3/F_RC_eic3
RC_F = (T_Born_eic3/T_RC_eic3)[:12]
plt.plot(np.asarray(df_F_eic3_unpol_rc['qT_Q']),RC_F/RC_T,label='$RC_F/RC_T')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize = 16)
plt.ylim(0.9,1.2)
plt.savefig('results/compare/compare_RC_eic3.pdf')

# %%
plt.plot(np.asarray(df_T_eic2['qt_to_Q']),df_T_eic2['sivers_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_eic2_siv_bn['qT_Q']),df_F_eic2_siv_bn['xs'],color='r',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize = 16)
plt.savefig('results/compare/siv_bn_eic2.pdf')
plt.figure()
plt.plot(np.asarray(df_T_eic2['qt_to_Q']),df_T_eic2['sivers_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_eic2_siv_rc['qT_Q']),df_F_eic2_siv_rc['xs'],color='r',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize = 16)
plt.savefig('results/compare/siv_rc_eic2.pdf')

# %%
plt.plot(np.asarray(df_T_eic2['qt_to_Q']),df_T_eic2['collins_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_eic2_col_bn['qT_Q']),df_F_eic2_col_bn['xs'],color='r',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize = 16)
plt.savefig('results/compare/col_bn_eic2.pdf')
plt.figure()
plt.plot(np.asarray(df_T_eic2['qt_to_Q']),df_T_eic2['collins_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_eic2_col_rc['qT_Q']),df_F_eic2_col_rc['xs'],color='r',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize = 16)
plt.savefig('results/compare/col_rc_eic2.pdf')

# %%
plt.plot(np.asarray(df_T_eic2['qt_to_Q']),df_T_eic2['unpol_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_eic2_unpol_bn['qT_Q']),df_F_eic2_unpol_bn['xs'],color='r',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$d\sigma$',fontsize = 16)
plt.savefig('results/compare/unpol_bn_eic2.pdf')

plt.figure()
plt.plot(np.asarray(df_T_eic2['qt_to_Q']),df_T_eic2['unpol_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_eic2_unpol_rc['qT_Q']),df_F_eic2_unpol_rc['xs'],color='r',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$d\sigma$',fontsize = 16)
plt.savefig('results/compare/unpol_rc_eic2.pdf')

# %%
plt.figure()
F_Born_eic2 = np.asarray(df_F_eic2_unpol_bn['xs'])+np.asarray(df_F_eic2_siv_bn['xs'])+np.asarray(df_F_eic2_col_bn['xs'])
T_Born_eic2 = np.asarray(df_T_eic2['unpol_bn'])+np.asarray(df_T_eic2['sivers_bn'])+np.asarray(df_T_eic2['collins_bn'])
R_Born_eic2 = F_Born_eic2/T_Born_eic2[:12]
plt.plot(np.asarray(df_F_eic2_unpol_bn['qT_Q']),R_Born_eic2[:12],color='b')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$R_{Born}$',fontsize=16)
plt.ylim(0.94,1.06)
plt.savefig('results/compare/compare_born_eic2.pdf')

plt.figure()
F_RC_eic2 = np.asarray(df_F_eic2_unpol_rc['xs'])+np.asarray(df_F_eic2_siv_rc['xs'])+np.asarray(df_F_eic2_col_rc['xs'])
T_RC_eic2 = np.asarray(df_T_eic2['unpol_rc'])+np.asarray(df_T_eic2['sivers_rc'])+np.asarray(df_T_eic2['collins_rc'])
RC_T = F_Born_eic2/F_RC_eic2
RC_F = (T_Born_eic2/T_RC_eic2)[:12]
plt.plot(np.asarray(df_F_eic2_unpol_rc['qT_Q']),RC_F/RC_T,label='$RC_F/RC_T')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize = 16)
plt.ylim(0.9,1.2)
plt.savefig('results/compare/compare_RC_eic2.pdf')

# %%
plt.plot(np.asarray(df_T_eic1['qt_to_Q']),df_T_eic1['sivers_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_eic1_siv_bn['qT_Q']),df_F_eic1_siv_bn['xs'],color='r',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize = 16)
plt.savefig('results/compare/siv_bn_eic1.pdf')
plt.figure()
plt.plot(np.asarray(df_T_eic1['qt_to_Q']),df_T_eic1['sivers_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_eic1_siv_rc['qT_Q']),df_F_eic1_siv_rc['xs'],color='r',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize = 16)
plt.savefig('results/compare/siv_rc_eic1.pdf')

# %%
plt.plot(np.asarray(df_T_eic1['qt_to_Q']),df_T_eic1['collins_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_eic1_col_bn['qT_Q']),df_F_eic1_col_bn['xs'],color='r',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize = 16)
plt.savefig('results/compare/col_bn_eic1.pdf')
plt.figure()
plt.plot(np.asarray(df_T_eic1['qt_to_Q']),df_T_eic1['collins_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_eic1_col_rc['qT_Q']),df_F_eic1_col_rc['xs'],color='r',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize = 16)
plt.savefig('results/compare/col_rc_eic1.pdf')

# %%
plt.plot(np.asarray(df_T_eic1['qt_to_Q']),df_T_eic1['unpol_bn'],color='b',label='Traditional bn')
plt.plot(np.asarray(df_F_eic1_unpol_bn['qT_Q']),df_F_eic1_unpol_bn['xs'],color='r',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$d\sigma$',fontsize = 16)
plt.savefig('results/compare/unpol_bn_eic1.pdf')

plt.figure()
plt.plot(np.asarray(df_T_eic1['qt_to_Q']),df_T_eic1['unpol_rc'],color='b',label='Traditional rc')
plt.plot(np.asarray(df_F_eic1_unpol_rc['qT_Q']),df_F_eic1_unpol_rc['xs'],color='r',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$d\sigma$',fontsize = 16)
plt.savefig('results/compare/unpol_rc_eic1.pdf')

# %%
plt.figure()
F_Born_eic1 = np.asarray(df_F_eic1_unpol_bn['xs'])+np.asarray(df_F_eic1_siv_bn['xs'])+np.asarray(df_F_eic1_col_bn['xs'])
T_Born_eic1 = np.asarray(df_T_eic1['unpol_bn'])+np.asarray(df_T_eic1['sivers_bn'])+np.asarray(df_T_eic1['collins_bn'])
R_Born_eic1 = F_Born_eic1/T_Born_eic1[:12]
plt.plot(np.asarray(df_F_eic1_unpol_bn['qT_Q']),R_Born_eic1[:12],color='b')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$R_{Born}$',fontsize=16)
plt.ylim(0.94,1.06)
plt.savefig('results/compare/compare_born_eic1.pdf')

plt.figure()
F_RC_eic1 = np.asarray(df_F_eic1_unpol_rc['xs'])+np.asarray(df_F_eic1_siv_rc['xs'])+np.asarray(df_F_eic1_col_rc['xs'])
T_RC_eic1 = np.asarray(df_T_eic1['unpol_rc'])+np.asarray(df_T_eic1['sivers_rc'])+np.asarray(df_T_eic1['collins_rc'])
RC_T = F_Born_eic1/F_RC_eic1
RC_F = (T_Born_eic1/T_RC_eic1)[:12]
plt.plot(np.asarray(df_F_eic1_unpol_rc['qT_Q']),RC_F/RC_T,label='$RC_F/RC_T')
plt.xlabel('$qT/Q$',fontsize=16)
plt.ylabel('$RC_F/RC_T$',fontsize = 16)
plt.ylim(0.9,1.2)
plt.savefig('results/compare/compare_RC_eic1.pdf')

# %%
# Out:
# 22.5185301144

# %%
# Out:
# 4.745369333824292

# %%
# Out:
# 3.2093613071762426

# %%
# Out:
# 0.0031887755102040817
