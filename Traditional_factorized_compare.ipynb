# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
#    JLab 1: S=10.3 GeV2, Q=1.52 GeV, x=0.32, z=0.55
#    JLab 2: Eb=12 GeV, Q2=8 GeV2, x=0.48, z=0.375
#    JLab 3: Eb=24 GeV, Q2=15 GeV2, x=0.48, z=0.375
#    EIC 1: sqrt(S)=140 GeV, Q=3 GeV, y=0.4, z=0.5
#    EIC 2: sqrt(S)=140 GeV, Q=10 GeV, y=0.4, z=0.5
#    EIC 3: sqrt(S)=140 GeV, Q=5 GeV, x=0.01, z=0.5
#    qt_to_Q = PhT/x/Q

# %%
df_T_eic3 = pd.read_csv('results/Tra-results/inj-all/results-eic3.txt',delim_whitespace=True)
df_T_eic3.head()
# Out:
#    qt_to_Q  unpol_bn  err  unpol_rc     err.1  sivers_bn         err.2  \
# 0     0.05  0.009875  0.0  0.007579  0.000007   0.000003  6.320409e-13
# 1     0.10  0.008231  0.0  0.006370  0.000006   0.000004  1.093996e-12
# 2     0.15  0.006076  0.0  0.004769  0.000005   0.000004  1.289758e-12
# 3     0.20  0.003973  0.0  0.003189  0.000003   0.000004  1.227463e-12
# 4     0.25  0.002302  0.0  0.001911  0.000002   0.000002  9.945817e-13
#
#    sivers_rc         err.3    collins_bn         err.4    collins_rc  \
# 0   0.000002  3.126797e-09  3.160295e-07  5.216781e-12  3.281548e-07
# 1   0.000003  3.293999e-09  5.470140e-07  8.474286e-12  5.633221e-07
# 2   0.000003  3.233590e-09  6.448980e-07  8.986405e-12  6.557637e-07
# 3   0.000003  2.854644e-09  6.137501e-07  7.371301e-12  6.153806e-07
# 4   0.000002  2.250446e-09  4.973063e-07  4.931298e-12  4.913136e-07
#
#           err.5
# 0  3.031394e-09
# 1  3.545602e-09
# 2  3.501906e-09
# 3  2.883643e-09
# 4  2.266710e-09

# %%
df_T_eic2 = pd.read_csv('results/Tra-results/inj-all/results-eic2.txt',delim_whitespace=True)
df_T_eic2.head()
# Out:
#    qt_to_Q  unpol_bn  err  unpol_rc         err.1     sivers_bn         err.2  \
# 0     0.05  0.000375  0.0  0.000314  3.867324e-07  2.206934e-07  5.407394e-14
# 1     0.10  0.000181  0.0  0.000158  2.161711e-07  1.920459e-07  6.067086e-14
# 2     0.15  0.000054  0.0  0.000052  1.031903e-07  7.180035e-08  3.472763e-14
# 3     0.20  0.000010  0.0  0.000013  4.878019e-08  1.361080e-08  1.201876e-14
# 4     0.25  0.000001  0.0  0.000003  2.204611e-08  1.368685e-09  2.652511e-15
#
#       sivers_rc         err.3    collins_bn         err.4    collins_rc  \
# 0  1.788200e-07  2.622358e-10  2.703774e-08  4.413716e-13  3.071216e-08
# 1  1.606789e-07  2.254816e-10  3.033634e-08  3.840785e-13  3.309621e-08
# 2  6.498922e-08  1.167842e-10  1.736436e-08  1.435958e-13  1.821477e-08
# 3  1.553714e-08  5.235768e-11  6.009576e-09  2.722067e-14  6.405805e-09
# 4  3.286616e-09  3.013351e-11  1.326301e-09  2.737277e-15  1.672682e-09
#
#           err.5
# 0  2.606041e-10
# 1  2.139027e-10
# ...

# %%
df_T_eic1 = pd.read_csv('results/Tra-results/inj-all/results-eic1.txt',delim_whitespace=True)
df_T_eic1.head()
# Out:
#    qt_to_Q  unpol_bn  err  unpol_rc     err.1     sivers_bn         err.2  \
# 0     0.05  0.082480  0.0  0.073698  0.000043  3.774092e-07  8.845906e-14
# 1     0.10  0.077260  0.0  0.069147  0.000040  6.997227e-07  1.679496e-13
# 2     0.15  0.069283  0.0  0.062215  0.000035  9.249988e-07  2.310014e-13
# 3     0.20  0.059482  0.0  0.053654  0.000030  1.033288e-06  2.727945e-13
# 4     0.25  0.048891  0.0  0.044365  0.000025  1.028623e-06  2.917196e-13
#
#       sivers_rc         err.3    collins_bn         err.4    collins_rc  \
# 0  3.429881e-07  5.709146e-10  4.423078e-08  7.547923e-13  4.958992e-08
# 1  6.362328e-07  5.375377e-10  8.397719e-08  1.399397e-12  9.439674e-08
# 2  8.447189e-07  5.081603e-10  1.155040e-07  1.849934e-12  1.301662e-07
# 3  9.495574e-07  4.780441e-10  1.364012e-07  2.066504e-12  1.531083e-07
# 4  9.525548e-07  4.479895e-10  1.458641e-07  2.057175e-12  1.631642e-07
#
#           err.5
# 0  5.609107e-10
# 1  5.539320e-10
# 2  5.819250e-10
# 3  5.809472e-10
# ...

# %%
df_T_JLab2 = pd.read_csv('results/Tra-results/inj-all/results-jlab2.txt',delim_whitespace=True)
df_T_JLab2.head()
# Out:
#    qt_to_Q  unpol_bn  err  unpol_rc         err.1     sivers_bn         err.2  \
# 0     0.05  0.000087  0.0  0.000082  3.625538e-08  9.324191e-08  3.169540e-13
# 1     0.10  0.000084  0.0  0.000079  3.447479e-08  1.780502e-07  6.071224e-13
# 2     0.15  0.000078  0.0  0.000073  3.168681e-08  2.472486e-07  8.475334e-13
# 3     0.20  0.000071  0.0  0.000066  2.819474e-08  2.959165e-07  1.022076e-12
# 4     0.25  0.000062  0.0  0.000059  2.428449e-08  3.219349e-07  1.123214e-12
#
#       sivers_rc         err.3    collins_bn         err.4    collins_rc  \
# 0  8.552664e-08  9.741932e-11  1.584824e-07  1.864776e-13  1.490132e-07
# 1  1.635341e-07  1.581023e-10  3.035716e-07  3.560885e-13  2.854647e-07
# 2  2.272986e-07  2.039279e-10  4.237812e-07  4.944808e-13  3.988900e-07
# 3  2.723634e-07  2.331197e-10  5.110556e-07  5.918132e-13  4.817261e-07
# 4  2.967736e-07  2.447190e-10  5.616265e-07  6.438482e-13  5.303905e-07
#
#           err.5
# 0  1.064226e-10
# 1  1.573043e-10
# ...

# %%
df_T_JLab3 = pd.read_csv('results/Tra-results/inj-all/results-jlab3.txt',delim_whitespace=True)
df_T_JLab3.head()
# Out:
#    qt_to_Q  unpol_bn  err  unpol_rc         err.1     sivers_bn         err.2  \
# 0     0.05  0.000043  0.0  0.000040  2.096498e-08  6.185693e-08  2.690789e-13
# 1     0.10  0.000039  0.0  0.000037  1.918149e-08  1.134277e-07  4.960532e-13
# 2     0.15  0.000034  0.0  0.000032  1.660157e-08  1.472216e-07  6.498102e-13
# 3     0.20  0.000029  0.0  0.000027  1.363974e-08  1.602956e-07  7.172108e-13
# 4     0.25  0.000022  0.0  0.000021  1.056217e-08  1.544110e-07  7.039231e-13
#
#       sivers_rc         err.3    collins_bn         err.4    collins_rc  \
# 0  5.654491e-08  9.021826e-11  1.345441e-07  1.237098e-13  1.247376e-07
# 1  1.038324e-07  1.295568e-10  2.480351e-07  2.268479e-13  2.300501e-07
# 2  1.350562e-07  1.657669e-10  3.249163e-07  2.944334e-13  3.020311e-07
# 3  1.474125e-07  1.801857e-10  3.586177e-07  3.205806e-13  3.344107e-07
# 4  1.424496e-07  1.713743e-10  3.519736e-07  3.088118e-13  3.297103e-07
#
#           err.5
# 0  1.019848e-10
# 1  1.374673e-10
# ...

# %%
df_F_eic1_siv_rc = pd.read_csv('results/Fac-results/EIC_1_siv_rc.txt',delim_whitespace=True,skiprows=12)
df_F_eic1_siv_bn = pd.read_csv('results/Fac-results/EIC_1_siv_bn.txt',delim_whitespace=True,skiprows=12)
df_F_eic1_col_rc = pd.read_csv('results/Fac-results/EIC_1_col_rc.txt',delim_whitespace=True,skiprows=12)
df_F_eic1_col_bn = pd.read_csv('results/Fac-results/EIC_1_col_bn.txt',delim_whitespace=True,skiprows=12)
df_F_eic1_unpol_rc = pd.read_csv('results/Fac-results/EIC_1_unpol_rc.txt',delim_whitespace=True,skiprows=12)
df_F_eic1_unpol_bn = pd.read_csv('results/Fac-results/EIC_1_unpol_bn.txt',delim_whitespace=True,skiprows=12)

# %%
df_F_eic2_siv_rc = pd.read_csv('results/Fac-results/EIC_2_siv_rc.txt',delim_whitespace=True,skiprows=12)
df_F_eic2_siv_bn = pd.read_csv('results/Fac-results/EIC_2_siv_bn.txt',delim_whitespace=True,skiprows=12)
df_F_eic2_col_rc = pd.read_csv('results/Fac-results/EIC_2_col_rc.txt',delim_whitespace=True,skiprows=12)
df_F_eic2_col_bn = pd.read_csv('results/Fac-results/EIC_2_col_bn.txt',delim_whitespace=True,skiprows=12)
df_F_eic2_unpol_rc = pd.read_csv('results/Fac-results/EIC_2_unpol_rc.txt',delim_whitespace=True,skiprows=12)
df_F_eic2_unpol_bn = pd.read_csv('results/Fac-results/EIC_2_unpol_bn.txt',delim_whitespace=True,skiprows=12)
df_F_eic2_siv_rc.head()
# Out:
#          x    z     Q  qT_Q            xs        xs_err
# 0  0.01276  0.5  10.0  0.05  2.020001e-07  2.830289e-10
# 1  0.01276  0.5  10.0  0.10  1.775923e-07  3.079637e-10
# 2  0.01276  0.5  10.0  0.15  6.821144e-08  1.297053e-10
# 3  0.01276  0.5  10.0  0.20  1.388197e-08  3.099692e-11
# 4  0.01276  0.5  10.0  0.25  1.863405e-09  6.739420e-12

# %%
df_F_eic3_siv_rc = pd.read_csv('results/Fac-results/EIC_3_siv_rc.txt',delim_whitespace=True,skiprows=12)
df_F_eic3_siv_bn = pd.read_csv('results/Fac-results/EIC_3_siv_bn.txt',delim_whitespace=True,skiprows=12)
df_F_eic3_col_rc = pd.read_csv('results/Fac-results/EIC_3_col_rc.txt',delim_whitespace=True,skiprows=12)
df_F_eic3_col_bn = pd.read_csv('results/Fac-results/EIC_3_col_bn.txt',delim_whitespace=True,skiprows=12)
df_F_eic3_unpol_rc = pd.read_csv('results/Fac-results/EIC_3_unpol_rc.txt',delim_whitespace=True,skiprows=12)
df_F_eic3_unpol_bn = pd.read_csv('results/Fac-results/EIC_3_unpol_bn.txt',delim_whitespace=True,skiprows=12)

# %%
df_F_JLab2_siv_rc = pd.read_csv('results/Fac-results/JLab_2_siv_rc.txt',delim_whitespace=True,skiprows=12)
df_F_JLab2_siv_bn = pd.read_csv('results/Fac-results/JLab_2_siv_bn.txt',delim_whitespace=True,skiprows=12)
df_F_JLab2_col_rc = pd.read_csv('results/Fac-results/JLab_2_col_rc.txt',delim_whitespace=True,skiprows=12)
df_F_JLab2_col_bn = pd.read_csv('results/Fac-results/JLab_2_col_bn.txt',delim_whitespace=True,skiprows=12)
df_F_JLab2_unpol_rc = pd.read_csv('results/Fac-results/JLab_2_unpol_rc.txt',delim_whitespace=True,skiprows=12)
df_F_JLab2_unpol_bn = pd.read_csv('results/Fac-results/JLab_2_unpol_bn.txt',delim_whitespace=True,skiprows=12)
df_F_JLab2_siv_rc.head()
# Out:
#       x      z      Q  qT_Q            xs        xs_err
# 0  0.48  0.375  2.828  0.05  8.732731e-08  1.350437e-10
# 1  0.48  0.375  2.828  0.10  1.664322e-07  2.939237e-10
# 2  0.48  0.375  2.828  0.15  2.323079e-07  3.439296e-10
# 3  0.48  0.375  2.828  0.20  2.773488e-07  3.696180e-10
# 4  0.48  0.375  2.828  0.25  3.038099e-07  5.023426e-10

# %%
df_F_JLab3_siv_rc = pd.read_csv('results/Fac-results/JLab_3_siv_rc.txt',delim_whitespace=True,skiprows=12)
df_F_JLab3_siv_bn = pd.read_csv('results/Fac-results/JLab_3_siv_bn.txt',delim_whitespace=True,skiprows=12)
df_F_JLab3_col_rc = pd.read_csv('results/Fac-results/JLab_3_col_rc.txt',delim_whitespace=True,skiprows=12)
df_F_JLab3_col_bn = pd.read_csv('results/Fac-results/JLab_3_col_bn.txt',delim_whitespace=True,skiprows=12)
df_F_JLab3_unpol_rc = pd.read_csv('results/Fac-results/JLab_3_unpol_rc.txt',delim_whitespace=True,skiprows=12)
df_F_JLab3_unpol_bn = pd.read_csv('results/Fac-results/JLab_3_unpol_bn.txt',delim_whitespace=True,skiprows=12)
df_F_JLab3_siv_rc.head()
# Out:
#       x      z      Q  qT_Q            xs        xs_err
# 0  0.48  0.375  3.873  0.05  5.767824e-08  1.312010e-10
# 1  0.48  0.375  3.873  0.10  1.055242e-07  2.237967e-10
# 2  0.48  0.375  3.873  0.15  1.375757e-07  2.138303e-10
# 3  0.48  0.375  3.873  0.20  1.492984e-07  2.361214e-10
# 4  0.48  0.375  3.873  0.25  1.438883e-07  2.725764e-10

# %%
plt.plot(np.asarray(df_T_JLab2['qt_to_Q']),df_T_JLab2['sivers_bn'],color='r',label='Traditional bn')
plt.plot(np.asarray(df_F_JLab2_siv_bn['qT_Q']),df_F_JLab2_siv_bn['xs'],color='b',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =20)
plt.savefig('results/compare/siv_bn_JLab2.pdf')
plt.figure()
plt.plot(np.asarray(df_T_JLab2['qt_to_Q']),df_T_JLab2['sivers_rc'],color='r',label='Traditional rc')
plt.plot(np.asarray(df_F_JLab2_siv_rc['qT_Q']),df_F_JLab2_siv_rc['xs'],color='b',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =20)
plt.savefig('results/compare/siv_rc_JLab2.pdf')

# %%
plt.plot(np.asarray(df_T_JLab2['qt_to_Q']),df_T_JLab2['collins_bn'],color='r',label='Traditional bn')
plt.plot(np.asarray(df_F_JLab2_col_bn['qT_Q']),df_F_JLab2_col_bn['xs'],color='b',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =20)
plt.savefig('results/compare/col_bn_JLab2.pdf')
plt.figure()
plt.plot(np.asarray(df_T_JLab2['qt_to_Q']),df_T_JLab2['collins_rc'],color='r',label='Traditional rc')
plt.plot(np.asarray(df_F_JLab2_col_rc['qT_Q']),df_F_JLab2_col_rc['xs'],color='b',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =20)
plt.savefig('results/compare/col_rc_JLab2.pdf')

# %%
plt.plot(np.asarray(df_T_JLab2['qt_to_Q']),df_T_JLab2['unpol_bn'],color='r',label='Traditional bn')
plt.plot(np.asarray(df_F_JLab2_unpol_bn['qT_Q']),df_F_JLab2_unpol_bn['xs'],color='b',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$d\sigma$',fontsize =20)
plt.savefig('results/compare/unpol_bn_JLab2.pdf')
plt.figure()
plt.plot(np.asarray(df_F_JLab2_unpol_bn['qT_Q']),np.asarray(df_F_JLab2_unpol_bn['xs'])/np.asarray(df_T_JLab2['unpol_bn'])[:12],color='b')
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$R_{Born}$',fontsize=20)
plt.ylim(0.94,1.06)
plt.savefig('results/compare/compare_born_JLab2.pdf')
plt.figure()
plt.plot(np.asarray(df_T_JLab2['qt_to_Q']),df_T_JLab2['unpol_rc'],color='r',label='Traditional rc')
plt.plot(np.asarray(df_F_JLab2_unpol_rc['qT_Q']),df_F_JLab2_unpol_rc['xs'],color='b',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$d\sigma$',fontsize =20)
plt.savefig('results/compare/unpol_rc_JLab2.pdf')
plt.figure()
RC_T = np.asarray(df_T_JLab2['unpol_rc'])/np.asarray(df_T_JLab2['unpol_bn'])
RC_F = np.asarray(df_F_JLab2_unpol_rc['xs'])/np.asarray(df_F_JLab2_unpol_bn['xs'])
plt.plot(np.asarray(df_F_JLab2_unpol_rc['qT_Q']),RC_F/RC_T[:12],label='$RC_F/RC_T')
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$RC_F/RC_T$',fontsize =20)
plt.ylim(0.9,1.2)
plt.savefig('results/compare/compare_RC_JLab2.pdf')
# Out:
# /var/folders/ll/8_2_l77j4yl2zjb6stl8d9b00000gn/T/ipykernel_11006/3189369208.py:23: RuntimeWarning: invalid value encountered in true_divide
#   RC_T = np.asarray(df_T_JLab2['unpol_rc'])/np.asarray(df_T_JLab2['unpol_bn'])

# %%
plt.plot(np.asarray(df_T_JLab3['qt_to_Q']),df_T_JLab3['sivers_bn'],color='r',label='Traditional bn')
plt.plot(np.asarray(df_F_JLab3_siv_bn['qT_Q']),df_F_JLab3_siv_bn['xs'],color='b',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =20)
plt.savefig('results/compare/siv_bn_JLab3.pdf')
plt.figure()
plt.plot(np.asarray(df_T_JLab3['qt_to_Q']),df_T_JLab3['sivers_rc'],color='r',label='Traditional rc')
plt.plot(np.asarray(df_F_JLab3_siv_rc['qT_Q']),df_F_JLab3_siv_rc['xs'],color='b',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =20)
plt.savefig('results/compare/siv_rc_JLab3.pdf')

# %%
plt.plot(np.asarray(df_T_JLab3['qt_to_Q']),df_T_JLab3['collins_bn'],color='r',label='Traditional bn')
plt.plot(np.asarray(df_F_JLab3_col_bn['qT_Q']),df_F_JLab3_col_bn['xs'],color='b',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =20)
plt.savefig('results/compare/col_bn_JLab3.pdf')
plt.figure()
plt.plot(np.asarray(df_T_JLab3['qt_to_Q']),df_T_JLab3['collins_rc'],color='r',label='Traditional rc')
plt.plot(np.asarray(df_F_JLab3_col_rc['qT_Q']),df_F_JLab3_col_rc['xs'],color='b',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =20)
plt.savefig('results/compare/col_rc_JLab3.pdf')

# %%
plt.plot(np.asarray(df_T_JLab3['qt_to_Q']),df_T_JLab3['unpol_bn'],color='r',label='Traditional bn')
plt.plot(np.asarray(df_F_JLab3_unpol_bn['qT_Q']),df_F_JLab3_unpol_bn['xs'],color='b',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$d\sigma$',fontsize =20)
plt.savefig('results/compare/unpol_bn_JLab3.pdf')
plt.figure()
plt.plot(np.asarray(df_F_JLab3_unpol_bn['qT_Q']),np.asarray(df_F_JLab3_unpol_bn['xs'])/np.asarray(df_T_JLab3['unpol_bn'])[:12],color='b')
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$R_{Born}$',fontsize=20)
plt.ylim(0.94,1.06)
plt.savefig('results/compare/compare_born_JLab3.pdf')
plt.figure()
plt.plot(np.asarray(df_T_JLab3['qt_to_Q']),df_T_JLab3['unpol_rc'],color='r',label='Traditional rc')
plt.plot(np.asarray(df_F_JLab3_unpol_rc['qT_Q']),df_F_JLab3_unpol_rc['xs'],color='b',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$d\sigma$',fontsize =20)
plt.savefig('results/compare/unpol_rc_JLab3.pdf')
plt.figure()
RC_T = np.asarray(df_T_JLab3['unpol_rc'])/np.asarray(df_T_JLab3['unpol_bn'])
RC_F = np.asarray(df_F_JLab3_unpol_rc['xs'])/np.asarray(df_F_JLab3_unpol_bn['xs'])
plt.plot(np.asarray(df_F_JLab3_unpol_rc['qT_Q']),RC_F/RC_T[:12],label='$RC_F/RC_T')
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$RC_F/RC_T$',fontsize =20)
plt.ylim(0.9,1.2)
plt.savefig('results/compare/compare_RC_JLab3.pdf')
# Out:
# /var/folders/ll/8_2_l77j4yl2zjb6stl8d9b00000gn/T/ipykernel_11006/132770441.py:23: RuntimeWarning: invalid value encountered in true_divide
#   RC_T = np.asarray(df_T_JLab3['unpol_rc'])/np.asarray(df_T_JLab3['unpol_bn'])

# %%
plt.plot(np.asarray(df_T_eic3['qt_to_Q']),df_T_eic3['sivers_bn'],color='r',label='Traditional bn')
plt.plot(np.asarray(df_F_eic3_siv_bn['qT_Q']),df_F_eic3_siv_bn['xs'],color='b',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =20)
plt.savefig('results/compare/siv_bn_eic3.pdf')
plt.figure()
plt.plot(np.asarray(df_T_eic3['qt_to_Q']),df_T_eic3['sivers_rc'],color='r',label='Traditional rc')
plt.plot(np.asarray(df_F_eic3_siv_rc['qT_Q']),df_F_eic3_siv_rc['xs'],color='b',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =20)
plt.savefig('results/compare/siv_rc_eic3.pdf')

# %%
plt.plot(np.asarray(df_T_eic3['qt_to_Q']),df_T_eic3['collins_bn'],color='r',label='Traditional bn')
plt.plot(np.asarray(df_F_eic3_col_bn['qT_Q']),df_F_eic3_col_bn['xs'],color='b',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =20)
plt.savefig('results/compare/col_bn_eic3.pdf')
plt.figure()
plt.plot(np.asarray(df_T_eic3['qt_to_Q']),df_T_eic3['collins_rc'],color='r',label='Traditional rc')
plt.plot(np.asarray(df_F_eic3_col_rc['qT_Q']),df_F_eic3_col_rc['xs'],color='b',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =20)
plt.savefig('results/compare/col_rc_eic3.pdf')

# %%
plt.plot(np.asarray(df_T_eic3['qt_to_Q']),df_T_eic3['unpol_bn'],color='r',label='Traditional bn')
plt.plot(np.asarray(df_F_eic3_unpol_bn['qT_Q']),df_F_eic3_unpol_bn['xs'],color='b',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$d\sigma$',fontsize =20)
plt.savefig('results/compare/unpol_bn_eic3.pdf')
plt.figure()
plt.plot(np.asarray(df_F_eic3_unpol_bn['qT_Q']),np.asarray(df_F_eic3_unpol_bn['xs'])/np.asarray(df_T_eic3['unpol_bn'])[:12],color='b')
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$R_{Born}$',fontsize=20)
plt.ylim(0.94,1.06)
plt.savefig('results/compare/compare_born_eic3.pdf')
plt.figure()
plt.plot(np.asarray(df_T_eic3['qt_to_Q']),df_T_eic3['unpol_rc'],color='r',label='Traditional rc')
plt.plot(np.asarray(df_F_eic3_unpol_rc['qT_Q']),df_F_eic3_unpol_rc['xs'],color='b',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$d\sigma$',fontsize =20)
plt.savefig('results/compare/unpol_rc_eic3.pdf')
plt.figure()
RC_T = np.asarray(df_T_eic3['unpol_rc'])/np.asarray(df_T_eic3['unpol_bn'])
RC_F = np.asarray(df_F_eic3_unpol_rc['xs'])/np.asarray(df_F_eic3_unpol_bn['xs'])
plt.plot(np.asarray(df_F_eic3_unpol_rc['qT_Q']),RC_F/RC_T[:12],label='$RC_F/RC_T')
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$RC_F/RC_T$',fontsize =20)
plt.ylim(0.9,1.2)
plt.savefig('results/compare/compare_RC_eic3.pdf')

# %%
plt.plot(np.asarray(df_T_eic2['qt_to_Q']),df_T_eic2['sivers_bn'],color='r',label='Traditional bn')
plt.plot(np.asarray(df_F_eic2_siv_bn['qT_Q']),df_F_eic2_siv_bn['xs'],color='b',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =20)
plt.savefig('results/compare/siv_bn_eic2.pdf')
plt.figure()
plt.plot(np.asarray(df_T_eic2['qt_to_Q']),df_T_eic2['sivers_rc'],color='r',label='Traditional rc')
plt.plot(np.asarray(df_F_eic2_siv_rc['qT_Q']),df_F_eic2_siv_rc['xs'],color='b',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =20)
plt.savefig('results/compare/siv_rc_eic2.pdf')

# %%
plt.plot(np.asarray(df_T_eic2['qt_to_Q']),df_T_eic2['collins_bn'],color='r',label='Traditional bn')
plt.plot(np.asarray(df_F_eic2_col_bn['qT_Q']),df_F_eic2_col_bn['xs'],color='b',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =20)
plt.savefig('results/compare/col_bn_eic2.pdf')
plt.figure()
plt.plot(np.asarray(df_T_eic2['qt_to_Q']),df_T_eic2['collins_rc'],color='r',label='Traditional rc')
plt.plot(np.asarray(df_F_eic2_col_rc['qT_Q']),df_F_eic2_col_rc['xs'],color='b',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =20)
plt.savefig('results/compare/col_rc_eic2.pdf')

# %%
plt.plot(np.asarray(df_T_eic2['qt_to_Q']),df_T_eic2['unpol_bn'],color='r',label='Traditional bn')
plt.plot(np.asarray(df_F_eic2_unpol_bn['qT_Q']),df_F_eic2_unpol_bn['xs'],color='b',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$d\sigma$',fontsize =20)
plt.savefig('results/compare/unpol_bn_eic2.pdf')
plt.figure()
plt.plot(np.asarray(df_F_eic2_unpol_bn['qT_Q']),np.asarray(df_F_eic2_unpol_bn['xs'])/np.asarray(df_T_eic2['unpol_bn'])[:12],color='b')
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$R_{Born}$',fontsize=20)
plt.ylim(0.94,1.06)
plt.savefig('results/compare/compare_born_eic2.pdf')
plt.figure()
plt.plot(np.asarray(df_T_eic2['qt_to_Q']),df_T_eic2['unpol_rc'],color='r',label='Traditional rc')
plt.plot(np.asarray(df_F_eic2_unpol_rc['qT_Q']),df_F_eic2_unpol_rc['xs'],color='b',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$d\sigma$',fontsize =20)
plt.savefig('results/compare/unpol_rc_eic2.pdf')
plt.figure()
RC_T = np.asarray(df_T_eic2['unpol_rc'])/np.asarray(df_T_eic2['unpol_bn'])
RC_F = np.asarray(df_F_eic2_unpol_rc['xs'])/np.asarray(df_F_eic2_unpol_bn['xs'])
plt.plot(np.asarray(df_F_eic2_unpol_rc['qT_Q']),RC_F/RC_T[:12],label='$RC_F/RC_T')
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$RC_F/RC_T$',fontsize =20)
plt.ylim(0.9,1.2)
plt.savefig('results/compare/compare_RC_eic2.pdf')

# %%
plt.plot(np.asarray(df_T_eic1['qt_to_Q']),df_T_eic1['sivers_bn'],color='r',label='Traditional bn')
plt.plot(np.asarray(df_F_eic1_siv_bn['qT_Q']),df_F_eic1_siv_bn['xs'],color='b',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =20)
plt.savefig('results/compare/siv_bn_eic1.pdf')
plt.figure()
plt.plot(np.asarray(df_T_eic1['qt_to_Q']),df_T_eic1['sivers_rc'],color='r',label='Traditional rc')
plt.plot(np.asarray(df_F_eic1_siv_rc['qT_Q']),df_F_eic1_siv_rc['xs'],color='b',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$\int \int sin(\phi_h-\phi_s)d\sigma$',fontsize =20)
plt.savefig('results/compare/siv_rc_eic1.pdf')

# %%
plt.plot(np.asarray(df_T_eic1['qt_to_Q']),df_T_eic1['collins_bn'],color='r',label='Traditional bn')
plt.plot(np.asarray(df_F_eic1_col_bn['qT_Q']),df_F_eic1_col_bn['xs'],color='b',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =20)
plt.savefig('results/compare/col_bn_eic1.pdf')
plt.figure()
plt.plot(np.asarray(df_T_eic1['qt_to_Q']),df_T_eic1['collins_rc'],color='r',label='Traditional rc')
plt.plot(np.asarray(df_F_eic1_col_rc['qT_Q']),df_F_eic1_col_rc['xs'],color='b',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$\int \int sin(\phi_h+\phi_s)d\sigma$',fontsize =20)
plt.savefig('results/compare/col_rc_eic1.pdf')

# %%
plt.plot(np.asarray(df_T_eic1['qt_to_Q']),df_T_eic1['unpol_bn'],color='r',label='Traditional bn')
plt.plot(np.asarray(df_F_eic1_unpol_bn['qT_Q']),df_F_eic1_unpol_bn['xs'],color='b',label='Factorized bn')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$d\sigma$',fontsize =20)
plt.savefig('results/compare/unpol_bn_eic1.pdf')
plt.figure()
plt.plot(np.asarray(df_F_eic1_unpol_bn['qT_Q']),np.asarray(df_F_eic1_unpol_bn['xs'])/np.asarray(df_T_eic1['unpol_bn'])[:12],color='b')
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$R_{Born}$',fontsize=20)
plt.ylim(0.94,1.06)
plt.savefig('results/compare/compare_born_eic1.pdf')
plt.figure()
plt.plot(np.asarray(df_T_eic1['qt_to_Q']),df_T_eic1['unpol_rc'],color='r',label='Traditional rc')
plt.plot(np.asarray(df_F_eic1_unpol_rc['qT_Q']),df_F_eic1_unpol_rc['xs'],color='b',label='Factorized rc')
plt.xlim(0,0.7)
plt.legend()
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$d\sigma$',fontsize =20)
plt.savefig('results/compare/unpol_rc_eic1.pdf')
plt.figure()
RC_T = np.asarray(df_T_eic1['unpol_rc'])/np.asarray(df_T_eic1['unpol_bn'])
RC_F = np.asarray(df_F_eic1_unpol_rc['xs'])/np.asarray(df_F_eic1_unpol_bn['xs'])
plt.plot(np.asarray(df_F_eic1_unpol_rc['qT_Q']),RC_F/RC_T[:12],label='$RC_F/RC_T')
plt.xlabel('$qT/Q$',fontsize=20)
plt.ylabel('$RC_F/RC_T$',fontsize =20)
plt.ylim(0.9,1.2)
plt.savefig('results/compare/compare_RC_eic1.pdf')
