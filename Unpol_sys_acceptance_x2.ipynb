# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def Get_weighted_average(value,error):
    Factor=1
    sum_mean = 0
    sum_sigma = 0
    #print(value,error)
    for i in range(len(value)):
        #print(i,value[i],error[i])
        sum_mean += Factor*value[i]/((Factor/4*math.pi**2)**2*error[i]*error[i])
        sum_sigma += 1/((Factor/4*math.pi**2)**2*error[i]*error[i])
    if sum_sigma==0:
        print('sum_sigma 0 warning')
        return 0,0
    return sum_mean/sum_sigma,math.sqrt(1/sum_sigma)
def Get_weighted_average_phi(value,error):
    sum_mean = 0
    sum_sigma = 0
    #print(value,error)
    for i in range(len(value)):
        #print(i,value[i],error[i])
        sum_mean += value[i]/(error[i]*error[i])
        sum_sigma += 1/(error[i]*error[i])
    if sum_sigma==0:
        print('sum_sigma 0 warning')
        return 0,0
    return sum_mean/sum_sigma,math.sqrt(1/sum_sigma)
def Get_average(value1,error1,value2,error2):
    sum_mean = value1/error1**2+value2/error2**2
    sum_sigma = 1/error1**2+1/error2**2
    return sum_mean/sum_sigma,math.sqrt(1/sum_sigma)
def Get_ratio_error(value1,error1,value2,error2):#aft,bef
    #return value1/value2,abs(error1-error2)/error2
    if error1==0:
        return 1,0
    #return 1,error2/error1
    return 1,abs(error1-error2)/error1

# %%
df_default_bef_all =  pd.read_csv('../Unpol_proposal/Materials/Shuo_Vlad_unpol_cs_results/models/CS_default_bef_acc_x2/CS_default_bef_acc_x2_pip.dat',delim_whitespace=True)
print(df_default_bef_all.head())
df_default_aft_all =  pd.read_csv('../Unpol_proposal/Materials/Shuo_Vlad_unpol_cs_results/models/CS_default_aft_acc_x2/CS_default_aft_acc_x2_pip.dat',delim_whitespace=True)
# Out:
#    i  Ebeam         x      phih         y         z        Q2        pT   obs
# 0  0   11.0  0.254448 -1.645200  0.353970  0.322958  1.859027  0.056902  FUUT  \
# 1  1   11.0  0.267248 -1.491419  0.345375  0.322007  1.904805  0.060411  FUUT
# 2  2   11.0  0.253686 -0.941636  0.343184  0.323306  1.797004  0.066615  FUUT
# 3  3   11.0  0.262374 -0.937883  0.334334  0.323170  1.810574  0.067423  FUUT
# 4  4   11.0  0.272237 -0.923019  0.326073  0.322911  1.832254  0.069568  FUUT
#
#       value      stat  systrel systabs   target hadron Experiment     error
# 0  0.097023  0.000988      0.0     0.0  neutron    pi+      solid  0.000988
# 1  0.090470  0.001247      0.0     0.0  neutron    pi+      solid  0.001247
# 2  0.104566  0.000957      0.0     0.0  neutron    pi+      solid  0.000957
# 3  0.101693  0.000882      0.0     0.0  neutron    pi+      solid  0.000882
# 4  0.097515  0.000986      0.0     0.0  neutron    pi+      solid  0.000986

# %%
df_2011_bef_all =  pd.read_csv('../Unpol_proposal/Materials/Shuo_Vlad_unpol_cs_results/models/CS_mod_2011_bef_acc_x2/CS_mod_2011_bef_acc_x2_pip.dat',delim_whitespace=True)
print(df_default_bef_all.head())
df_2011_aft_all =  pd.read_csv('../Unpol_proposal/Materials/Shuo_Vlad_unpol_cs_results/models/CS_mod_2011_aft_acc_x2/CS_mod_2011_aft_acc_x2_pip.dat',delim_whitespace=True)
# Out:
#    i  Ebeam         x      phih         y         z        Q2        pT   obs
# 0  0   11.0  0.254448 -1.645200  0.353970  0.322958  1.859027  0.056902  FUUT  \
# 1  1   11.0  0.267248 -1.491419  0.345375  0.322007  1.904805  0.060411  FUUT
# 2  2   11.0  0.253686 -0.941636  0.343184  0.323306  1.797004  0.066615  FUUT
# 3  3   11.0  0.262374 -0.937883  0.334334  0.323170  1.810574  0.067423  FUUT
# 4  4   11.0  0.272237 -0.923019  0.326073  0.322911  1.832254  0.069568  FUUT
#
#       value      stat  systrel systabs   target hadron Experiment     error
# 0  0.097023  0.000988      0.0     0.0  neutron    pi+      solid  0.000988
# 1  0.090470  0.001247      0.0     0.0  neutron    pi+      solid  0.001247
# 2  0.104566  0.000957      0.0     0.0  neutron    pi+      solid  0.000957
# 3  0.101693  0.000882      0.0     0.0  neutron    pi+      solid  0.000882
# 4  0.097515  0.000986      0.0     0.0  neutron    pi+      solid  0.000986

# %%
df_2015_bef_all =  pd.read_csv('../Unpol_proposal/Materials/Shuo_Vlad_unpol_cs_results/models/CS_mod_2015_bef_acc_x2/CS_mod_2015_bef_acc_x2_pip.dat',delim_whitespace=True)
print(df_default_bef_all.head())
df_2015_aft_all =  pd.read_csv('../Unpol_proposal/Materials/Shuo_Vlad_unpol_cs_results/models/CS_mod_2015_aft_acc_x2/CS_mod_2015_aft_acc_x2_pip.dat',delim_whitespace=True)
# Out:
#    i  Ebeam         x      phih         y         z        Q2        pT   obs
# 0  0   11.0  0.254448 -1.645200  0.353970  0.322958  1.859027  0.056902  FUUT  \
# 1  1   11.0  0.267248 -1.491419  0.345375  0.322007  1.904805  0.060411  FUUT
# 2  2   11.0  0.253686 -0.941636  0.343184  0.323306  1.797004  0.066615  FUUT
# 3  3   11.0  0.262374 -0.937883  0.334334  0.323170  1.810574  0.067423  FUUT
# 4  4   11.0  0.272237 -0.923019  0.326073  0.322911  1.832254  0.069568  FUUT
#
#       value      stat  systrel systabs   target hadron Experiment     error
# 0  0.097023  0.000988      0.0     0.0  neutron    pi+      solid  0.000988
# 1  0.090470  0.001247      0.0     0.0  neutron    pi+      solid  0.001247
# 2  0.104566  0.000957      0.0     0.0  neutron    pi+      solid  0.000957
# 3  0.101693  0.000882      0.0     0.0  neutron    pi+      solid  0.000882
# 4  0.097515  0.000986      0.0     0.0  neutron    pi+      solid  0.000986

# %%
PI = math.pi
print(PI)
z_cuts=[0.3,0.4,0.5,0.6]
#z_cuts=[0.3,0.35,0.4,0.45]
#Q2_cuts=[1,2,3,4,5]
Q2_cuts=[1,1.5,2,2.5,3]
#xbj_cuts=[0,0.25]
xbj_cuts=[0.25,0.4]
#PhT_cuts = [0,0.2]
PhT_cuts = [0.2,0.4]
#PhT_cuts=[0.2,0.6]
#PhT_cuts=[0.2,0.4]
#phih_bins = [-3.14,-2.5,-2,-1.5,-1,-0.5,0,0.5,1,1.5,2,2.5,3.14]
#phih_bins =[-PI,-3*PI/5,-2*PI/5,-PI/5,PI/5,2*PI/5,3*PI/5,4*PI/5,PI]
#phih_bins =[-PI,-0.6*PI,-0.4*PI,-0.2*PI,0.2*PI,0.4*PI,0.6*PI,0.8*PI,PI]
phih_bins =[-PI,-0.6*PI,-0.2*PI,0.2*PI,0.4*PI,0.6*PI,0.8*PI,PI]
# Out:
# 3.141592653589793

# %%
df_default_bef_zQ2 = df_default_bef_all[(df_default_bef_all['Ebeam']==11)&(df_default_bef_all['x']>xbj_cuts[0])&(df_default_bef_all['x']<xbj_cuts[1])&(df_default_bef_all['pT']>PhT_cuts[0])&(df_default_bef_all['pT']<PhT_cuts[1])]
df_default_aft_zQ2 = df_default_aft_all[(df_default_aft_all['Ebeam']==11)&(df_default_aft_all['x']>xbj_cuts[0])&(df_default_aft_all['x']<xbj_cuts[1])&(df_default_aft_all['pT']>PhT_cuts[0])&(df_default_aft_all['pT']<PhT_cuts[1])]

# %%
df_2011_bef_zQ2 = df_2011_bef_all[(df_2011_bef_all['Ebeam']==11)&(df_2011_bef_all['x']>xbj_cuts[0])&(df_2011_bef_all['x']<xbj_cuts[1])&(df_2011_bef_all['pT']>PhT_cuts[0])&(df_2011_bef_all['pT']<PhT_cuts[1])]
df_2011_aft_zQ2 = df_2011_aft_all[(df_2011_aft_all['Ebeam']==11)&(df_2011_aft_all['x']>xbj_cuts[0])&(df_2011_aft_all['x']<xbj_cuts[1])&(df_2011_aft_all['pT']>PhT_cuts[0])&(df_2011_aft_all['pT']<PhT_cuts[1])]

# %%
df_2015_bef_zQ2 = df_2015_bef_all[(df_2015_bef_all['Ebeam']==11)&(df_2015_bef_all['x']>xbj_cuts[0])&(df_2015_bef_all['x']<xbj_cuts[1])&(df_2015_bef_all['pT']>PhT_cuts[0])&(df_2015_bef_all['pT']<PhT_cuts[1])]
df_2015_aft_zQ2 = df_2015_aft_all[(df_2015_aft_all['Ebeam']==11)&(df_2015_aft_all['x']>xbj_cuts[0])&(df_2015_aft_all['x']<xbj_cuts[1])&(df_2015_aft_all['pT']>PhT_cuts[0])&(df_2015_aft_all['pT']<PhT_cuts[1])]

# %%
for i_z in range(1,len(z_cuts)):
    for i_Q2 in range(1,len(Q2_cuts)):
        df_default_bef=df_default_bef_zQ2[(df_default_bef_zQ2['z']>z_cuts[i_z-1])&(df_default_bef_zQ2['z']<z_cuts[i_z])&(df_default_bef_zQ2['Q2']>Q2_cuts[i_Q2-1])&(df_default_bef_zQ2['Q2']<Q2_cuts[i_Q2])]
        df_default_aft=df_default_aft_zQ2[(df_default_aft_zQ2['z']>z_cuts[i_z-1])&(df_default_aft_zQ2['z']<z_cuts[i_z])&(df_default_aft_zQ2['Q2']>Q2_cuts[i_Q2-1])&(df_default_aft_zQ2['Q2']<Q2_cuts[i_Q2])]

        fig = plt.figure()
        ax = fig.add_subplot()
        phih_bef = df_default_bef['phih'].to_list()
        Fuu_bef = df_default_bef['value'].to_list()
        phih_aft = df_default_aft['phih'].to_list()
        Fuu_aft = df_default_aft['value'].to_list()
        plt.plot(phih_bef,np.asarray(Fuu_bef),'ro')
        plt.plot(phih_aft,np.asarray(Fuu_aft),'ko')
        #for i_phi in np.asarray(phihs):
        #    print(i_phi)
        for i_phih in phih_bins:
            plt.axvline(x=i_phih)
        #print(df_default_bef)

# %%
for i_z in range(1,len(z_cuts)):
    for i_Q2 in range(1,len(Q2_cuts)):
        df_2011_bef=df_2011_bef_zQ2[(df_2011_bef_zQ2['z']>z_cuts[i_z-1])&(df_2011_bef_zQ2['z']<z_cuts[i_z])&(df_2011_bef_zQ2['Q2']>Q2_cuts[i_Q2-1])&(df_2011_bef_zQ2['Q2']<Q2_cuts[i_Q2])]
        df_2011_aft=df_2011_aft_zQ2[(df_2011_aft_zQ2['z']>z_cuts[i_z-1])&(df_2011_aft_zQ2['z']<z_cuts[i_z])&(df_2011_aft_zQ2['Q2']>Q2_cuts[i_Q2-1])&(df_2011_aft_zQ2['Q2']<Q2_cuts[i_Q2])]

        fig = plt.figure()
        ax = fig.add_subplot()
        phih_bef = df_2011_bef['phih'].to_list()
        Fuu_bef = df_2011_bef['value'].to_list()
        phih_aft = df_2011_aft['phih'].to_list()
        Fuu_aft = df_2011_aft['value'].to_list()
        plt.plot(phih_bef,np.asarray(Fuu_bef),'ro')
        plt.plot(phih_aft,np.asarray(Fuu_aft),'ko')
        #for i_phi in np.asarray(phihs):
        #    print(i_phi)
        for i_phih in phih_bins:
            plt.axvline(x=i_phih)

# %%
for i_z in range(1,len(z_cuts)):
    for i_Q2 in range(1,len(Q2_cuts)):
        df_2015_bef=df_2015_bef_zQ2[(df_2015_bef_zQ2['z']>z_cuts[i_z-1])&(df_2015_bef_zQ2['z']<z_cuts[i_z])&(df_2015_bef_zQ2['Q2']>Q2_cuts[i_Q2-1])&(df_2015_bef_zQ2['Q2']<Q2_cuts[i_Q2])]
        df_2015_aft=df_2015_aft_zQ2[(df_2015_aft_zQ2['z']>z_cuts[i_z-1])&(df_2015_aft_zQ2['z']<z_cuts[i_z])&(df_2015_aft_zQ2['Q2']>Q2_cuts[i_Q2-1])&(df_2015_aft_zQ2['Q2']<Q2_cuts[i_Q2])]

        fig = plt.figure()
        ax = fig.add_subplot()
        phih_bef = df_2015_bef['phih'].to_list()
        Fuu_bef = df_2015_bef['value'].to_list()
        phih_aft = df_2015_aft['phih'].to_list()
        Fuu_aft = df_2015_aft['value'].to_list()
        plt.plot(phih_bef,np.asarray(Fuu_bef),'ro')
        plt.plot(phih_aft,np.asarray(Fuu_aft),'ko')
        #for i_phi in np.asarray(phihs):
        #    print(i_phi)
        for i_phih in phih_bins:
            plt.axvline(x=i_phih)

# %%
import pprint
rows = len(z_cuts)-1
cols = len(Q2_cuts)-1
row_phi = len(phih_bins)-1

phihs_default_bef={}
Fuus_default_bef = {}#[[[0]*rows]*cols]*row_phi
Fuus_err_default_bef = {}#[[[0]*rows]*cols]*row_phi
phihs_default_aft={}
Fuus_default_aft = {}#[[[0]*rows]*cols]*row_phi
Fuus_err_default_aft = {}#[[[0]*rows]*cols]*row_phi
print('rows,cols,row_phi',rows,cols,row_phi)
pprint.pprint(phihs_default_bef)
for i_z in range(1,len(z_cuts)):
    for i_Q2 in range(1,len(Q2_cuts)):
        df_default_bef=df_default_bef_zQ2[(df_default_bef_zQ2['z']>z_cuts[i_z-1])&(df_default_bef_zQ2['z']<z_cuts[i_z])&(df_default_bef_zQ2['Q2']>Q2_cuts[i_Q2-1])&(df_default_bef_zQ2['Q2']<Q2_cuts[i_Q2])]
        df_default_aft=df_default_aft_zQ2[(df_default_aft_zQ2['z']>z_cuts[i_z-1])&(df_default_aft_zQ2['z']<z_cuts[i_z])&(df_default_aft_zQ2['Q2']>Q2_cuts[i_Q2-1])&(df_default_aft_zQ2['Q2']<Q2_cuts[i_Q2])]
        fig = plt.figure()
        ax = fig.add_subplot()
        phih_default_bef = df_default_bef['phih'].to_list()
        Fuu_default_bef = df_default_bef['value'].to_list()
        phih_default_aft = df_default_aft['phih'].to_list()
        Fuu_default_aft = df_default_aft['value'].to_list()
        phih_default_bef=[]
        Fuu_default_bef=[]
        Fuu_default_bef_stat=[]
        #Fuu_default_bef_sys=[]
        phih_default_aft=[]
        Fuu_default_aft=[]
        Fuu_default_aft_stat=[]
        i_phi_left = phih_bins[0]
        i_phi_count = 0
        for i_phi in phih_bins[1:]:
            print(i_phi_left,i_phi)
            phih_default_befs = df_default_bef[(df_default_bef['phih']>=i_phi_left)&(df_default_bef['phih']<i_phi)]['phih'].tolist()
            Fuu_default_befs = df_default_bef[(df_default_bef['phih']>=i_phi_left)&(df_default_bef['phih']<i_phi)]['value'].tolist()
            Fuu_default_bef_stats = df_default_bef[(df_default_bef['phih']>=i_phi_left)&(df_default_bef['phih']<i_phi)]['stat'].tolist()
            phih_default_afts = df_default_aft[(df_default_aft['phih']>=i_phi_left)&(df_default_aft['phih']<i_phi)]['phih'].tolist()
            Fuu_default_afts = df_default_aft[(df_default_aft['phih']>=i_phi_left)&(df_default_aft['phih']<i_phi)]['value'].tolist()
            Fuu_default_aft_stats = df_default_aft[(df_default_aft['phih']>=i_phi_left)&(df_default_aft['phih']<i_phi)]['stat'].tolist()

            if len(phih_default_befs)>0:  
                #print('phih',phih_default_befs)
                #print('Fuu',Fuu_default_befs)
                #print('Fuu_stat',Fuu_default_bef_stats)
                _Fuu_default_bef = Get_weighted_average(Fuu_default_befs,Fuu_default_bef_stats)[0]
                _Fuu_default_bef_stat = Get_weighted_average(Fuu_default_befs,Fuu_default_bef_stats)[1]
                _phih_default_bef= Get_weighted_average_phi(phih_default_befs,Fuu_default_bef_stats)[0]
                _Fuu_default_aft = Get_weighted_average(Fuu_default_afts,Fuu_default_aft_stats)[0]
                _Fuu_default_aft_stat = Get_weighted_average(Fuu_default_afts,Fuu_default_aft_stats)[1]
                _phih_default_aft= Get_weighted_average_phi(phih_default_afts,Fuu_default_aft_stats)[0]

                #print('_Fuu_default_bef',_Fuu_default_bef)
                #print('_phih',_phih_default_bef)
                #print('_Fuu_stat',_Fuu_default_bef_stat)
                Fuu_default_bef.append(_Fuu_default_bef)
                phih_default_bef.append(_phih_default_bef)
                Fuu_default_bef_stat.append(_Fuu_default_bef_stat)
                Fuu_default_aft.append(_Fuu_default_aft)
                phih_default_aft.append(_phih_default_aft)
                Fuu_default_aft_stat.append(_Fuu_default_aft_stat)
                #Fuu_default_bef_sys.append(0.05*_Fuu_default_bef)
                print('z,Q2,phi',i_z-1,i_Q2-1,i_phi_count)
                phihs_default_bef[i_z-1,i_Q2-1,i_phi_count]=(_phih_default_bef)
                #pprint.pprint(phihs_default_bef)
                Fuus_default_bef[i_z-1,i_Q2-1,i_phi_count]=(_Fuu_default_bef)
                Fuus_err_default_bef[i_z-1,i_Q2-1,i_phi_count]=(_Fuu_default_bef_stat)
                phihs_default_aft[i_z-1,i_Q2-1,i_phi_count]=(_phih_default_aft)
                #pprint.pprint(phihs_default_bef)
                Fuus_default_aft[i_z-1,i_Q2-1,i_phi_count]=(_Fuu_default_aft)
                Fuus_err_default_aft[i_z-1,i_Q2-1,i_phi_count]=(_Fuu_default_aft_stat)
                i_phi_count+=1
                #print(Fuu_default_bef,phih_default_bef)
                ax.plot([_phih_default_bef,_phih_default_bef],[_Fuu_default_bef-_Fuu_default_bef_stat,_Fuu_default_bef+_Fuu_default_bef_stat],color='red',marker='_')
                ax.plot([_phih_default_aft,_phih_default_aft],[_Fuu_default_aft-_Fuu_default_aft_stat,_Fuu_default_aft+_Fuu_default_aft_stat],color='blue',marker='_')

            i_phi_left = i_phi
        plt.plot(phih_default_bef,Fuu_default_bef,'ro')
        plt.plot(phih_default_aft,Fuu_default_aft,'bo')
        plt.xlabel('$\phi_h$',fontsize=16)
        plt.ylabel('$F_{UU}$',fontsize=16)
pprint.pprint(phihs_default_bef)
# Out:
# rows,cols,row_phi 3 4 7
# {}
# -3.141592653589793 -1.8849555921538759
# -1.8849555921538759 -0.6283185307179586
# -0.6283185307179586 0.6283185307179586
# 0.6283185307179586 1.2566370614359172
# 1.2566370614359172 1.8849555921538759
# 1.8849555921538759 2.5132741228718345
# 2.5132741228718345 3.141592653589793
# -3.141592653589793 -1.8849555921538759
# -1.8849555921538759 -0.6283185307179586
# z,Q2,phi 0 1 0
# -0.6283185307179586 0.6283185307179586
# z,Q2,phi 0 1 1
# 0.6283185307179586 1.2566370614359172
# z,Q2,phi 0 1 2
# 1.2566370614359172 1.8849555921538759
# sum_sigma 0 warning
# sum_sigma 0 warning
# sum_sigma 0 warning
# z,Q2,phi 0 1 3
# 1.8849555921538759 2.5132741228718345
# 2.5132741228718345 3.141592653589793
# -3.141592653589793 -1.8849555921538759
# -1.8849555921538759 -0.6283185307179586
# z,Q2,phi 0 2 0
# -0.6283185307179586 0.6283185307179586
# z,Q2,phi 0 2 1
# 0.6283185307179586 1.2566370614359172
# z,Q2,phi 0 2 2
# 1.2566370614359172 1.8849555921538759
# ...

# %%
import pprint
rows = len(z_cuts)-1
cols = len(Q2_cuts)-1
row_phi = len(phih_bins)-1

phihs_2011_bef={}
Fuus_2011_bef = {}#[[[0]*rows]*cols]*row_phi
Fuus_err_2011_bef = {}#[[[0]*rows]*cols]*row_phi
phihs_2011_aft={}
Fuus_2011_aft = {}#[[[0]*rows]*cols]*row_phi
Fuus_err_2011_aft = {}#[[[0]*rows]*cols]*row_phi
print('rows,cols,row_phi',rows,cols,row_phi)
pprint.pprint(phihs_2011_bef)
for i_z in range(1,len(z_cuts)):
    for i_Q2 in range(1,len(Q2_cuts)):
        df_2011_bef=df_2011_bef_zQ2[(df_2011_bef_zQ2['z']>z_cuts[i_z-1])&(df_2011_bef_zQ2['z']<z_cuts[i_z])&(df_2011_bef_zQ2['Q2']>Q2_cuts[i_Q2-1])&(df_2011_bef_zQ2['Q2']<Q2_cuts[i_Q2])]
        df_2011_aft=df_2011_aft_zQ2[(df_2011_aft_zQ2['z']>z_cuts[i_z-1])&(df_2011_aft_zQ2['z']<z_cuts[i_z])&(df_2011_aft_zQ2['Q2']>Q2_cuts[i_Q2-1])&(df_2011_aft_zQ2['Q2']<Q2_cuts[i_Q2])]
        fig = plt.figure()
        ax = fig.add_subplot()
        phih_2011_bef = df_2011_bef['phih'].to_list()
        Fuu_2011_bef = df_2011_bef['value'].to_list()
        phih_2011_aft = df_2011_aft['phih'].to_list()
        Fuu_2011_aft = df_2011_aft['value'].to_list()
        phih_2011_bef=[]
        Fuu_2011_bef=[]
        Fuu_2011_bef_stat=[]
        #Fuu_2011_bef_sys=[]
        phih_2011_aft=[]
        Fuu_2011_aft=[]
        Fuu_2011_aft_stat=[]
        i_phi_left = phih_bins[0]
        i_phi_count = 0
        for i_phi in phih_bins[1:]:
            print(i_phi_left,i_phi)
            phih_2011_befs = df_2011_bef[(df_2011_bef['phih']>=i_phi_left)&(df_2011_bef['phih']<i_phi)]['phih'].tolist()
            Fuu_2011_befs = df_2011_bef[(df_2011_bef['phih']>=i_phi_left)&(df_2011_bef['phih']<i_phi)]['value'].tolist()
            Fuu_2011_bef_stats = df_2011_bef[(df_2011_bef['phih']>=i_phi_left)&(df_2011_bef['phih']<i_phi)]['stat'].tolist()
            phih_2011_afts = df_2011_aft[(df_2011_aft['phih']>=i_phi_left)&(df_2011_aft['phih']<i_phi)]['phih'].tolist()
            Fuu_2011_afts = df_2011_aft[(df_2011_aft['phih']>=i_phi_left)&(df_2011_aft['phih']<i_phi)]['value'].tolist()
            Fuu_2011_aft_stats = df_2011_aft[(df_2011_aft['phih']>=i_phi_left)&(df_2011_aft['phih']<i_phi)]['stat'].tolist()

            if len(phih_2011_befs)>0:  
                #print('phih',phih_2011_befs)
                #print('Fuu',Fuu_2011_befs)
                #print('Fuu_stat',Fuu_2011_bef_stats)
                _Fuu_2011_bef = Get_weighted_average(Fuu_2011_befs,Fuu_2011_bef_stats)[0]
                _Fuu_2011_bef_stat = Get_weighted_average(Fuu_2011_befs,Fuu_2011_bef_stats)[1]
                _phih_2011_bef= Get_weighted_average_phi(phih_2011_befs,Fuu_2011_bef_stats)[0]
                _Fuu_2011_aft = Get_weighted_average(Fuu_2011_afts,Fuu_2011_aft_stats)[0]
                _Fuu_2011_aft_stat = Get_weighted_average(Fuu_2011_afts,Fuu_2011_aft_stats)[1]
                _phih_2011_aft= Get_weighted_average_phi(phih_2011_afts,Fuu_2011_aft_stats)[0]

                #print('_Fuu_2011_bef',_Fuu_2011_bef)
                #print('_phih',_phih_2011_bef)
                #print('_Fuu_stat',_Fuu_2011_bef_stat)
                Fuu_2011_bef.append(_Fuu_2011_bef)
                phih_2011_bef.append(_phih_2011_bef)
                Fuu_2011_bef_stat.append(_Fuu_2011_bef_stat)
                Fuu_2011_aft.append(_Fuu_2011_aft)
                phih_2011_aft.append(_phih_2011_aft)
                Fuu_2011_aft_stat.append(_Fuu_2011_aft_stat)
                #Fuu_2011_bef_sys.append(0.05*_Fuu_2011_bef)
                print('z,Q2,phi',i_z-1,i_Q2-1,i_phi_count)
                phihs_2011_bef[i_z-1,i_Q2-1,i_phi_count]=(_phih_2011_bef)
                #pprint.pprint(phihs_2011_bef)
                Fuus_2011_bef[i_z-1,i_Q2-1,i_phi_count]=(_Fuu_2011_bef)
                Fuus_err_2011_bef[i_z-1,i_Q2-1,i_phi_count]=(_Fuu_2011_bef_stat)
                phihs_2011_aft[i_z-1,i_Q2-1,i_phi_count]=(_phih_2011_aft)
                #pprint.pprint(phihs_2011_bef)
                Fuus_2011_aft[i_z-1,i_Q2-1,i_phi_count]=(_Fuu_2011_aft)
                Fuus_err_2011_aft[i_z-1,i_Q2-1,i_phi_count]=(_Fuu_2011_aft_stat)
                i_phi_count+=1
                #print(Fuu_2011_bef,phih_2011_bef)
                ax.plot([_phih_2011_bef,_phih_2011_bef],[_Fuu_2011_bef-_Fuu_2011_bef_stat,_Fuu_2011_bef+_Fuu_2011_bef_stat],color='red',marker='_')
                ax.plot([_phih_2011_aft,_phih_2011_aft],[_Fuu_2011_aft-_Fuu_2011_aft_stat,_Fuu_2011_aft+_Fuu_2011_aft_stat],color='blue',marker='_')

            i_phi_left = i_phi
        plt.plot(phih_2011_bef,Fuu_2011_bef,'ro')
        plt.plot(phih_2011_aft,Fuu_2011_aft,'bo')
        plt.xlabel('$\phi_h$',fontsize=16)
        plt.ylabel('$F_{UU}$',fontsize=16)
pprint.pprint(phihs_2011_bef)
# Out:
# rows,cols,row_phi 3 4 7
# {}
# -3.141592653589793 -1.8849555921538759
# -1.8849555921538759 -0.6283185307179586
# -0.6283185307179586 0.6283185307179586
# 0.6283185307179586 1.2566370614359172
# 1.2566370614359172 1.8849555921538759
# 1.8849555921538759 2.5132741228718345
# 2.5132741228718345 3.141592653589793
# -3.141592653589793 -1.8849555921538759
# -1.8849555921538759 -0.6283185307179586
# z,Q2,phi 0 1 0
# -0.6283185307179586 0.6283185307179586
# z,Q2,phi 0 1 1
# 0.6283185307179586 1.2566370614359172
# z,Q2,phi 0 1 2
# 1.2566370614359172 1.8849555921538759
# sum_sigma 0 warning
# sum_sigma 0 warning
# sum_sigma 0 warning
# z,Q2,phi 0 1 3
# 1.8849555921538759 2.5132741228718345
# 2.5132741228718345 3.141592653589793
# -3.141592653589793 -1.8849555921538759
# -1.8849555921538759 -0.6283185307179586
# z,Q2,phi 0 2 0
# -0.6283185307179586 0.6283185307179586
# z,Q2,phi 0 2 1
# 0.6283185307179586 1.2566370614359172
# z,Q2,phi 0 2 2
# 1.2566370614359172 1.8849555921538759
# ...

# %%
import pprint
rows = len(z_cuts)-1
cols = len(Q2_cuts)-1
row_phi = len(phih_bins)-1

phihs_2015_bef={}
Fuus_2015_bef = {}#[[[0]*rows]*cols]*row_phi
Fuus_err_2015_bef = {}#[[[0]*rows]*cols]*row_phi
phihs_2015_aft={}
Fuus_2015_aft = {}#[[[0]*rows]*cols]*row_phi
Fuus_err_2015_aft = {}#[[[0]*rows]*cols]*row_phi
print('rows,cols,row_phi',rows,cols,row_phi)
pprint.pprint(phihs_2015_bef)
for i_z in range(1,len(z_cuts)):
    for i_Q2 in range(1,len(Q2_cuts)):
        df_2015_bef=df_2015_bef_zQ2[(df_2015_bef_zQ2['z']>z_cuts[i_z-1])&(df_2015_bef_zQ2['z']<z_cuts[i_z])&(df_2015_bef_zQ2['Q2']>Q2_cuts[i_Q2-1])&(df_2015_bef_zQ2['Q2']<Q2_cuts[i_Q2])]
        df_2015_aft=df_2015_aft_zQ2[(df_2015_aft_zQ2['z']>z_cuts[i_z-1])&(df_2015_aft_zQ2['z']<z_cuts[i_z])&(df_2015_aft_zQ2['Q2']>Q2_cuts[i_Q2-1])&(df_2015_aft_zQ2['Q2']<Q2_cuts[i_Q2])]
        fig = plt.figure()
        ax = fig.add_subplot()
        phih_2015_bef = df_2015_bef['phih'].to_list()
        Fuu_2015_bef = df_2015_bef['value'].to_list()
        phih_2015_aft = df_2015_aft['phih'].to_list()
        Fuu_2015_aft = df_2015_aft['value'].to_list()
        phih_2015_bef=[]
        Fuu_2015_bef=[]
        Fuu_2015_bef_stat=[]
        #Fuu_2015_bef_sys=[]
        phih_2015_aft=[]
        Fuu_2015_aft=[]
        Fuu_2015_aft_stat=[]
        i_phi_left = phih_bins[0]
        i_phi_count = 0
        for i_phi in phih_bins[1:]:
            print(i_phi_left,i_phi)
            phih_2015_befs = df_2015_bef[(df_2015_bef['phih']>=i_phi_left)&(df_2015_bef['phih']<i_phi)]['phih'].tolist()
            Fuu_2015_befs = df_2015_bef[(df_2015_bef['phih']>=i_phi_left)&(df_2015_bef['phih']<i_phi)]['value'].tolist()
            Fuu_2015_bef_stats = df_2015_bef[(df_2015_bef['phih']>=i_phi_left)&(df_2015_bef['phih']<i_phi)]['stat'].tolist()
            phih_2015_afts = df_2015_aft[(df_2015_aft['phih']>=i_phi_left)&(df_2015_aft['phih']<i_phi)]['phih'].tolist()
            Fuu_2015_afts = df_2015_aft[(df_2015_aft['phih']>=i_phi_left)&(df_2015_aft['phih']<i_phi)]['value'].tolist()
            Fuu_2015_aft_stats = df_2015_aft[(df_2015_aft['phih']>=i_phi_left)&(df_2015_aft['phih']<i_phi)]['stat'].tolist()

            if len(phih_2015_befs)>0:  
                #print('phih',phih_2015_befs)
                #print('Fuu',Fuu_2015_befs)
                #print('Fuu_stat',Fuu_2015_bef_stats)
                _Fuu_2015_bef = Get_weighted_average(Fuu_2015_befs,Fuu_2015_bef_stats)[0]
                _Fuu_2015_bef_stat = Get_weighted_average(Fuu_2015_befs,Fuu_2015_bef_stats)[1]
                _phih_2015_bef= Get_weighted_average_phi(phih_2015_befs,Fuu_2015_bef_stats)[0]
                _Fuu_2015_aft = Get_weighted_average(Fuu_2015_afts,Fuu_2015_aft_stats)[0]
                _Fuu_2015_aft_stat = Get_weighted_average(Fuu_2015_afts,Fuu_2015_aft_stats)[1]
                _phih_2015_aft= Get_weighted_average_phi(phih_2015_afts,Fuu_2015_aft_stats)[0]

                #print('_Fuu_2015_bef',_Fuu_2015_bef)
                #print('_phih',_phih_2015_bef)
                #print('_Fuu_stat',_Fuu_2015_bef_stat)
                Fuu_2015_bef.append(_Fuu_2015_bef)
                phih_2015_bef.append(_phih_2015_bef)
                Fuu_2015_bef_stat.append(_Fuu_2015_bef_stat)
                Fuu_2015_aft.append(_Fuu_2015_aft)
                phih_2015_aft.append(_phih_2015_aft)
                Fuu_2015_aft_stat.append(_Fuu_2015_aft_stat)
                #Fuu_2015_bef_sys.append(0.05*_Fuu_2015_bef)
                print('z,Q2,phi',i_z-1,i_Q2-1,i_phi_count)
                phihs_2015_bef[i_z-1,i_Q2-1,i_phi_count]=(_phih_2015_bef)
                #pprint.pprint(phihs_2015_bef)
                Fuus_2015_bef[i_z-1,i_Q2-1,i_phi_count]=(_Fuu_2015_bef)
                Fuus_err_2015_bef[i_z-1,i_Q2-1,i_phi_count]=(_Fuu_2015_bef_stat)
                phihs_2015_aft[i_z-1,i_Q2-1,i_phi_count]=(_phih_2015_aft)
                #pprint.pprint(phihs_2015_bef)
                Fuus_2015_aft[i_z-1,i_Q2-1,i_phi_count]=(_Fuu_2015_aft)
                Fuus_err_2015_aft[i_z-1,i_Q2-1,i_phi_count]=(_Fuu_2015_aft_stat)
                i_phi_count+=1
                #print(Fuu_2015_bef,phih_2015_bef)
                ax.plot([_phih_2015_bef,_phih_2015_bef],[_Fuu_2015_bef-_Fuu_2015_bef_stat,_Fuu_2015_bef+_Fuu_2015_bef_stat],color='red',marker='_')
                ax.plot([_phih_2015_aft,_phih_2015_aft],[_Fuu_2015_aft-_Fuu_2015_aft_stat,_Fuu_2015_aft+_Fuu_2015_aft_stat],color='blue',marker='_')

            i_phi_left = i_phi
        plt.plot(phih_2015_bef,Fuu_2015_bef,'ro')
        plt.plot(phih_2015_aft,Fuu_2015_aft,'bo')
        plt.xlabel('$\phi_h$',fontsize=16)
        plt.ylabel('$F_{UU}$',fontsize=16)
pprint.pprint(phihs_2015_bef)
# Out:
# rows,cols,row_phi 3 4 7
# {}
# -3.141592653589793 -1.8849555921538759
# -1.8849555921538759 -0.6283185307179586
# -0.6283185307179586 0.6283185307179586
# 0.6283185307179586 1.2566370614359172
# 1.2566370614359172 1.8849555921538759
# 1.8849555921538759 2.5132741228718345
# 2.5132741228718345 3.141592653589793
# -3.141592653589793 -1.8849555921538759
# -1.8849555921538759 -0.6283185307179586
# z,Q2,phi 0 1 0
# -0.6283185307179586 0.6283185307179586
# z,Q2,phi 0 1 1
# 0.6283185307179586 1.2566370614359172
# z,Q2,phi 0 1 2
# 1.2566370614359172 1.8849555921538759
# sum_sigma 0 warning
# sum_sigma 0 warning
# sum_sigma 0 warning
# z,Q2,phi 0 1 3
# 1.8849555921538759 2.5132741228718345
# 2.5132741228718345 3.141592653589793
# -3.141592653589793 -1.8849555921538759
# -1.8849555921538759 -0.6283185307179586
# z,Q2,phi 0 2 0
# -0.6283185307179586 0.6283185307179586
# z,Q2,phi 0 2 1
# 0.6283185307179586 1.2566370614359172
# z,Q2,phi 0 2 2
# 1.2566370614359172 1.8849555921538759
# ...

# %%
for i_z in range(1,len(z_cuts)):
    for i_Q2 in range(1,len(Q2_cuts)):
        fig = plt.figure()
        ax = fig.add_subplot()
        for i_phi in range(0,len(phih_bins)-1):
            
            try:
                
                phih = phihs_default_bef[i_z-1,i_Q2-1,i_phi]
                Fuu_default_aft = Fuus_default_aft[i_z-1,i_Q2-1,i_phi]
                Fuu_err_default_aft = Fuus_err_default_aft[i_z-1,i_Q2-1,i_phi]
                #Fuu_kT4 = Fuus_kT4[i_z-1,i_Q2-1,i_phi]
                #Fuu_err_kT4 = Fuus_err_kT4[i_z-1,i_Q2-1,i_phi]
                Fuu_default_bef = Fuus_default_bef[i_z-1,i_Q2-1,i_phi]
                Fuu_err_default_bef = Fuus_err_default_bef[i_z-1,i_Q2-1,i_phi]
                print(Fuu_err_default_aft,Fuu_err_default_bef)
                _Fuu_ratio,_Fuu_ratio_err = Get_ratio_error(Fuu_default_aft,Fuu_err_default_aft,Fuu_default_bef,Fuu_err_default_bef)
                #_Fuu_ratio2,_Fuu_ratio2_err = Get_ratio_error(Fuu_kT4,Fuu_err_kT4,Fuu_default_bef,Fuu_err_default_bef)
                #Fuu_ratio = (_Fuu_ratio+_Fuu_ratio2)/2
                #Fuu_ratio_err = (_Fuu_ratio_err+_Fuu_ratio2_err)/2
                Fuu_ratio=_Fuu_ratio
                Fuu_ratio_err=_Fuu_ratio_err
                ax.plot([phih,phih],[Fuu_ratio-Fuu_ratio_err,Fuu_ratio+Fuu_ratio_err],color='black',marker='_')
                plt.plot(phih,Fuu_ratio,'ko')
                plt.axhline(1,color = 'black',linestyle = ':')
                ax.text(0.5,0.9,r'${}<z_h<{}\ \ {}<Q^2<{}$'.format(z_cuts[i_z-1],z_cuts[i_z],Q2_cuts[i_Q2-1],Q2_cuts[i_Q2]), horizontalalignment='center', verticalalignment='center',transform=ax.transAxes)
                ax.text(0.5,0.8,r'${}<x_{{b}}<{}\ \ {}<P_{{hT}}<{}$'.format(xbj_cuts[0],xbj_cuts[1],PhT_cuts[0],PhT_cuts[1]), horizontalalignment='center', verticalalignment='center',transform=ax.transAxes)

                #plt.plot(phihs_kT4[i_z-1,i_Q2-1,i_phi],Fuus_kT4[i_z-1,i_Q2-1,i_phi],'bo',label='kT=0.404')
            except KeyError:
                print('no data here i_z,i_Q2,i_phi',i_z,i_Q2,i_phi)
        plt.xlabel('$\phi_h$',fontsize=16)
        plt.ylabel('$default$',fontsize=16)
# Out:
# no data here i_z,i_Q2,i_phi 1 1 0
# no data here i_z,i_Q2,i_phi 1 1 1
# no data here i_z,i_Q2,i_phi 1 1 2
# no data here i_z,i_Q2,i_phi 1 1 3
# no data here i_z,i_Q2,i_phi 1 1 4
# no data here i_z,i_Q2,i_phi 1 1 5
# no data here i_z,i_Q2,i_phi 1 1 6
# 0.0006619839561755643 0.0003536906352808463
# 0.0009772568967821305 0.00047656989554330784
# 0.0006636750097347522 0.0003560915913248723
# 0 0.0030269952272956716
# no data here i_z,i_Q2,i_phi 1 2 4
# no data here i_z,i_Q2,i_phi 1 2 5
# no data here i_z,i_Q2,i_phi 1 2 6
# 0.0004417367464738903 0.00025032429258158104
# 0.0007945864152155752 0.00039769661702028936
# 0.00046121203421055514 0.0002649847244868417
# 0.0015874747605088542 0.0007642483606169388
# no data here i_z,i_Q2,i_phi 1 3 4
# no data here i_z,i_Q2,i_phi 1 3 5
# no data here i_z,i_Q2,i_phi 1 3 6
# 0 0.0014199258885606134
# 0.00040784414044346305 0.0002450882355390321
# 0.000876730081839203 0.00046073366241011353
# 0.00047437466964764187 0.0002856476497828357
# ...

# %%
for i_z in range(1,len(z_cuts)):
    for i_Q2 in range(1,len(Q2_cuts)):
        fig = plt.figure()
        ax = fig.add_subplot()
        for i_phi in range(0,len(phih_bins)-1):
            
            try:
                
                phih = phihs_2011_bef[i_z-1,i_Q2-1,i_phi]
                Fuu_2011_aft = Fuus_2011_aft[i_z-1,i_Q2-1,i_phi]
                Fuu_err_2011_aft = Fuus_err_2011_aft[i_z-1,i_Q2-1,i_phi]
                #Fuu_kT4 = Fuus_kT4[i_z-1,i_Q2-1,i_phi]
                #Fuu_err_kT4 = Fuus_err_kT4[i_z-1,i_Q2-1,i_phi]
                Fuu_2011_bef = Fuus_2011_bef[i_z-1,i_Q2-1,i_phi]
                Fuu_err_2011_bef = Fuus_err_2011_bef[i_z-1,i_Q2-1,i_phi]
                _Fuu_ratio,_Fuu_ratio_err = Get_ratio_error(Fuu_2011_aft,Fuu_err_2011_aft,Fuu_2011_bef,Fuu_err_2011_bef)
                #_Fuu_ratio2,_Fuu_ratio2_err = Get_ratio_error(Fuu_kT4,Fuu_err_kT4,Fuu_2011_bef,Fuu_err_2011_bef)
                #Fuu_ratio = (_Fuu_ratio+_Fuu_ratio2)/2
                #Fuu_ratio_err = (_Fuu_ratio_err+_Fuu_ratio2_err)/2
                Fuu_ratio=_Fuu_ratio
                Fuu_ratio_err=_Fuu_ratio_err
                ax.plot([phih,phih],[Fuu_ratio-Fuu_ratio_err,Fuu_ratio+Fuu_ratio_err],color='black',marker='_')
                plt.plot(phih,Fuu_ratio,'ko')
                plt.axhline(1,color = 'black',linestyle = ':')
                ax.text(0.5,0.9,r'${}<z_h<{}\ \ {}<Q^2<{}$'.format(z_cuts[i_z-1],z_cuts[i_z],Q2_cuts[i_Q2-1],Q2_cuts[i_Q2]), horizontalalignment='center', verticalalignment='center',transform=ax.transAxes)
                ax.text(0.5,0.8,r'${}<x_{{b}}<{}\ \ {}<P_{{hT}}<{}$'.format(xbj_cuts[0],xbj_cuts[1],PhT_cuts[0],PhT_cuts[1]), horizontalalignment='center', verticalalignment='center',transform=ax.transAxes)

                #plt.plot(phihs_kT4[i_z-1,i_Q2-1,i_phi],Fuus_kT4[i_z-1,i_Q2-1,i_phi],'bo',label='kT=0.404')
            except KeyError:
                print('no data here i_z,i_Q2,i_phi',i_z,i_Q2,i_phi)
        plt.xlabel('$\phi_h$',fontsize=16)
        plt.ylabel('$2011$',fontsize=16)
# Out:
# no data here i_z,i_Q2,i_phi 1 1 0
# no data here i_z,i_Q2,i_phi 1 1 1
# no data here i_z,i_Q2,i_phi 1 1 2
# no data here i_z,i_Q2,i_phi 1 1 3
# no data here i_z,i_Q2,i_phi 1 1 4
# no data here i_z,i_Q2,i_phi 1 1 5
# no data here i_z,i_Q2,i_phi 1 1 6
# no data here i_z,i_Q2,i_phi 1 2 4
# no data here i_z,i_Q2,i_phi 1 2 5
# no data here i_z,i_Q2,i_phi 1 2 6
# no data here i_z,i_Q2,i_phi 1 3 4
# no data here i_z,i_Q2,i_phi 1 3 5
# no data here i_z,i_Q2,i_phi 1 3 6
# no data here i_z,i_Q2,i_phi 2 1 0
# no data here i_z,i_Q2,i_phi 2 1 1
# no data here i_z,i_Q2,i_phi 2 1 2
# no data here i_z,i_Q2,i_phi 2 1 3
# no data here i_z,i_Q2,i_phi 2 1 4
# no data here i_z,i_Q2,i_phi 2 1 5
# no data here i_z,i_Q2,i_phi 2 1 6
# no data here i_z,i_Q2,i_phi 2 2 4
# no data here i_z,i_Q2,i_phi 2 2 5
# no data here i_z,i_Q2,i_phi 2 2 6
# no data here i_z,i_Q2,i_phi 2 3 4
# no data here i_z,i_Q2,i_phi 2 3 5
# no data here i_z,i_Q2,i_phi 2 3 6
# no data here i_z,i_Q2,i_phi 3 1 0
# ...

# %%
for i_z in range(1,len(z_cuts)):
    for i_Q2 in range(1,len(Q2_cuts)):
        fig = plt.figure()
        ax = fig.add_subplot()
        for i_phi in range(0,len(phih_bins)-1):
            
            try:
                
                phih = phihs_2015_bef[i_z-1,i_Q2-1,i_phi]
                Fuu_2015_aft = Fuus_2015_aft[i_z-1,i_Q2-1,i_phi]
                Fuu_err_2015_aft = Fuus_err_2015_aft[i_z-1,i_Q2-1,i_phi]
                #Fuu_kT4 = Fuus_kT4[i_z-1,i_Q2-1,i_phi]
                #Fuu_err_kT4 = Fuus_err_kT4[i_z-1,i_Q2-1,i_phi]
                Fuu_2015_bef = Fuus_2015_bef[i_z-1,i_Q2-1,i_phi]
                Fuu_err_2015_bef = Fuus_err_2015_bef[i_z-1,i_Q2-1,i_phi]
                _Fuu_ratio,_Fuu_ratio_err = Get_ratio_error(Fuu_2015_aft,Fuu_err_2015_aft,Fuu_2015_bef,Fuu_err_2015_bef)
                #_Fuu_ratio2,_Fuu_ratio2_err = Get_ratio_error(Fuu_kT4,Fuu_err_kT4,Fuu_2015_bef,Fuu_err_2015_bef)
                #Fuu_ratio = (_Fuu_ratio+_Fuu_ratio2)/2
                #Fuu_ratio_err = (_Fuu_ratio_err+_Fuu_ratio2_err)/2
                Fuu_ratio=_Fuu_ratio
                Fuu_ratio_err=_Fuu_ratio_err
                ax.plot([phih,phih],[Fuu_ratio-Fuu_ratio_err,Fuu_ratio+Fuu_ratio_err],color='black',marker='_')
                plt.plot(phih,Fuu_ratio,'ko')
                plt.axhline(1,color = 'black',linestyle = ':')
                ax.text(0.5,0.9,r'${}<z_h<{}\ \ {}<Q^2<{}$'.format(z_cuts[i_z-1],z_cuts[i_z],Q2_cuts[i_Q2-1],Q2_cuts[i_Q2]), horizontalalignment='center', verticalalignment='center',transform=ax.transAxes)
                ax.text(0.5,0.8,r'${}<x_{{b}}<{}\ \ {}<P_{{hT}}<{}$'.format(xbj_cuts[0],xbj_cuts[1],PhT_cuts[0],PhT_cuts[1]), horizontalalignment='center', verticalalignment='center',transform=ax.transAxes)

                #plt.plot(phihs_kT4[i_z-1,i_Q2-1,i_phi],Fuus_kT4[i_z-1,i_Q2-1,i_phi],'bo',label='kT=0.404')
            except KeyError:
                print('no data here i_z,i_Q2,i_phi',i_z,i_Q2,i_phi)
        plt.xlabel('$\phi_h$',fontsize=16)
        plt.ylabel('$2015$',fontsize=16)
# Out:
# no data here i_z,i_Q2,i_phi 1 1 0
# no data here i_z,i_Q2,i_phi 1 1 1
# no data here i_z,i_Q2,i_phi 1 1 2
# no data here i_z,i_Q2,i_phi 1 1 3
# no data here i_z,i_Q2,i_phi 1 1 4
# no data here i_z,i_Q2,i_phi 1 1 5
# no data here i_z,i_Q2,i_phi 1 1 6
# no data here i_z,i_Q2,i_phi 1 2 4
# no data here i_z,i_Q2,i_phi 1 2 5
# no data here i_z,i_Q2,i_phi 1 2 6
# no data here i_z,i_Q2,i_phi 1 3 4
# no data here i_z,i_Q2,i_phi 1 3 5
# no data here i_z,i_Q2,i_phi 1 3 6
# no data here i_z,i_Q2,i_phi 2 1 0
# no data here i_z,i_Q2,i_phi 2 1 1
# no data here i_z,i_Q2,i_phi 2 1 2
# no data here i_z,i_Q2,i_phi 2 1 3
# no data here i_z,i_Q2,i_phi 2 1 4
# no data here i_z,i_Q2,i_phi 2 1 5
# no data here i_z,i_Q2,i_phi 2 1 6
# no data here i_z,i_Q2,i_phi 2 2 4
# no data here i_z,i_Q2,i_phi 2 2 5
# no data here i_z,i_Q2,i_phi 2 2 6
# no data here i_z,i_Q2,i_phi 2 3 4
# no data here i_z,i_Q2,i_phi 2 3 5
# no data here i_z,i_Q2,i_phi 2 3 6
# no data here i_z,i_Q2,i_phi 3 1 0
# ...

# %%
for i_z in range(1,len(z_cuts)):
    for i_Q2 in range(1,len(Q2_cuts)):
        fig = plt.figure()
        ax = fig.add_subplot()
        for i_phi in range(0,len(phih_bins)-1):
            
            try:
                
                phih_2015 = phihs_2015_bef[i_z-1,i_Q2-1,i_phi]
                Fuu_2015_aft = Fuus_2015_aft[i_z-1,i_Q2-1,i_phi]
                Fuu_err_2015_aft = Fuus_err_2015_aft[i_z-1,i_Q2-1,i_phi]
                #Fuu_kT4 = Fuus_kT4[i_z-1,i_Q2-1,i_phi]
                #Fuu_err_kT4 = Fuus_err_kT4[i_z-1,i_Q2-1,i_phi]
                Fuu_2015_bef = Fuus_2015_bef[i_z-1,i_Q2-1,i_phi]
                Fuu_err_2015_bef = Fuus_err_2015_bef[i_z-1,i_Q2-1,i_phi]
                ax.plot([phih_2015,phih_2015],[Fuu_2015_bef-Fuu_err_2015_bef,Fuu_2015_bef+Fuu_err_2015_bef],color='black',marker='_')
                plt.plot(phih_2015,Fuu_2015_bef,'ko')
                ax.plot([phih_2015,phih_2015],[Fuu_2015_aft-Fuu_err_2015_aft,Fuu_2015_aft+Fuu_err_2015_aft],color='black',marker='_')
                plt.plot(phih_2015,Fuu_2015_aft,'k',marker=11)
            
                phih_2011 = phihs_2011_bef[i_z-1,i_Q2-1,i_phi]+0.1
                Fuu_2011_aft = Fuus_2011_aft[i_z-1,i_Q2-1,i_phi]
                Fuu_err_2011_aft = Fuus_err_2011_aft[i_z-1,i_Q2-1,i_phi]
                #Fuu_kT4 = Fuus_kT4[i_z-1,i_Q2-1,i_phi]
                #Fuu_err_kT4 = Fuus_err_kT4[i_z-1,i_Q2-1,i_phi]
                Fuu_2011_bef = Fuus_2011_bef[i_z-1,i_Q2-1,i_phi]
                Fuu_err_2011_bef = Fuus_err_2011_bef[i_z-1,i_Q2-1,i_phi]
                ax.plot([phih_2011,phih_2011],[Fuu_2011_bef-Fuu_err_2011_bef,Fuu_2011_bef+Fuu_err_2011_bef],color='blue',marker='_')
                plt.plot(phih_2011,Fuu_2011_bef,'bo')
                ax.plot([phih_2011,phih_2011],[Fuu_2011_aft-Fuu_err_2011_aft,Fuu_2011_aft+Fuu_err_2011_aft],color='blue',marker='_')
                plt.plot(phih_2011,Fuu_2011_aft,'b',marker=11)
            
                phih_default = phihs_default_bef[i_z-1,i_Q2-1,i_phi]+0.2
                Fuu_default_aft = Fuus_default_aft[i_z-1,i_Q2-1,i_phi]
                Fuu_err_default_aft = Fuus_err_default_aft[i_z-1,i_Q2-1,i_phi]
                #Fuu_kT4 = Fuus_kT4[i_z-1,i_Q2-1,i_phi]
                #Fuu_err_kT4 = Fuus_err_kT4[i_z-1,i_Q2-1,i_phi]
                Fuu_default_bef = Fuus_default_bef[i_z-1,i_Q2-1,i_phi]
                Fuu_err_default_bef = Fuus_err_default_bef[i_z-1,i_Q2-1,i_phi]
                ax.plot([phih_default,phih_default],[Fuu_default_bef-Fuu_err_default_bef,Fuu_default_bef+Fuu_err_default_bef],color='red',marker='_')
                plt.plot(phih_default,Fuu_default_bef,'ro')
                ax.plot([phih_default,phih_default],[Fuu_default_aft-Fuu_err_default_aft,Fuu_default_aft+Fuu_err_default_aft],color='red',marker='_')
                plt.plot(phih_default,Fuu_default_aft,'r',marker=11)
                
                
                ax.text(0.5,0.9,r'${}<z_h<{}\ \ {}<Q^2<{}$'.format(z_cuts[i_z-1],z_cuts[i_z],Q2_cuts[i_Q2-1],Q2_cuts[i_Q2]), horizontalalignment='center', verticalalignment='center',transform=ax.transAxes)
                ax.text(0.5,0.8,r'${}<x_{{b}}<{}\ \ {}<P_{{hT}}<{}$'.format(xbj_cuts[0],xbj_cuts[1],PhT_cuts[0],PhT_cuts[1]), horizontalalignment='center', verticalalignment='center',transform=ax.transAxes)

                #plt.plot(phihs_kT4[i_z-1,i_Q2-1,i_phi],Fuus_kT4[i_z-1,i_Q2-1,i_phi],'bo',label='kT=0.404')
            except KeyError:
                print('no data here i_z,i_Q2,i_phi',i_z,i_Q2,i_phi)
        plt.xlabel('$\phi_h$',fontsize=16)
        plt.ylabel('$2015$',fontsize=16)
# Out:
# no data here i_z,i_Q2,i_phi 1 1 0
# no data here i_z,i_Q2,i_phi 1 1 1
# no data here i_z,i_Q2,i_phi 1 1 2
# no data here i_z,i_Q2,i_phi 1 1 3
# no data here i_z,i_Q2,i_phi 1 1 4
# no data here i_z,i_Q2,i_phi 1 1 5
# no data here i_z,i_Q2,i_phi 1 1 6
# no data here i_z,i_Q2,i_phi 1 2 4
# no data here i_z,i_Q2,i_phi 1 2 5
# no data here i_z,i_Q2,i_phi 1 2 6
# no data here i_z,i_Q2,i_phi 1 3 4
# no data here i_z,i_Q2,i_phi 1 3 5
# no data here i_z,i_Q2,i_phi 1 3 6
# no data here i_z,i_Q2,i_phi 2 1 0
# no data here i_z,i_Q2,i_phi 2 1 1
# no data here i_z,i_Q2,i_phi 2 1 2
# no data here i_z,i_Q2,i_phi 2 1 3
# no data here i_z,i_Q2,i_phi 2 1 4
# no data here i_z,i_Q2,i_phi 2 1 5
# no data here i_z,i_Q2,i_phi 2 1 6
# no data here i_z,i_Q2,i_phi 2 2 4
# no data here i_z,i_Q2,i_phi 2 2 5
# no data here i_z,i_Q2,i_phi 2 2 6
# no data here i_z,i_Q2,i_phi 2 3 4
# no data here i_z,i_Q2,i_phi 2 3 5
# no data here i_z,i_Q2,i_phi 2 3 6
# no data here i_z,i_Q2,i_phi 3 1 0
# ...

# %%
f=open('../Unpol_proposal/Materials/results_sys/acceptance_errorbar_ratio.txt','w')
for i_z in range(1,len(z_cuts)):
    for i_Q2 in range(1,len(Q2_cuts)):
        fig = plt.figure()
        ax = fig.add_subplot()
        for i_phi in range(0,len(phih_bins)-1):
            
            try:
                
                phih_2015 = phihs_2015_bef[i_z-1,i_Q2-1,i_phi]
                Fuu_2015_aft = Fuus_2015_aft[i_z-1,i_Q2-1,i_phi]
                Fuu_err_2015_aft = Fuus_err_2015_aft[i_z-1,i_Q2-1,i_phi]
                #Fuu_kT4 = Fuus_kT4[i_z-1,i_Q2-1,i_phi]
                #Fuu_err_kT4 = Fuus_err_kT4[i_z-1,i_Q2-1,i_phi]
                Fuu_2015_bef = Fuus_2015_bef[i_z-1,i_Q2-1,i_phi]
                Fuu_err_2015_bef = Fuus_err_2015_bef[i_z-1,i_Q2-1,i_phi]
                #ax.plot([phih_2015,phih_2015],[1-Fuu_err_2015_bef,1+Fuu_err_2015_bef],color='black',marker='_')
                #plt.plot(phih_2015,Fuu_2015_bef,'ko')
                #ax.plot([phih_2015+0.05,phih_2015+0.05],[1-Fuu_err_2015_aft,1+Fuu_err_2015_aft],color='black',marker='_')
                #plt.plot(phih_2015,Fuu_2015_aft,'k',marker=11)
            
                phih_2011 = phihs_2011_bef[i_z-1,i_Q2-1,i_phi]+0.1
                Fuu_2011_aft = Fuus_2011_aft[i_z-1,i_Q2-1,i_phi]
                Fuu_err_2011_aft = Fuus_err_2011_aft[i_z-1,i_Q2-1,i_phi]
                #Fuu_kT4 = Fuus_kT4[i_z-1,i_Q2-1,i_phi]
                #Fuu_err_kT4 = Fuus_err_kT4[i_z-1,i_Q2-1,i_phi]
                Fuu_2011_bef = Fuus_2011_bef[i_z-1,i_Q2-1,i_phi]
                Fuu_err_2011_bef = Fuus_err_2011_bef[i_z-1,i_Q2-1,i_phi]
                #ax.plot([phih_2011,phih_2011],[1-Fuu_err_2011_bef,1+Fuu_err_2011_bef],color='blue',marker='_')
                #plt.plot(phih_2011,Fuu_2011_bef,'bo')
                #ax.plot([phih_2011+0.05,phih_2011+0.05],[1-Fuu_err_2011_aft,1+Fuu_err_2011_aft],color='blue',marker='_')
                #plt.plot(phih_2011,Fuu_2011_aft,'b',marker=11)
            
                phih_default = phihs_default_bef[i_z-1,i_Q2-1,i_phi]+0.2
                Fuu_default_aft = Fuus_default_aft[i_z-1,i_Q2-1,i_phi]
                Fuu_err_default_aft = Fuus_err_default_aft[i_z-1,i_Q2-1,i_phi]
                #Fuu_kT4 = Fuus_kT4[i_z-1,i_Q2-1,i_phi]
                #Fuu_err_kT4 = Fuus_err_kT4[i_z-1,i_Q2-1,i_phi]
                Fuu_default_bef = Fuus_default_bef[i_z-1,i_Q2-1,i_phi]
                Fuu_err_default_bef = Fuus_err_default_bef[i_z-1,i_Q2-1,i_phi]
                #ax.plot([phih_default,phih_default],[1-Fuu_err_default_bef,1+Fuu_err_default_bef],color='red',marker='_')
                #plt.plot(phih_default,Fuu_default_bef,'ro')
                #ax.plot([phih_default+0.05,phih_default+0.05],[1-Fuu_err_default_aft,1+Fuu_err_default_aft],color='red',marker='_')
                #plt.plot(phih_default,Fuu_default_aft,'r',marker=11)
                #print('2015',Fuu_err_2015_bef,Fuu_err_2015_aft)
                #print('2011',Fuu_err_2011_bef,Fuu_err_2011_aft)
                #print('default',Fuu_err_default_bef,Fuu_err_default_aft)
                if Fuu_err_2011_aft>0 and Fuu_err_default_aft>0:
                    
                    print('high edge of z,Q2,phi',z_cuts[i_z],Q2_cuts[i_Q2],phih_bins[i_phi+1],file=f)
                    #print('2015/2011 bef',Fuu_err_2015_bef/Fuu_err_2011_bef,'2015/2011 aft',Fuu_err_2015_aft/Fuu_err_2011_aft,file=f)
                    #print('2015/default bef',Fuu_err_2015_bef/Fuu_err_default_bef,'2015/default aft',Fuu_err_2015_aft/Fuu_err_default_aft,file=f)
                    #print('2011/default bef',Fuu_err_2011_bef/Fuu_err_default_bef,'2011/default aft',Fuu_err_2011_aft/Fuu_err_default_aft,file=f)
                    bef_1 = Fuu_err_2011_bef/Fuu_err_default_aft
                    bef_2 = Fuu_err_default_bef/Fuu_err_2011_aft
                    ratio = abs(bef_1-bef_2)/bef_1
                    print('2011 bef/default aft',bef_1,'default bef/2011 aft',bef_2,'ratio',ratio,file=f)
                    #print('2011 bef/default aft',Fuu_err_2011_bef/Fuu_err_default_aft,'default bef/2011 aft',Fuu_err_default_bef/Fuu_err_2011_aft,file=f)
                    ax.plot(phih_default,ratio,'ko')
                ax.text(0.5,0.9,r'${}<z_h<{}\ \ {}<Q^2<{}$'.format(z_cuts[i_z-1],z_cuts[i_z],Q2_cuts[i_Q2-1],Q2_cuts[i_Q2]), horizontalalignment='center', verticalalignment='center',transform=ax.transAxes)
                ax.text(0.5,0.8,r'${}<x_{{b}}<{}\ \ {}<P_{{hT}}<{}$'.format(xbj_cuts[0],xbj_cuts[1],PhT_cuts[0],PhT_cuts[1]), horizontalalignment='center', verticalalignment='center',transform=ax.transAxes)

                #plt.plot(phihs_kT4[i_z-1,i_Q2-1,i_phi],Fuus_kT4[i_z-1,i_Q2-1,i_phi],'bo',label='kT=0.404')
            except KeyError:
                print('no data here i_z,i_Q2,i_phi',i_z,i_Q2,i_phi)
        plt.xlabel('$\phi_h$',fontsize=16)
        plt.ylabel('$2015$',fontsize=16)
f.close()
# Out:
# no data here i_z,i_Q2,i_phi 1 1 0
# no data here i_z,i_Q2,i_phi 1 1 1
# no data here i_z,i_Q2,i_phi 1 1 2
# no data here i_z,i_Q2,i_phi 1 1 3
# no data here i_z,i_Q2,i_phi 1 1 4
# no data here i_z,i_Q2,i_phi 1 1 5
# no data here i_z,i_Q2,i_phi 1 1 6
# no data here i_z,i_Q2,i_phi 1 2 4
# no data here i_z,i_Q2,i_phi 1 2 5
# no data here i_z,i_Q2,i_phi 1 2 6
# no data here i_z,i_Q2,i_phi 1 3 4
# no data here i_z,i_Q2,i_phi 1 3 5
# no data here i_z,i_Q2,i_phi 1 3 6
# no data here i_z,i_Q2,i_phi 2 1 0
# no data here i_z,i_Q2,i_phi 2 1 1
# no data here i_z,i_Q2,i_phi 2 1 2
# no data here i_z,i_Q2,i_phi 2 1 3
# no data here i_z,i_Q2,i_phi 2 1 4
# no data here i_z,i_Q2,i_phi 2 1 5
# no data here i_z,i_Q2,i_phi 2 1 6
# no data here i_z,i_Q2,i_phi 2 2 4
# no data here i_z,i_Q2,i_phi 2 2 5
# no data here i_z,i_Q2,i_phi 2 2 6
# no data here i_z,i_Q2,i_phi 2 3 4
# no data here i_z,i_Q2,i_phi 2 3 5
# no data here i_z,i_Q2,i_phi 2 3 6
# no data here i_z,i_Q2,i_phi 3 1 0
# ...

# %%
fig, axs = plt.subplots(4,3,figsize=(10,8),sharey=True,sharex=True)
fig.subplots_adjust(hspace=0)
fig.subplots_adjust(wspace=0)
#plt.ylabel('Ratio',fontsize=16)
plt.xlabel('$\phi_h(rad)$',fontsize=16)
f=open('../Unpol_proposal/Materials/results_sys/sys.txt','w')
print("zl zr Q2l Q2r phihl phihr phih dFuu dFuu_err",file=f)
for i_z in range(1,len(z_cuts)):
    for i_Q2 in range(1,len(Q2_cuts)):

        for i_phi in range(0,len(phih_bins)-1):
            
            try:
                phih_2015 = phihs_2015_bef[i_z-1,i_Q2-1,i_phi]
                Fuu_2015_aft = Fuus_2015_aft[i_z-1,i_Q2-1,i_phi]
                Fuu_err_2015_aft = Fuus_err_2015_aft[i_z-1,i_Q2-1,i_phi]
                #Fuu_kT4 = Fuus_kT4[i_z-1,i_Q2-1,i_phi]
                #Fuu_err_kT4 = Fuus_err_kT4[i_z-1,i_Q2-1,i_phi]
                Fuu_2015_bef = Fuus_2015_bef[i_z-1,i_Q2-1,i_phi]
                Fuu_err_2015_bef = Fuus_err_2015_bef[i_z-1,i_Q2-1,i_phi]
                _Fuu_ratio_2015,_Fuu_ratio_2015_err = Get_ratio_error(Fuu_2015_aft,Fuu_err_2015_aft,Fuu_2015_bef,Fuu_err_2015_bef)
                axs[i_Q2-1][i_z-1].plot([phih_2015,phih_2015],[_Fuu_ratio_2015-_Fuu_ratio_2015_err,_Fuu_ratio_2015+_Fuu_ratio_2015_err],color='black',marker='_')
                axs[i_Q2-1][i_z-1].plot(phih_2015,_Fuu_ratio_2015,'ko')
                
                phih_2011 = phihs_2011_bef[i_z-1,i_Q2-1,i_phi]+0.1
                Fuu_2011_aft = Fuus_2011_aft[i_z-1,i_Q2-1,i_phi]
                Fuu_err_2011_aft = Fuus_err_2011_aft[i_z-1,i_Q2-1,i_phi]
                #Fuu_kT4 = Fuus_kT4[i_z-1,i_Q2-1,i_phi]
                #Fuu_err_kT4 = Fuus_err_kT4[i_z-1,i_Q2-1,i_phi]
                Fuu_2011_bef = Fuus_2011_bef[i_z-1,i_Q2-1,i_phi]
                Fuu_err_2011_bef = Fuus_err_2011_bef[i_z-1,i_Q2-1,i_phi]
                _Fuu_ratio_2011,_Fuu_ratio_2011_err = Get_ratio_error(Fuu_2011_aft,Fuu_err_2011_aft,Fuu_2011_bef,Fuu_err_2011_bef)
                axs[i_Q2-1][i_z-1].plot([phih_2011,phih_2011],[_Fuu_ratio_2011-_Fuu_ratio_2011_err,_Fuu_ratio_2011+_Fuu_ratio_2011_err],color='blue',marker='_')
                axs[i_Q2-1][i_z-1].plot(phih_2011,_Fuu_ratio_2011,'bo')

                phih_default = phihs_default_bef[i_z-1,i_Q2-1,i_phi]+0.2
                Fuu_default_aft = Fuus_default_aft[i_z-1,i_Q2-1,i_phi]
                Fuu_err_default_aft = Fuus_err_default_aft[i_z-1,i_Q2-1,i_phi]
                #Fuu_kT4 = Fuus_kT4[i_z-1,i_Q2-1,i_phi]
                #Fuu_err_kT4 = Fuus_err_kT4[i_z-1,i_Q2-1,i_phi]
                Fuu_default_bef = Fuus_default_bef[i_z-1,i_Q2-1,i_phi]
                Fuu_err_default_bef = Fuus_err_default_bef[i_z-1,i_Q2-1,i_phi]
                _Fuu_ratio_default,_Fuu_ratio_default_err = Get_ratio_error(Fuu_default_aft,Fuu_err_default_aft,Fuu_default_bef,Fuu_err_default_bef)
                axs[i_Q2-1][i_z-1].plot([phih_default,phih_default],[_Fuu_ratio_default-_Fuu_ratio_default_err,_Fuu_ratio_default+_Fuu_ratio_default_err],color='red',marker='_')
                axs[i_Q2-1][i_z-1].plot(phih_default,_Fuu_ratio_default,'ro')
                
                print(z_cuts[i_z-1],z_cuts[i_z],Q2_cuts[i_Q2-1],Q2_cuts[i_Q2],phih_bins[i_phi],phih_bins[i_phi+1],phih,Fuu_ratio,Fuu_ratio_err,file=f)
                #axs[i_Q2-1][i_z-1].axhline(1,color = 'black',linestyle = ':')
                axs[i_Q2-1][i_z-1].text(0.5,0.9,r'${}<z_h<{}\ \ {}<Q^2<{}$'.format(z_cuts[i_z-1],z_cuts[i_z],Q2_cuts[i_Q2-1],Q2_cuts[i_Q2]), horizontalalignment='center', verticalalignment='center', transform=axs[i_Q2-1][i_z-1].transAxes)
                axs[i_Q2-1][i_z-1].text(0.5,0.8,r'${}<x_{{b}}<{}\ \ {}<P_{{hT}}<{}$'.format(xbj_cuts[0],xbj_cuts[1],PhT_cuts[0],PhT_cuts[1]), horizontalalignment='center', verticalalignment='center', transform=axs[i_Q2-1][i_z-1].transAxes)
            except KeyError:
                print('no data here i_z,i_Q2,i_phi',i_z,i_Q2,i_phi)
                

        #axs[i_Q2-1][i_z-1].set_xlabel('$\phi_h$',fontsize=16)
        #axs[i_Q2-1][i_z-1].set_ylabel('$F_{UU}$',fontsize=16)
        #axs[i_Q2-1][i_z-1].set_ylim(0.7,1.3)
        #axs[i_Q2-1][i_z-1].set_ylim(0.85,1.15)
        #axs[i_Q2-1][i_z-1].set_ylim(-1,4)
axs[0][0].set_ylim(1.2,1.6)
#axs[0][0].set_ylim(1.25,1.75)
axs[0][0].set_ylabel('$Systematic$',fontsize=16)
axs[0][0].legend(["","2015","","2011","","default"])
#for i_phih in phih_bins:
#    axs[0][0].axvline(x=i_phih)
plt.savefig('../Unpol_proposal/Materials/results_sys/Systemaic_acceptance.pdf')
f.close()
# Out:
# no data here i_z,i_Q2,i_phi 1 1 0
# no data here i_z,i_Q2,i_phi 1 1 1
# no data here i_z,i_Q2,i_phi 1 1 2
# no data here i_z,i_Q2,i_phi 1 1 3
# no data here i_z,i_Q2,i_phi 1 1 4
# no data here i_z,i_Q2,i_phi 1 1 5
# no data here i_z,i_Q2,i_phi 1 1 6
# no data here i_z,i_Q2,i_phi 1 2 4
# no data here i_z,i_Q2,i_phi 1 2 5
# no data here i_z,i_Q2,i_phi 1 2 6
# no data here i_z,i_Q2,i_phi 1 3 4
# no data here i_z,i_Q2,i_phi 1 3 5
# no data here i_z,i_Q2,i_phi 1 3 6
# no data here i_z,i_Q2,i_phi 2 1 0
# no data here i_z,i_Q2,i_phi 2 1 1
# no data here i_z,i_Q2,i_phi 2 1 2
# no data here i_z,i_Q2,i_phi 2 1 3
# no data here i_z,i_Q2,i_phi 2 1 4
# no data here i_z,i_Q2,i_phi 2 1 5
# no data here i_z,i_Q2,i_phi 2 1 6
# no data here i_z,i_Q2,i_phi 2 2 4
# no data here i_z,i_Q2,i_phi 2 2 5
# no data here i_z,i_Q2,i_phi 2 2 6
# no data here i_z,i_Q2,i_phi 2 3 4
# no data here i_z,i_Q2,i_phi 2 3 5
# no data here i_z,i_Q2,i_phi 2 3 6
# no data here i_z,i_Q2,i_phi 3 1 0
# ...

# %%
fig, axs = plt.subplots(4,3,figsize=(10,8),sharey=True,sharex=True)
fig.subplots_adjust(hspace=0)
fig.subplots_adjust(wspace=0)
#plt.ylabel('Ratio',fontsize=16)
plt.xlabel('$\phi_h(rad)$',fontsize=16)

for i_z in range(1,len(z_cuts)):
    for i_Q2 in range(1,len(Q2_cuts)):

        for i_phi in range(0,len(phih_bins)-1):
            
            try:
                phih_2015 = phihs_2015_bef[i_z-1,i_Q2-1,i_phi]
                Fuu_2015_aft = Fuus_2015_aft[i_z-1,i_Q2-1,i_phi]
                Fuu_err_2015_aft = Fuus_err_2015_aft[i_z-1,i_Q2-1,i_phi]
                #Fuu_kT4 = Fuus_kT4[i_z-1,i_Q2-1,i_phi]
                #Fuu_err_kT4 = Fuus_err_kT4[i_z-1,i_Q2-1,i_phi]
                Fuu_2015_bef = Fuus_2015_bef[i_z-1,i_Q2-1,i_phi]
                Fuu_err_2015_bef = Fuus_err_2015_bef[i_z-1,i_Q2-1,i_phi]
                _Fuu_ratio_2015,_Fuu_ratio_2015_err = Get_ratio_error(Fuu_2015_aft,Fuu_err_2015_aft,Fuu_2015_bef,Fuu_err_2015_bef)
                #axs[i_Q2-1][i_z-1].plot([phih_2015,phih_2015],[_Fuu_ratio_2015-_Fuu_ratio_2015_err,_Fuu_ratio_2015+_Fuu_ratio_2015_err],color='black',marker='_')
                #axs[i_Q2-1][i_z-1].plot(phih_2015,_Fuu_ratio_2015,'ko')
                
                phih_2011 = phihs_2011_bef[i_z-1,i_Q2-1,i_phi]+0.1
                Fuu_2011_aft = Fuus_2011_aft[i_z-1,i_Q2-1,i_phi]
                Fuu_err_2011_aft = Fuus_err_2011_aft[i_z-1,i_Q2-1,i_phi]
                #Fuu_kT4 = Fuus_kT4[i_z-1,i_Q2-1,i_phi]
                #Fuu_err_kT4 = Fuus_err_kT4[i_z-1,i_Q2-1,i_phi]
                Fuu_2011_bef = Fuus_2011_bef[i_z-1,i_Q2-1,i_phi]
                Fuu_err_2011_bef = Fuus_err_2011_bef[i_z-1,i_Q2-1,i_phi]
                _Fuu_ratio_2011,_Fuu_ratio_2011_err = Get_ratio_error(Fuu_2011_aft,Fuu_err_2011_aft,Fuu_2011_bef,Fuu_err_2011_bef)
                #axs[i_Q2-1][i_z-1].plot([phih_2011,phih_2011],[_Fuu_ratio_2011-_Fuu_ratio_2011_err,_Fuu_ratio_2011+_Fuu_ratio_2011_err],color='blue',marker='_')
                #axs[i_Q2-1][i_z-1].plot(phih_2011,_Fuu_ratio_2011,'bo')

                phih_default = phihs_default_bef[i_z-1,i_Q2-1,i_phi]+0.2
                Fuu_default_aft = Fuus_default_aft[i_z-1,i_Q2-1,i_phi]
                Fuu_err_default_aft = Fuus_err_default_aft[i_z-1,i_Q2-1,i_phi]
                #Fuu_kT4 = Fuus_kT4[i_z-1,i_Q2-1,i_phi]
                #Fuu_err_kT4 = Fuus_err_kT4[i_z-1,i_Q2-1,i_phi]
                Fuu_default_bef = Fuus_default_bef[i_z-1,i_Q2-1,i_phi]
                Fuu_err_default_bef = Fuus_err_default_bef[i_z-1,i_Q2-1,i_phi]
                _Fuu_ratio_default,_Fuu_ratio_default_err = Get_ratio_error(Fuu_default_aft,Fuu_err_default_aft,Fuu_default_bef,Fuu_err_default_bef)
                #axs[i_Q2-1][i_z-1].plot([phih_default,phih_default],[_Fuu_ratio_default-_Fuu_ratio_default_err,_Fuu_ratio_default+_Fuu_ratio_default_err],color='red',marker='_')
                #axs[i_Q2-1][i_z-1].plot(phih_default,_Fuu_ratio_default,'ro')
                
                if Fuu_err_2011_aft>0 and Fuu_err_default_aft>0 and Fuu_err_2015_aft>0:
                    
                    #print('high edge of z,Q2,phi',z_cuts[i_z],Q2_cuts[i_Q2],phih_bins[i_phi+1],file=f)
                    #print('2015/2011 bef',Fuu_err_2015_bef/Fuu_err_2011_bef,'2015/2011 aft',Fuu_err_2015_aft/Fuu_err_2011_aft,file=f)
                    #print('2015/default bef',Fuu_err_2015_bef/Fuu_err_default_bef,'2015/default aft',Fuu_err_2015_aft/Fuu_err_default_aft,file=f)
                    #print('2011/default bef',Fuu_err_2011_bef/Fuu_err_default_bef,'2011/default aft',Fuu_err_2011_aft/Fuu_err_default_aft,file=f)
                    bef_1 = Fuu_err_2011_bef/Fuu_err_default_aft
                    bef_2 = Fuu_err_default_bef/Fuu_err_2011_aft
                    ratio = abs(bef_1-bef_2)/bef_1
                    bef2_1 = Fuu_err_2015_bef/Fuu_err_default_aft
                    bef2_2 = Fuu_err_default_bef/Fuu_err_2015_aft
                    ratio_2 = abs(bef2_1-bef2_2)/bef2_1
                    bef3_1 =  Fuu_err_2011_bef/Fuu_err_2015_aft
                    bef3_2 = Fuu_err_2015_bef/Fuu_err_2011_aft
                    ratio_3 = abs(bef3_1-bef3_2)/bef3_1
                    diff = ratio
                    #diff = 1/3*(ratio+ratio_2+ratio_3)
                    axs[i_Q2-1][i_z-1].plot(phih_default,diff,'ko')

                #axs[i_Q2-1][i_z-1].axhline(1,color = 'black',linestyle = ':')
                axs[i_Q2-1][i_z-1].text(0.5,0.9,r'${}<z_h<{}\ \ {}<Q^2<{}$'.format(z_cuts[i_z-1],z_cuts[i_z],Q2_cuts[i_Q2-1],Q2_cuts[i_Q2]), horizontalalignment='center', verticalalignment='center', transform=axs[i_Q2-1][i_z-1].transAxes)
                axs[i_Q2-1][i_z-1].text(0.5,0.8,r'${}<x_{{b}}<{}\ \ {}<P_{{hT}}<{}$'.format(xbj_cuts[0],xbj_cuts[1],PhT_cuts[0],PhT_cuts[1]), horizontalalignment='center', verticalalignment='center', transform=axs[i_Q2-1][i_z-1].transAxes)
            except KeyError:
                print('no data here i_z,i_Q2,i_phi',i_z,i_Q2,i_phi)
                

        #axs[i_Q2-1][i_z-1].set_xlabel('$\phi_h$',fontsize=16)
        #axs[i_Q2-1][i_z-1].set_ylabel('$F_{UU}$',fontsize=16)
        #axs[i_Q2-1][i_z-1].set_ylim(0.7,1.3)
        #axs[i_Q2-1][i_z-1].set_ylim(0.85,1.15)
        #axs[i_Q2-1][i_z-1].set_ylim(-1,4)
axs[0][0].set_ylim(-0.01,0.21)
#axs[0][0].set_ylim(1.25,1.75)
axs[0][0].set_ylabel('$Systematic$',fontsize=16)
#axs[0][0].legend(["","2015","","2011","","default"])
#for i_phih in phih_bins:
#    axs[0][0].axvline(x=i_phih)
plt.savefig('../Unpol_proposal/Materials/results_sys/Systemaic_acceptance.pdf')
# Out:
# no data here i_z,i_Q2,i_phi 1 1 0
# no data here i_z,i_Q2,i_phi 1 1 1
# no data here i_z,i_Q2,i_phi 1 1 2
# no data here i_z,i_Q2,i_phi 1 1 3
# no data here i_z,i_Q2,i_phi 1 1 4
# no data here i_z,i_Q2,i_phi 1 1 5
# no data here i_z,i_Q2,i_phi 1 1 6
# no data here i_z,i_Q2,i_phi 1 2 4
# no data here i_z,i_Q2,i_phi 1 2 5
# no data here i_z,i_Q2,i_phi 1 2 6
# no data here i_z,i_Q2,i_phi 1 3 4
# no data here i_z,i_Q2,i_phi 1 3 5
# no data here i_z,i_Q2,i_phi 1 3 6
# no data here i_z,i_Q2,i_phi 2 1 0
# no data here i_z,i_Q2,i_phi 2 1 1
# no data here i_z,i_Q2,i_phi 2 1 2
# no data here i_z,i_Q2,i_phi 2 1 3
# no data here i_z,i_Q2,i_phi 2 1 4
# no data here i_z,i_Q2,i_phi 2 1 5
# no data here i_z,i_Q2,i_phi 2 1 6
# no data here i_z,i_Q2,i_phi 2 2 4
# no data here i_z,i_Q2,i_phi 2 2 5
# no data here i_z,i_Q2,i_phi 2 2 6
# no data here i_z,i_Q2,i_phi 2 3 4
# no data here i_z,i_Q2,i_phi 2 3 5
# no data here i_z,i_Q2,i_phi 2 3 6
# no data here i_z,i_Q2,i_phi 3 1 0
# ...
